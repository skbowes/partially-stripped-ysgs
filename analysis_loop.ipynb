# %%
import numpy as np
import os
import sys
import astropy as ast
from astropy.io import ascii
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import pandas as pd
import scipy as sp
from astropy.timeseries import LombScargle
from astropy import units as u
import gc

# %%
from view_and_clean import get_telescope, find_header_line, modified_zscore, df_extract, individual_plotter, grid_plotter, offset_corrector, offset_corrector_window
from metrics import mean_med_flux, fit_plotter_flux, curve_fitter_flux,\
    largest_amplitude, offset_warning, chi, percentile_amplitude, plot_percentile_amplitude, \
        compute_lomb_scargle, plot_periodogram, plot_phase_fold, amplitude_per_period, amplitude_per_period_plot

# %% [markdown]
# ### Extracting data from files and plotting:

# %%
# coords = pd.read_csv('ysg_coords_with_lcs.dat', comment='#', sep="\\s+", names=['RA', 'DEC'])
# coords = pd.read_csv('/Users/shannonbowes/Research/ysg/candidates_and_lcs/final_smc_ysgcands.csv', comment='#', sep="\\s+", names=['ra', 'dec'])
coords = pd.read_csv('merged_smc_lmc_coords.csv', comment='#', sep="\\s+", names=['ra', 'dec'])

# %%
results = []

# %% [markdown]
# ### New data:

# %%
# Create DataFrame structure once before the loop
columns = [
    'RA', 'DEC', 'overall_mean', 'overall_median', 'overall_mean_mag', 'overall_median_mag',
    'offset_flag', 'chi_squared_68', 'chi2_threshold_68', 'chi_flag_68',
    'chi_squared_95', 'chi2_threshold_95', 'chi_flag_95', 
    'chi_squared_997', 'chi2_threshold_997', 'chi_flag_997',
    'amplitude_5', 'lower_percentile_5', 'upper_percentile_5', 'mag_amplitude_5',
    'amplitude_1', 'lower_percentile_1', 'upper_percentile_1', 'mag_amplitude_1',
    'largest_amp', 'best_period', 'alarm_level_flag', 'std_amplitude'
]

# Initialize DataFrame with NaN values and pre-populate coordinates
results_df = pd.DataFrame(index=range(848), columns=columns, dtype=float)
results_df['RA'] = coords['ra'].values
results_df['DEC'] = coords['dec'].values

# Main analysis loop
for target in range(0, 848):
    print("Target: ", target)
    
    try:
        df, telescopes = offset_corrector(target, additive=False, show=False)
        # if target in [375, 376, 377, 378, 379, 380]:
        #     print(f"\n=== DETAILED TARGET {target} ANALYSIS ===")
        #     print(f"Dataset: {'SMC' if target <= 376 else 'LMC'}")
        #     print(f"DataFrame shape: {df.shape}")
        #     print(f"Telescopes: {telescopes}")
        #     print(f"Time range: {df['HJD'].min():.1f} to {df['HJD'].max():.1f}")
        #     print(f"Unique telescope count: {len(telescopes)}")
        #     print(f"Data points per telescope: {[len(df[df['telescope']==t]) for t in telescopes]}")
        
        # analysis
        overall_mean, means, overall_median, medians, overall_mags_mean, overall_mags_median, mags_means, mags_medians = mean_med_flux(target, df=df, telescopes=telescopes)
        chi_squared_95, chi2_threshold_95, dof_95, chi_flag_95 = chi(target, df=df, telescopes=telescopes, confidence=0.95)
        chi_squared_997, chi2_threshold_997, dof_997, chi_flag_997 = chi(target, df=df, telescopes=telescopes, confidence=0.997)
        chi_squared_68, chi2_threshold_68, dof_68, chi_flag_68 = chi(target, df=df, telescopes=telescopes, confidence=0.68)
        offset_flag = offset_warning(target)
        amplitude_5, lower_percentile_5, upper_percentile_5, mag_amplitude_5 = percentile_amplitude(target, df=df, telescopes=telescopes, tails=5)
        amplitude_1, lower_percentile_1, upper_percentile_1, mag_amplitude_1 = percentile_amplitude(target, df=df, telescopes=telescopes, tails=1)
        largest_amp = largest_amplitude(target, df=df, telescopes=telescopes)
        lombs = compute_lomb_scargle(target, df=df, telescopes=telescopes, auto=False, median=False, subtract_median=False, samples_per_peak=10, report=False)
        best_period = lombs['best_period']
        alarm_level_flag = lombs['alarm_level_flag']
        result = amplitude_per_period(target, best_period, df=df, telescopes=telescopes, report=False)
        std_amp = result['std_amplitude']
        
        results_df.loc[target, 'overall_mean'] = overall_mean
        results_df.loc[target, 'overall_median'] = overall_median
        results_df.loc[target, 'overall_mean_mag'] = overall_mags_mean
        results_df.loc[target, 'overall_median_mag'] = overall_mags_median
        results_df.loc[target, 'offset_flag'] = offset_flag
        results_df.loc[target, 'chi_squared_68'] = chi_squared_68
        results_df.loc[target, 'chi2_threshold_68'] = chi2_threshold_68
        results_df.loc[target, 'chi_flag_68'] = chi_flag_68
        results_df.loc[target, 'chi_squared_95'] = chi_squared_95
        results_df.loc[target, 'chi2_threshold_95'] = chi2_threshold_95
        results_df.loc[target, 'chi_flag_95'] = chi_flag_95
        results_df.loc[target, 'chi_squared_997'] = chi_squared_997
        results_df.loc[target, 'chi2_threshold_997'] = chi2_threshold_997
        results_df.loc[target, 'chi_flag_997'] = chi_flag_997
        results_df.loc[target, 'amplitude_5'] = amplitude_5
        results_df.loc[target, 'lower_percentile_5'] = lower_percentile_5
        results_df.loc[target, 'upper_percentile_5'] = upper_percentile_5
        results_df.loc[target, 'mag_amplitude_5'] = mag_amplitude_5
        results_df.loc[target, 'amplitude_1'] = amplitude_1
        results_df.loc[target, 'lower_percentile_1'] = lower_percentile_1
        results_df.loc[target, 'upper_percentile_1'] = upper_percentile_1
        results_df.loc[target, 'mag_amplitude_1'] = mag_amplitude_1
        results_df.loc[target, 'largest_amp'] = largest_amp
        results_df.loc[target, 'best_period'] = best_period
        results_df.loc[target, 'alarm_level_flag'] = alarm_level_flag
        results_df.loc[target, 'std_amplitude'] = std_amp
        
        # Explicit memory cleanup to prevent accumulation
        del df, telescopes, lombs, result
        del overall_mean, means, overall_median, medians
        del overall_mags_mean, overall_mags_median, mags_means, mags_medians
        del amplitude_5, amplitude_1, largest_amp, std_amp
        
    except Exception as e:
        print(f"Target {target} failed: {e}")
        # Values remain NaN in DataFrame - no action needed
        continue
    
    # More frequent garbage collection for better memory management
    if target % 25 == 0:
        gc.collect()
        # Optional: Memory monitoring
        if target % 100 == 0:
            import psutil, os
            process = psutil.Process(os.getpid())
            memory_mb = process.memory_info().rss / 1024 / 1024
            print(f"Memory usage at target {target}: {memory_mb:.1f} MB")

# Save results
results_df.to_csv('summary_results17.csv', index=False)
print(f"Analysis complete! Results saved to summary_results17.csv")
print(f"Shape: {results_df.shape}")
print(f"Memory usage: {results_df.memory_usage(deep=True).sum() / 1024**2:.1f} MB")
# Out:
# Target:  0
# Offsets for object 0 (g-band: True):
# {'k_vs_l': np.float64(nan), 'k_vs_o': np.float64(nan), 'k_vs_p': np.float64(nan), 'k_vs_G': np.float64(nan), 'k_vs_H': np.float64(nan), 'l_vs_k': np.float64(nan), 'l_vs_o': nan, 'l_vs_p': nan, 'l_vs_G': nan, 'l_vs_H': nan, 'o_vs_k': np.float64(nan), 'o_vs_l': nan, 'o_vs_p': nan, 'o_vs_G': nan, 'o_vs_H': nan, 'p_vs_k': np.float64(nan), 'p_vs_l': nan, 'p_vs_o': nan, 'p_vs_G': nan, 'p_vs_H': nan, 'G_vs_k': np.float64(nan), 'G_vs_l': nan, 'G_vs_o': nan, 'G_vs_p': nan, 'G_vs_H': nan, 'H_vs_k': np.float64(nan), 'H_vs_l': nan, 'H_vs_o': nan, 'H_vs_p': nan, 'H_vs_G': nan}
# Amplitude metrics:
# 	Lower 5% percentile: 9.95 mJy, 13.83 mags
# 	Upper 5% percentile: 10.70 mJy, 13.91 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.75 mJy, 0.08 mags
# Amplitude metrics:
# 	Lower 1% percentile: 9.80 mJy, 13.81 mags
# 	Upper 1% percentile: 10.87 mJy, 13.92 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 1.06 mJy, 0.11 mags
# 	Largest amplitude of variability (g-band: True): 1.31 mJy, 0.14 mags
# 	Average amplitude across all periods: 0.036 mJy
# 	Standard deviation of amplitudes: 0.102 mJy
# 	Warning: average amplitude (0.036 mJy) is less than 5 sigma (0.102 mJy). This indicates significant variability in the amplitudes across periods.
# Memory usage at target 0: 405.2 MB
# Target:  1
# Offsets for object 1 (g-band: True):
# {'l_vs_o': np.float64(nan), 'l_vs_p': np.float64(nan), 'l_vs_G': np.float64(nan), 'l_vs_H': np.float64(nan), 'o_vs_l': np.float64(nan), 'o_vs_p': nan, 'o_vs_G': nan, 'o_vs_H': nan, 'p_vs_l': np.float64(nan), 'p_vs_o': nan, 'p_vs_G': nan, 'p_vs_H': nan, 'G_vs_l': np.float64(nan), 'G_vs_o': nan, 'G_vs_p': nan, 'G_vs_H': nan, 'H_vs_l': np.float64(nan), 'H_vs_o': nan, 'H_vs_p': nan, 'H_vs_G': nan}
# Amplitude metrics:
# 	Lower 5% percentile: 7.97 mJy, 14.08 mags
# 	Upper 5% percentile: 8.50 mJy, 14.15 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.53 mJy, 0.07 mags
# Amplitude metrics:
# 	Lower 1% percentile: 7.88 mJy, 14.06 mags
# 	Upper 1% percentile: 8.62 mJy, 14.16 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.75 mJy, 0.10 mags
# 	Largest amplitude of variability (g-band: True): 1.08 mJy, 0.14 mags
# 	Average amplitude across all periods: 0.072 mJy
# 	Standard deviation of amplitudes: 0.125 mJy
# 	Warning: average amplitude (0.072 mJy) is less than 5 sigma (0.125 mJy). This indicates significant variability in the amplitudes across periods.
# Target:  2
# Offsets for object 2 (g-band: True):
# {'l_vs_o': np.float64(nan), 'l_vs_p': np.float64(nan), 'l_vs_G': np.float64(nan), 'l_vs_H': np.float64(nan), 'o_vs_l': np.float64(nan), 'o_vs_p': nan, 'o_vs_G': nan, 'o_vs_H': nan, 'p_vs_l': np.float64(nan), 'p_vs_o': nan, 'p_vs_G': nan, 'p_vs_H': nan, 'G_vs_l': np.float64(nan), 'G_vs_o': nan, 'G_vs_p': nan, 'G_vs_H': nan, 'H_vs_l': np.float64(nan), 'H_vs_o': nan, 'H_vs_p': nan, 'H_vs_G': nan}
# Amplitude metrics:
# 	Lower 5% percentile: 3.47 mJy, 14.92 mags
# 	Upper 5% percentile: 3.92 mJy, 15.05 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.46 mJy, 0.13 mags
# Amplitude metrics:
# 	Lower 1% percentile: 3.39 mJy, 14.88 mags
# 	Upper 1% percentile: 4.05 mJy, 15.07 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.66 mJy, 0.19 mags
# 	Largest amplitude of variability (g-band: True): 0.94 mJy, 0.28 mags
# 	Average amplitude across all periods: 0.655 mJy
# 	Standard deviation of amplitudes: 0.094 mJy
# 	Average amplitude (0.655 mJy) is greater than 5 sigma (0.094 mJy). This indicates consistent variability across periods.
# Target:  3
# Offsets for object 3 (g-band: True):
# {'l_vs_o': np.float64(nan), 'l_vs_p': np.float64(nan), 'l_vs_G': np.float64(nan), 'l_vs_H': np.float64(nan), 'o_vs_l': np.float64(nan), 'o_vs_p': nan, 'o_vs_G': nan, 'o_vs_H': nan, 'p_vs_l': np.float64(nan), 'p_vs_o': nan, 'p_vs_G': nan, 'p_vs_H': nan, 'G_vs_l': np.float64(nan), 'G_vs_o': nan, 'G_vs_p': nan, 'G_vs_H': nan, 'H_vs_l': np.float64(nan), 'H_vs_o': nan, 'H_vs_p': nan, 'H_vs_G': nan}
# Amplitude metrics:
# 	Lower 5% percentile: 4.16 mJy, 14.76 mags
# 	Upper 5% percentile: 4.54 mJy, 14.85 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.37 mJy, 0.09 mags
# Amplitude metrics:
# 	Lower 1% percentile: 4.06 mJy, 14.74 mags
# 	Upper 1% percentile: 4.63 mJy, 14.88 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.57 mJy, 0.14 mags
# 	Largest amplitude of variability (g-band: True): 0.79 mJy, 0.20 mags
# 	Average amplitude across all periods: 0.583 mJy
# 	Standard deviation of amplitudes: 0.102 mJy
# 	Average amplitude (0.583 mJy) is greater than 5 sigma (0.102 mJy). This indicates consistent variability across periods.
# Target:  4
# Offsets for object 4 (g-band: True):
# {'l_vs_o': np.float64(nan), 'l_vs_p': np.float64(nan), 'l_vs_G': np.float64(nan), 'l_vs_H': np.float64(nan), 'o_vs_l': np.float64(nan), 'o_vs_p': nan, 'o_vs_G': nan, 'o_vs_H': nan, 'p_vs_l': np.float64(nan), 'p_vs_o': nan, 'p_vs_G': nan, 'p_vs_H': nan, 'G_vs_l': np.float64(nan), 'G_vs_o': nan, 'G_vs_p': nan, 'G_vs_H': nan, 'H_vs_l': np.float64(nan), 'H_vs_o': nan, 'H_vs_p': nan, 'H_vs_G': nan}
# Amplitude metrics:
# 	Lower 5% percentile: 2.88 mJy, 15.13 mags
# 	Upper 5% percentile: 3.23 mJy, 15.25 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.35 mJy, 0.12 mags
# Amplitude metrics:
# 	Lower 1% percentile: 2.82 mJy, 15.08 mags
# 	Upper 1% percentile: 3.37 mJy, 15.28 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.56 mJy, 0.20 mags
# 	Largest amplitude of variability (g-band: True): 0.69 mJy, 0.24 mags
# 	Average amplitude across all periods: 0.003 mJy
# 	Standard deviation of amplitudes: 0.019 mJy
# 	Warning: average amplitude (0.003 mJy) is less than 5 sigma (0.019 mJy). This indicates significant variability in the amplitudes across periods.
# Target:  5
# Offsets for object 5 (g-band: True):
# {'l_vs_o': np.float64(nan), 'l_vs_p': np.float64(nan), 'l_vs_G': np.float64(nan), 'l_vs_H': np.float64(nan), 'o_vs_l': np.float64(nan), 'o_vs_p': nan, 'o_vs_G': nan, 'o_vs_H': nan, 'p_vs_l': np.float64(nan), 'p_vs_o': nan, 'p_vs_G': nan, 'p_vs_H': nan, 'G_vs_l': np.float64(nan), 'G_vs_o': nan, 'G_vs_p': nan, 'G_vs_H': nan, 'H_vs_l': np.float64(nan), 'H_vs_o': nan, 'H_vs_p': nan, 'H_vs_G': nan}
# Amplitude metrics:
# 	Lower 5% percentile: 5.35 mJy, 14.47 mags
# 	Upper 5% percentile: 5.89 mJy, 14.58 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.54 mJy, 0.11 mags
# Amplitude metrics:
# 	Lower 1% percentile: 5.27 mJy, 14.45 mags
# 	Upper 1% percentile: 6.04 mJy, 14.60 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.77 mJy, 0.15 mags
# 	Largest amplitude of variability (g-band: True): 0.90 mJy, 0.17 mags
# 	Average amplitude across all periods: 0.603 mJy
# 	Standard deviation of amplitudes: 0.121 mJy
# 	Warning: average amplitude (0.603 mJy) is less than 5 sigma (0.121 mJy). This indicates significant variability in the amplitudes across periods.
# Target:  6
# Offsets for object 6 (g-band: True):
# {'l_vs_o': np.float64(nan), 'l_vs_p': np.float64(nan), 'l_vs_G': np.float64(nan), 'l_vs_H': np.float64(nan), 'o_vs_l': np.float64(nan), 'o_vs_p': nan, 'o_vs_G': nan, 'o_vs_H': nan, 'p_vs_l': np.float64(nan), 'p_vs_o': nan, 'p_vs_G': nan, 'p_vs_H': nan, 'G_vs_l': np.float64(nan), 'G_vs_o': nan, 'G_vs_p': nan, 'G_vs_H': nan, 'H_vs_l': np.float64(nan), 'H_vs_o': nan, 'H_vs_p': nan, 'H_vs_G': nan}
# Amplitude metrics:
# 	Lower 5% percentile: 4.79 mJy, 13.87 mags
# 	Upper 5% percentile: 10.31 mJy, 14.70 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 5.53 mJy, 0.83 mags
# Amplitude metrics:
# 	Lower 1% percentile: 4.65 mJy, 13.82 mags
# 	Upper 1% percentile: 10.78 mJy, 14.73 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 6.14 mJy, 0.91 mags
# 	Largest amplitude of variability (g-band: True): 6.89 mJy, 1.05 mags
# 	Average amplitude across all periods: 4.246 mJy
# 	Standard deviation of amplitudes: 1.498 mJy
# 	Warning: average amplitude (4.246 mJy) is less than 5 sigma (1.498 mJy). This indicates significant variability in the amplitudes across periods.
# Target:  7
# Offsets for object 7 (g-band: True):
# {'l_vs_p': np.float64(nan), 'l_vs_G': np.float64(nan), 'l_vs_H': np.float64(nan), 'p_vs_l': np.float64(nan), 'p_vs_G': nan, 'p_vs_H': nan, 'G_vs_l': np.float64(nan), 'G_vs_p': nan, 'G_vs_H': nan, 'H_vs_l': np.float64(nan), 'H_vs_p': nan, 'H_vs_G': nan}
# Amplitude metrics:
# 	Lower 5% percentile: 3.90 mJy, 14.79 mags
# 	Upper 5% percentile: 4.39 mJy, 14.92 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.49 mJy, 0.13 mags
# Amplitude metrics:
# 	Lower 1% percentile: 3.79 mJy, 14.77 mags
# 	Upper 1% percentile: 4.49 mJy, 14.95 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.70 mJy, 0.18 mags
# 	Largest amplitude of variability (g-band: True): 0.88 mJy, 0.23 mags
# 	Average amplitude across all periods: 0.387 mJy
# 	Standard deviation of amplitudes: 0.140 mJy
# 	Warning: average amplitude (0.387 mJy) is less than 5 sigma (0.140 mJy). This indicates significant variability in the amplitudes across periods.
# Target:  8
# Offsets for object 8 (g-band: True):
# {}
# Amplitude metrics:
# 	Lower 5% percentile: 24.63 mJy, 12.88 mags
# 	Upper 5% percentile: 25.64 mJy, 12.92 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 1.01 mJy, 0.04 mags
# Amplitude metrics:
# 	Lower 1% percentile: 24.39 mJy, 12.87 mags
# 	Upper 1% percentile: 25.85 mJy, 12.93 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 1.46 mJy, 0.06 mags
# 	Largest amplitude of variability (g-band: True): 2.40 mJy, 0.10 mags
# 	Average amplitude across all periods: 1.817 mJy
# 	Standard deviation of amplitudes: 0.355 mJy
# 	Average amplitude (1.817 mJy) is greater than 5 sigma (0.355 mJy). This indicates consistent variability across periods.
# Target:  9
# Offsets for object 9 (g-band: True):
# {'l_vs_p': np.float64(nan), 'l_vs_H': np.float64(nan), 'p_vs_l': np.float64(nan), 'p_vs_H': nan, 'H_vs_l': np.float64(nan), 'H_vs_p': nan}
# Amplitude metrics:
# 	Lower 5% percentile: 5.64 mJy, 14.44 mags
# 	Upper 5% percentile: 6.07 mJy, 14.52 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.43 mJy, 0.08 mags
# Amplitude metrics:
# 	Lower 1% percentile: 5.50 mJy, 14.41 mags
# 	Upper 1% percentile: 6.23 mJy, 14.55 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.73 mJy, 0.13 mags
# 	Largest amplitude of variability (g-band: True): 0.90 mJy, 0.17 mags
# 	Average amplitude across all periods: 0.686 mJy
# 	Standard deviation of amplitudes: 0.096 mJy
# 	Average amplitude (0.686 mJy) is greater than 5 sigma (0.096 mJy). This indicates consistent variability across periods.
# Target:  10
# Offsets for object 10 (g-band: True):
# {'l_vs_o': np.float64(nan), 'l_vs_p': np.float64(nan), 'l_vs_G': np.float64(nan), 'l_vs_H': np.float64(nan), 'o_vs_l': np.float64(nan), 'o_vs_p': nan, 'o_vs_G': nan, 'o_vs_H': nan, 'p_vs_l': np.float64(nan), 'p_vs_o': nan, 'p_vs_G': nan, 'p_vs_H': nan, 'G_vs_l': np.float64(nan), 'G_vs_o': nan, 'G_vs_p': nan, 'G_vs_H': nan, 'H_vs_l': np.float64(nan), 'H_vs_o': nan, 'H_vs_p': nan, 'H_vs_G': nan}
# Amplitude metrics:
# 	Lower 5% percentile: 7.98 mJy, 14.03 mags
# 	Upper 5% percentile: 8.86 mJy, 14.15 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.88 mJy, 0.11 mags
# Amplitude metrics:
# 	Lower 1% percentile: 7.76 mJy, 14.01 mags
# 	Upper 1% percentile: 9.06 mJy, 14.18 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 1.30 mJy, 0.17 mags
# 	Largest amplitude of variability (g-band: True): 1.80 mJy, 0.24 mags
# 	Average amplitude across all periods: 1.022 mJy
# 	Standard deviation of amplitudes: 0.214 mJy
# 	Warning: average amplitude (1.022 mJy) is less than 5 sigma (0.214 mJy). This indicates significant variability in the amplitudes across periods.
# Target:  11
# Offsets for object 11 (g-band: True):
# {'l_vs_p': np.float64(nan), 'l_vs_H': np.float64(nan), 'p_vs_l': np.float64(nan), 'p_vs_H': nan, 'H_vs_l': np.float64(nan), 'H_vs_p': nan}
# Amplitude metrics:
# 	Lower 5% percentile: 4.37 mJy, 14.71 mags
# 	Upper 5% percentile: 4.75 mJy, 14.80 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.37 mJy, 0.09 mags
# Amplitude metrics:
# 	Lower 1% percentile: 4.30 mJy, 14.69 mags
# 	Upper 1% percentile: 4.83 mJy, 14.82 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.53 mJy, 0.13 mags
# 	Largest amplitude of variability (g-band: True): 0.75 mJy, 0.18 mags
# 	Average amplitude across all periods: 0.485 mJy
# 	Standard deviation of amplitudes: 0.090 mJy
# 	Average amplitude (0.485 mJy) is greater than 5 sigma (0.090 mJy). This indicates consistent variability across periods.
# Target:  12
# Offsets for object 12 (g-band: True):
# {'l_vs_p': np.float64(nan), 'l_vs_H': np.float64(nan), 'p_vs_l': np.float64(nan), 'p_vs_H': nan, 'H_vs_l': np.float64(nan), 'H_vs_p': nan}
# Amplitude metrics:
# 	Lower 5% percentile: 10.55 mJy, 13.78 mags
# 	Upper 5% percentile: 11.15 mJy, 13.84 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.60 mJy, 0.06 mags
# Amplitude metrics:
# 	Lower 1% percentile: 10.42 mJy, 13.77 mags
# 	Upper 1% percentile: 11.31 mJy, 13.86 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.89 mJy, 0.09 mags
# 	Largest amplitude of variability (g-band: True): 1.11 mJy, 0.11 mags
# 	Average amplitude across all periods: 0.827 mJy
# 	Standard deviation of amplitudes: 0.090 mJy
# 	Average amplitude (0.827 mJy) is greater than 5 sigma (0.090 mJy). This indicates consistent variability across periods.
# Target:  13
# Offsets for object 13 (g-band: True):
# {'l_vs_p': np.float64(nan), 'l_vs_G': np.float64(nan), 'l_vs_H': np.float64(nan), 'p_vs_l': np.float64(nan), 'p_vs_G': nan, 'p_vs_H': nan, 'G_vs_l': np.float64(nan), 'G_vs_p': nan, 'G_vs_H': nan, 'H_vs_l': np.float64(nan), 'H_vs_p': nan, 'H_vs_G': nan}
# Amplitude metrics:
# 	Lower 5% percentile: 3.53 mJy, 14.92 mags
# 	Upper 5% percentile: 3.90 mJy, 15.03 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.37 mJy, 0.11 mags
# Amplitude metrics:
# 	Lower 1% percentile: 3.42 mJy, 14.89 mags
# 	Upper 1% percentile: 4.03 mJy, 15.07 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.61 mJy, 0.18 mags
# 	Largest amplitude of variability (g-band: True): 0.76 mJy, 0.22 mags
# 	Average amplitude across all periods: 0.179 mJy
# 	Standard deviation of amplitudes: 0.130 mJy
# 	Warning: average amplitude (0.179 mJy) is less than 5 sigma (0.130 mJy). This indicates significant variability in the amplitudes across periods.
# Target:  14
# Offsets for object 14 (g-band: True):
# {'l_vs_p': np.float64(nan), 'l_vs_H': np.float64(nan), 'p_vs_l': np.float64(nan), 'p_vs_H': nan, 'H_vs_l': np.float64(nan), 'H_vs_p': nan}
# Amplitude metrics:
# 	Lower 5% percentile: 9.77 mJy, 13.86 mags
# 	Upper 5% percentile: 10.41 mJy, 13.93 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.64 mJy, 0.07 mags
# Amplitude metrics:
# 	Lower 1% percentile: 9.66 mJy, 13.84 mags
# 	Upper 1% percentile: 10.60 mJy, 13.94 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.95 mJy, 0.10 mags
# 	Largest amplitude of variability (g-band: True): 1.31 mJy, 0.14 mags
# 	Average amplitude across all periods: 0.856 mJy
# 	Standard deviation of amplitudes: 0.135 mJy
# 	Average amplitude (0.856 mJy) is greater than 5 sigma (0.135 mJy). This indicates consistent variability across periods.
# Target:  15
# Offsets for object 15 (g-band: True):
# {'l_vs_p': np.float64(nan), 'l_vs_H': np.float64(nan), 'p_vs_l': np.float64(nan), 'p_vs_H': nan, 'H_vs_l': np.float64(nan), 'H_vs_p': nan}
# Amplitude metrics:
# 	Lower 5% percentile: 4.44 mJy, 14.66 mags
# 	Upper 5% percentile: 4.95 mJy, 14.78 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.51 mJy, 0.12 mags
# Amplitude metrics:
# 	Lower 1% percentile: 4.34 mJy, 14.64 mags
# 	Upper 1% percentile: 5.06 mJy, 14.81 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.72 mJy, 0.17 mags
# 	Largest amplitude of variability (g-band: True): 1.08 mJy, 0.25 mags
# 	Average amplitude across all periods: 0.698 mJy
# 	Standard deviation of amplitudes: 0.126 mJy
# 	Average amplitude (0.698 mJy) is greater than 5 sigma (0.126 mJy). This indicates consistent variability across periods.
# Target:  16
# Offsets for object 16 (g-band: True):
# {'l_vs_p': np.float64(nan), 'l_vs_H': np.float64(nan), 'p_vs_l': np.float64(nan), 'p_vs_H': nan, 'H_vs_l': np.float64(nan), 'H_vs_p': nan}
# Amplitude metrics:
# 	Lower 5% percentile: 5.86 mJy, 13.98 mags
# 	Upper 5% percentile: 9.26 mJy, 14.48 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 3.40 mJy, 0.50 mags
# Amplitude metrics:
# 	Lower 1% percentile: 5.71 mJy, 13.96 mags
# 	Upper 1% percentile: 9.49 mJy, 14.51 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 3.78 mJy, 0.55 mags
# 	Largest amplitude of variability (g-band: True): 4.06 mJy, 0.59 mags
# 	Average amplitude across all periods: 3.008 mJy
# 	Standard deviation of amplitudes: 0.684 mJy
# 	Warning: average amplitude (3.008 mJy) is less than 5 sigma (0.684 mJy). This indicates significant variability in the amplitudes across periods.
# Target:  17
# Offsets for object 17 (g-band: True):
# {'i_vs_l': np.float64(nan), 'i_vs_p': np.float64(nan), 'i_vs_m': np.float64(nan), 'i_vs_E': np.float64(nan), 'i_vs_H': np.float64(nan), 'l_vs_i': np.float64(nan), 'l_vs_p': nan, 'l_vs_m': nan, 'l_vs_E': nan, 'l_vs_H': nan, 'p_vs_i': np.float64(nan), 'p_vs_l': nan, 'p_vs_m': nan, 'p_vs_E': nan, 'p_vs_H': nan, 'm_vs_i': np.float64(nan), 'm_vs_l': nan, 'm_vs_p': nan, 'm_vs_E': nan, 'm_vs_H': nan, 'E_vs_i': np.float64(nan), 'E_vs_l': nan, 'E_vs_p': nan, 'E_vs_m': nan, 'E_vs_H': nan, 'H_vs_i': np.float64(nan), 'H_vs_l': nan, 'H_vs_p': nan, 'H_vs_m': nan, 'H_vs_E': nan}
# Amplitude metrics:
# 	Lower 5% percentile: 5.50 mJy, 13.52 mags
# 	Upper 5% percentile: 14.13 mJy, 14.55 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 8.63 mJy, 1.02 mags
# Amplitude metrics:
# 	Lower 1% percentile: 5.31 mJy, 13.47 mags
# 	Upper 1% percentile: 14.82 mJy, 14.59 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 9.51 mJy, 1.11 mags
# 	Largest amplitude of variability (g-band: True): 9.93 mJy, 1.17 mags
# 	Average amplitude across all periods: 6.502 mJy
# 	Standard deviation of amplitudes: 2.260 mJy
# 	Warning: average amplitude (6.502 mJy) is less than 5 sigma (2.260 mJy). This indicates significant variability in the amplitudes across periods.
# Target:  18
# Offsets for object 18 (g-band: True):
# {'l_vs_p': np.float64(nan), 'l_vs_H': np.float64(nan), 'p_vs_l': np.float64(nan), 'p_vs_H': nan, 'H_vs_l': np.float64(nan), 'H_vs_p': nan}
# Amplitude metrics:
# 	Lower 5% percentile: 5.11 mJy, 14.52 mags
# 	Upper 5% percentile: 5.66 mJy, 14.63 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.55 mJy, 0.11 mags
# Amplitude metrics:
# 	Lower 1% percentile: 4.92 mJy, 14.50 mags
# 	Upper 1% percentile: 5.77 mJy, 14.67 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.85 mJy, 0.17 mags
# 	Largest amplitude of variability (g-band: True): 1.25 mJy, 0.25 mags
# 	Average amplitude across all periods: 0.880 mJy
# 	Standard deviation of amplitudes: 0.204 mJy
# 	Warning: average amplitude (0.880 mJy) is less than 5 sigma (0.204 mJy). This indicates significant variability in the amplitudes across periods.
# Target:  19
# Offsets for object 19 (g-band: True):
# {'l_vs_p': np.float64(nan), 'l_vs_H': np.float64(nan), 'p_vs_l': np.float64(nan), 'p_vs_H': nan, 'H_vs_l': np.float64(nan), 'H_vs_p': nan}
# Amplitude metrics:
# 	Lower 5% percentile: 5.50 mJy, 13.68 mags
# 	Upper 5% percentile: 12.29 mJy, 14.55 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 6.79 mJy, 0.87 mags
# Amplitude metrics:
# 	Lower 1% percentile: 5.31 mJy, 13.64 mags
# 	Upper 1% percentile: 12.72 mJy, 14.59 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 7.41 mJy, 0.95 mags
# 	Largest amplitude of variability (g-band: True): 7.78 mJy, 0.98 mags
# 	Average amplitude across all periods: 5.898 mJy
# 	Standard deviation of amplitudes: 1.413 mJy
# 	Warning: average amplitude (5.898 mJy) is less than 5 sigma (1.413 mJy). This indicates significant variability in the amplitudes across periods.
# Target:  20
# Offsets for object 20 (g-band: True):
# {'l_vs_p': np.float64(nan), 'l_vs_H': np.float64(nan), 'p_vs_l': np.float64(nan), 'p_vs_H': nan, 'H_vs_l': np.float64(nan), 'H_vs_p': nan}
# Amplitude metrics:
# 	Lower 5% percentile: 3.86 mJy, 14.82 mags
# 	Upper 5% percentile: 4.28 mJy, 14.93 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.42 mJy, 0.11 mags
# Amplitude metrics:
# 	Lower 1% percentile: 3.69 mJy, 14.79 mags
# 	Upper 1% percentile: 4.39 mJy, 14.98 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.69 mJy, 0.19 mags
# 	Largest amplitude of variability (g-band: True): 0.86 mJy, 0.23 mags
# 	Average amplitude across all periods: 0.679 mJy
# 	Standard deviation of amplitudes: 0.072 mJy
# 	Average amplitude (0.679 mJy) is greater than 5 sigma (0.072 mJy). This indicates consistent variability across periods.
# Target:  21
# Offsets for object 21 (g-band: True):
# {'l_vs_p': np.float64(nan), 'l_vs_H': np.float64(nan), 'p_vs_l': np.float64(nan), 'p_vs_H': nan, 'H_vs_l': np.float64(nan), 'H_vs_p': nan}
# Amplitude metrics:
# 	Lower 5% percentile: 4.07 mJy, 14.76 mags
# 	Upper 5% percentile: 4.55 mJy, 14.88 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.47 mJy, 0.12 mags
# Amplitude metrics:
# 	Lower 1% percentile: 3.96 mJy, 14.72 mags
# 	Upper 1% percentile: 4.68 mJy, 14.91 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.72 mJy, 0.18 mags
# 	Largest amplitude of variability (g-band: True): 1.02 mJy, 0.26 mags
# 	Average amplitude across all periods: 0.787 mJy
# 	Standard deviation of amplitudes: 0.132 mJy
# 	Average amplitude (0.787 mJy) is greater than 5 sigma (0.132 mJy). This indicates consistent variability across periods.
# Target:  22
# Offsets for object 22 (g-band: True):
# {'l_vs_p': np.float64(nan), 'l_vs_H': np.float64(nan), 'p_vs_l': np.float64(nan), 'p_vs_H': nan, 'H_vs_l': np.float64(nan), 'H_vs_p': nan}
# Amplitude metrics:
# 	Lower 5% percentile: 14.18 mJy, 13.47 mags
# 	Upper 5% percentile: 14.86 mJy, 13.52 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.68 mJy, 0.05 mags
# Amplitude metrics:
# 	Lower 1% percentile: 14.05 mJy, 13.45 mags
# 	Upper 1% percentile: 15.10 mJy, 13.53 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 1.05 mJy, 0.08 mags
# 	Largest amplitude of variability (g-band: True): 1.44 mJy, 0.11 mags
# 	Average amplitude across all periods: 0.034 mJy
# 	Standard deviation of amplitudes: 0.104 mJy
# 	Warning: average amplitude (0.034 mJy) is less than 5 sigma (0.104 mJy). This indicates significant variability in the amplitudes across periods.
# Target:  23
# Offsets for object 23 (g-band: True):
# {'l_vs_p': np.float64(nan), 'l_vs_H': np.float64(nan), 'p_vs_l': np.float64(nan), 'p_vs_H': nan, 'H_vs_l': np.float64(nan), 'H_vs_p': nan}
# Amplitude metrics:
# 	Lower 5% percentile: 10.12 mJy, 13.84 mags
# 	Upper 5% percentile: 10.61 mJy, 13.89 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.48 mJy, 0.05 mags
# Amplitude metrics:
# 	Lower 1% percentile: 9.93 mJy, 13.82 mags
# 	Upper 1% percentile: 10.80 mJy, 13.91 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.87 mJy, 0.09 mags
# 	Largest amplitude of variability (g-band: True): 1.10 mJy, 0.12 mags
# 	Average amplitude across all periods: 0.012 mJy
# 	Standard deviation of amplitudes: 0.058 mJy
# 	Warning: average amplitude (0.012 mJy) is less than 5 sigma (0.058 mJy). This indicates significant variability in the amplitudes across periods.
# Target:  24
# Offsets for object 24 (g-band: True):
# {'l_vs_p': np.float64(nan), 'l_vs_H': np.float64(nan), 'p_vs_l': np.float64(nan), 'p_vs_H': nan, 'H_vs_l': np.float64(nan), 'H_vs_p': nan}
# Amplitude metrics:
# 	Lower 5% percentile: 4.61 mJy, 13.55 mags
# 	Upper 5% percentile: 13.76 mJy, 14.74 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 9.15 mJy, 1.19 mags
# Amplitude metrics:
# 	Lower 1% percentile: 4.31 mJy, 13.51 mags
# 	Upper 1% percentile: 14.28 mJy, 14.81 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 9.97 mJy, 1.30 mags
# 	Largest amplitude of variability (g-band: True): 11.17 mJy, 1.55 mags
# 	Average amplitude across all periods: 7.706 mJy
# 	Standard deviation of amplitudes: 2.043 mJy
# 	Warning: average amplitude (7.706 mJy) is less than 5 sigma (2.043 mJy). This indicates significant variability in the amplitudes across periods.
# Target:  25
# Offsets for object 25 (g-band: True):
# {'l_vs_p': np.float64(nan), 'l_vs_H': np.float64(nan), 'p_vs_l': np.float64(nan), 'p_vs_H': nan, 'H_vs_l': np.float64(nan), 'H_vs_p': nan}
# Amplitude metrics:
# 	Lower 5% percentile: 5.35 mJy, 14.47 mags
# 	Upper 5% percentile: 5.92 mJy, 14.58 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.56 mJy, 0.11 mags
# Amplitude metrics:
# 	Lower 1% percentile: 5.24 mJy, 14.45 mags
# 	Upper 1% percentile: 6.04 mJy, 14.60 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.79 mJy, 0.15 mags
# 	Largest amplitude of variability (g-band: True): 1.17 mJy, 0.23 mags
# 	Average amplitude across all periods: 0.870 mJy
# 	Standard deviation of amplitudes: 0.101 mJy
# 	Average amplitude (0.870 mJy) is greater than 5 sigma (0.101 mJy). This indicates consistent variability across periods.
# Target:  26
# Offsets for object 26 (g-band: True):
# {'l_vs_p': np.float64(nan), 'l_vs_H': np.float64(nan), 'p_vs_l': np.float64(nan), 'p_vs_H': nan, 'H_vs_l': np.float64(nan), 'H_vs_p': nan}
# Amplitude metrics:
# 	Lower 5% percentile: 4.90 mJy, 14.58 mags
# 	Upper 5% percentile: 5.37 mJy, 14.68 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.47 mJy, 0.10 mags
# Amplitude metrics:
# 	Lower 1% percentile: 4.81 mJy, 14.54 mags
# 	Upper 1% percentile: 5.55 mJy, 14.70 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.74 mJy, 0.16 mags
# 	Largest amplitude of variability (g-band: True): 0.95 mJy, 0.20 mags
# 	Average amplitude across all periods: 0.842 mJy
# 	Standard deviation of amplitudes: 0.070 mJy
# 	Average amplitude (0.842 mJy) is greater than 5 sigma (0.070 mJy). This indicates consistent variability across periods.
# Target:  27
# Offsets for object 27 (g-band: True):
# {'l_vs_p': np.float64(nan), 'l_vs_H': np.float64(nan), 'p_vs_l': np.float64(nan), 'p_vs_H': nan, 'H_vs_l': np.float64(nan), 'H_vs_p': nan}
# Amplitude metrics:
# 	Lower 5% percentile: 4.06 mJy, 14.76 mags
# 	Upper 5% percentile: 4.52 mJy, 14.88 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.46 mJy, 0.12 mags
# Amplitude metrics:
# 	Lower 1% percentile: 3.97 mJy, 14.73 mags
# 	Upper 1% percentile: 4.67 mJy, 14.90 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.70 mJy, 0.18 mags
# 	Largest amplitude of variability (g-band: True): 1.03 mJy, 0.26 mags
# 	Average amplitude across all periods: 0.008 mJy
# 	Standard deviation of amplitudes: 0.041 mJy
# 	Warning: average amplitude (0.008 mJy) is less than 5 sigma (0.041 mJy). This indicates significant variability in the amplitudes across periods.
# Target:  28
# Offsets for object 28 (g-band: True):
# {'l_vs_p': np.float64(nan), 'l_vs_H': np.float64(nan), 'p_vs_l': np.float64(nan), 'p_vs_H': nan, 'H_vs_l': np.float64(nan), 'H_vs_p': nan}
# Amplitude metrics:
# 	Lower 5% percentile: 3.15 mJy, 14.97 mags
# 	Upper 5% percentile: 3.72 mJy, 15.15 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.56 mJy, 0.18 mags
# Amplitude metrics:
# 	Lower 1% percentile: 2.98 mJy, 14.93 mags
# 	Upper 1% percentile: 3.87 mJy, 15.22 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.89 mJy, 0.28 mags
# 	Largest amplitude of variability (g-band: True): 1.18 mJy, 0.38 mags
# 	Average amplitude across all periods: 0.822 mJy
# 	Standard deviation of amplitudes: 0.086 mJy
# 	Average amplitude (0.822 mJy) is greater than 5 sigma (0.086 mJy). This indicates consistent variability across periods.
# Target:  29
# Offsets for object 29 (g-band: True):
# {'l_vs_p': np.float64(nan), 'l_vs_H': np.float64(nan), 'p_vs_l': np.float64(nan), 'p_vs_H': nan, 'H_vs_l': np.float64(nan), 'H_vs_p': nan}
# Amplitude metrics:
# 	Lower 5% percentile: 4.73 mJy, 14.61 mags
# 	Upper 5% percentile: 5.18 mJy, 14.71 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.46 mJy, 0.10 mags
# Amplitude metrics:
# 	Lower 1% percentile: 4.62 mJy, 14.58 mags
# 	Upper 1% percentile: 5.35 mJy, 14.74 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.73 mJy, 0.16 mags
# 	Largest amplitude of variability (g-band: True): 0.93 mJy, 0.21 mags
# 	Average amplitude across all periods: 0.860 mJy
# 	Standard deviation of amplitudes: 0.070 mJy
# 	Average amplitude (0.860 mJy) is greater than 5 sigma (0.070 mJy). This indicates consistent variability across periods.
# Target:  30
# Offsets for object 30 (g-band: True):
# {'l_vs_p': np.float64(nan), 'l_vs_H': np.float64(nan), 'p_vs_l': np.float64(nan), 'p_vs_H': nan, 'H_vs_l': np.float64(nan), 'H_vs_p': nan}
# Amplitude metrics:
# 	Lower 5% percentile: 6.64 mJy, 14.26 mags
# 	Upper 5% percentile: 7.18 mJy, 14.34 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.54 mJy, 0.08 mags
# Amplitude metrics:
# 	Lower 1% percentile: 6.47 mJy, 14.24 mags
# 	Upper 1% percentile: 7.32 mJy, 14.37 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.85 mJy, 0.13 mags
# 	Largest amplitude of variability (g-band: True): 1.23 mJy, 0.19 mags
# 	Average amplitude across all periods: 0.738 mJy
# 	Standard deviation of amplitudes: 0.166 mJy
# 	Warning: average amplitude (0.738 mJy) is less than 5 sigma (0.166 mJy). This indicates significant variability in the amplitudes across periods.
# Target:  31
# Offsets for object 31 (g-band: True):
# {'l_vs_p': np.float64(nan), 'l_vs_H': np.float64(nan), 'p_vs_l': np.float64(nan), 'p_vs_H': nan, 'H_vs_l': np.float64(nan), 'H_vs_p': nan}
# Amplitude metrics:
# 	Lower 5% percentile: 22.34 mJy, 12.98 mags
# 	Upper 5% percentile: 23.44 mJy, 13.03 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 1.11 mJy, 0.05 mags
# Amplitude metrics:
# 	Lower 1% percentile: 22.07 mJy, 12.96 mags
# 	Upper 1% percentile: 23.69 mJy, 13.04 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 1.62 mJy, 0.08 mags
# 	Largest amplitude of variability (g-band: True): 1.82 mJy, 0.09 mags
# 	Average amplitude across all periods: 1.424 mJy
# 	Standard deviation of amplitudes: 0.211 mJy
# 	Average amplitude (1.424 mJy) is greater than 5 sigma (0.211 mJy). This indicates consistent variability across periods.
# Target:  32
# Target 32 failed: index 0 is out of bounds for axis 0 with size 0
# Target:  33
# Offsets for object 33 (g-band: True):
# {'l_vs_p': np.float64(nan), 'l_vs_H': np.float64(nan), 'p_vs_l': np.float64(nan), 'p_vs_H': nan, 'H_vs_l': np.float64(nan), 'H_vs_p': nan}
# Amplitude metrics:
# 	Lower 5% percentile: 15.81 mJy, 13.35 mags
# 	Upper 5% percentile: 16.60 mJy, 13.40 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.79 mJy, 0.05 mags
# Amplitude metrics:
# 	Lower 1% percentile: 15.60 mJy, 13.34 mags
# 	Upper 1% percentile: 16.83 mJy, 13.42 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 1.23 mJy, 0.08 mags
# 	Largest amplitude of variability (g-band: True): 1.50 mJy, 0.10 mags
# 	Average amplitude across all periods: 1.035 mJy
# 	Standard deviation of amplitudes: 0.146 mJy
# 	Average amplitude (1.035 mJy) is greater than 5 sigma (0.146 mJy). This indicates consistent variability across periods.
# Target:  34
# Offsets for object 34 (g-band: True):
# {'l_vs_p': np.float64(nan), 'l_vs_H': np.float64(nan), 'p_vs_l': np.float64(nan), 'p_vs_H': nan, 'H_vs_l': np.float64(nan), 'H_vs_p': nan}
# Amplitude metrics:
# 	Lower 5% percentile: 13.36 mJy, 13.53 mags
# 	Upper 5% percentile: 14.09 mJy, 13.59 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.74 mJy, 0.06 mags
# Amplitude metrics:
# 	Lower 1% percentile: 13.21 mJy, 13.51 mags
# 	Upper 1% percentile: 14.31 mJy, 13.60 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 1.10 mJy, 0.09 mags
# 	Largest amplitude of variability (g-band: True): 1.58 mJy, 0.12 mags
# 	Average amplitude across all periods: 0.844 mJy
# 	Standard deviation of amplitudes: 0.217 mJy
# 	Warning: average amplitude (0.844 mJy) is less than 5 sigma (0.217 mJy). This indicates significant variability in the amplitudes across periods.
# Target:  35
# Offsets for object 35 (g-band: True):
# {'l_vs_p': np.float64(nan), 'l_vs_H': np.float64(nan), 'p_vs_l': np.float64(nan), 'p_vs_H': nan, 'H_vs_l': np.float64(nan), 'H_vs_p': nan}
# Amplitude metrics:
# 	Lower 5% percentile: 3.41 mJy, 14.96 mags
# 	Upper 5% percentile: 3.78 mJy, 15.07 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.37 mJy, 0.11 mags
# Amplitude metrics:
# 	Lower 1% percentile: 3.32 mJy, 14.92 mags
# 	Upper 1% percentile: 3.90 mJy, 15.10 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.59 mJy, 0.18 mags
# 	Largest amplitude of variability (g-band: True): 0.82 mJy, 0.25 mags
# 	Average amplitude across all periods: 0.584 mJy
# 	Standard deviation of amplitudes: 0.114 mJy
# 	Average amplitude (0.584 mJy) is greater than 5 sigma (0.114 mJy). This indicates consistent variability across periods.
# Target:  36
# Offsets for object 36 (g-band: True):
# {'l_vs_p': np.float64(nan), 'l_vs_H': np.float64(nan), 'p_vs_l': np.float64(nan), 'p_vs_H': nan, 'H_vs_l': np.float64(nan), 'H_vs_p': nan}
# Amplitude metrics:
# 	Lower 5% percentile: 17.31 mJy, 12.28 mags
# 	Upper 5% percentile: 44.54 mJy, 13.30 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 27.24 mJy, 1.03 mags
# Amplitude metrics:
# 	Lower 1% percentile: 16.39 mJy, 12.25 mags
# 	Upper 1% percentile: 45.85 mJy, 13.36 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 29.46 mJy, 1.12 mags
# 	Largest amplitude of variability (g-band: True): 31.23 mJy, 1.18 mags
# 	Average amplitude across all periods: 27.071 mJy
# 	Standard deviation of amplitudes: 2.339 mJy
# 	Average amplitude (27.071 mJy) is greater than 5 sigma (2.339 mJy). This indicates consistent variability across periods.
# Target:  37
# Offsets for object 37 (g-band: True):
# {'l_vs_p': np.float64(nan), 'l_vs_H': np.float64(nan), 'p_vs_l': np.float64(nan), 'p_vs_H': nan, 'H_vs_l': np.float64(nan), 'H_vs_p': nan}
# Amplitude metrics:
# 	Lower 5% percentile: 18.25 mJy, 13.20 mags
# 	Upper 5% percentile: 19.13 mJy, 13.25 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.88 mJy, 0.05 mags
# Amplitude metrics:
# 	Lower 1% percentile: 17.98 mJy, 13.18 mags
# 	Upper 1% percentile: 19.39 mJy, 13.26 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 1.41 mJy, 0.08 mags
# 	Largest amplitude of variability (g-band: True): 2.09 mJy, 0.12 mags
# 	Average amplitude across all periods: 1.380 mJy
# 	Standard deviation of amplitudes: 0.302 mJy
# 	Warning: average amplitude (1.380 mJy) is less than 5 sigma (0.302 mJy). This indicates significant variability in the amplitudes across periods.
# Target:  38
# Offsets for object 38 (g-band: True):
# {'l_vs_p': np.float64(nan), 'l_vs_H': np.float64(nan), 'p_vs_l': np.float64(nan), 'p_vs_H': nan, 'H_vs_l': np.float64(nan), 'H_vs_p': nan}
# Amplitude metrics:
# 	Lower 5% percentile: 16.25 mJy, 13.32 mags
# 	Upper 5% percentile: 17.05 mJy, 13.37 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.80 mJy, 0.05 mags
# Amplitude metrics:
# 	Lower 1% percentile: 16.07 mJy, 13.31 mags
# 	Upper 1% percentile: 17.14 mJy, 13.38 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 1.07 mJy, 0.07 mags
# 	Largest amplitude of variability (g-band: True): 1.64 mJy, 0.11 mags
# 	Average amplitude across all periods: 0.862 mJy
# 	Standard deviation of amplitudes: 0.220 mJy
# 	Warning: average amplitude (0.862 mJy) is less than 5 sigma (0.220 mJy). This indicates significant variability in the amplitudes across periods.
# Target:  39
# Offsets for object 39 (g-band: True):
# {'l_vs_p': np.float64(nan), 'l_vs_H': np.float64(nan), 'p_vs_l': np.float64(nan), 'p_vs_H': nan, 'H_vs_l': np.float64(nan), 'H_vs_p': nan}
# Amplitude metrics:
# 	Lower 5% percentile: 8.35 mJy, 14.02 mags
# 	Upper 5% percentile: 8.94 mJy, 14.10 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.59 mJy, 0.07 mags
# Amplitude metrics:
# 	Lower 1% percentile: 8.20 mJy, 14.00 mags
# 	Upper 1% percentile: 9.09 mJy, 14.12 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.89 mJy, 0.11 mags
# 	Largest amplitude of variability (g-band: True): 1.27 mJy, 0.16 mags
# 	Average amplitude across all periods: 0.867 mJy
# 	Standard deviation of amplitudes: 0.148 mJy
# 	Average amplitude (0.867 mJy) is greater than 5 sigma (0.148 mJy). This indicates consistent variability across periods.
# Target:  40
# Offsets for object 40 (g-band: True):
# {'l_vs_p': np.float64(nan), 'l_vs_H': np.float64(nan), 'p_vs_l': np.float64(nan), 'p_vs_H': nan, 'H_vs_l': np.float64(nan), 'H_vs_p': nan}
# Amplitude metrics:
# 	Lower 5% percentile: 14.57 mJy, 13.42 mags
# 	Upper 5% percentile: 15.57 mJy, 13.49 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 1.00 mJy, 0.07 mags
# Amplitude metrics:
# 	Lower 1% percentile: 14.41 mJy, 13.41 mags
# 	Upper 1% percentile: 15.70 mJy, 13.50 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 1.29 mJy, 0.09 mags
# 	Largest amplitude of variability (g-band: True): 1.65 mJy, 0.12 mags
# 	Average amplitude across all periods: 1.213 mJy
# 	Standard deviation of amplitudes: 0.179 mJy
# 	Average amplitude (1.213 mJy) is greater than 5 sigma (0.179 mJy). This indicates consistent variability across periods.
# Target:  41
# Offsets for object 41 (g-band: True):
# {'l_vs_p': np.float64(nan), 'l_vs_H': np.float64(nan), 'p_vs_l': np.float64(nan), 'p_vs_H': nan, 'H_vs_l': np.float64(nan), 'H_vs_p': nan}
# Amplitude metrics:
# 	Lower 5% percentile: 3.22 mJy, 14.09 mags
# 	Upper 5% percentile: 8.43 mJy, 15.13 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 5.21 mJy, 1.04 mags
# Amplitude metrics:
# 	Lower 1% percentile: 3.11 mJy, 14.04 mags
# 	Upper 1% percentile: 8.75 mJy, 15.17 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 5.64 mJy, 1.12 mags
# 	Largest amplitude of variability (g-band: True): 6.43 mJy, 1.35 mags
# 	Average amplitude across all periods: 4.413 mJy
# 	Standard deviation of amplitudes: 1.166 mJy
# 	Warning: average amplitude (4.413 mJy) is less than 5 sigma (1.166 mJy). This indicates significant variability in the amplitudes across periods.
# Target:  42
# Offsets for object 42 (g-band: True):
# {'l_vs_p': np.float64(nan), 'l_vs_H': np.float64(nan), 'p_vs_l': np.float64(nan), 'p_vs_H': nan, 'H_vs_l': np.float64(nan), 'H_vs_p': nan}
# Amplitude metrics:
# 	Lower 5% percentile: 2.00 mJy, 15.41 mags
# 	Upper 5% percentile: 2.49 mJy, 15.64 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.48 mJy, 0.23 mags
# Amplitude metrics:
# 	Lower 1% percentile: 1.89 mJy, 15.36 mags
# 	Upper 1% percentile: 2.62 mJy, 15.71 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.72 mJy, 0.35 mags
# 	Largest amplitude of variability (g-band: True): 0.94 mJy, 0.45 mags
# 	Average amplitude across all periods: 0.670 mJy
# 	Standard deviation of amplitudes: 0.092 mJy
# 	Average amplitude (0.670 mJy) is greater than 5 sigma (0.092 mJy). This indicates consistent variability across periods.
# Target:  43
# Offsets for object 43 (g-band: True):
# {'l_vs_p': np.float64(nan), 'l_vs_H': np.float64(nan), 'p_vs_l': np.float64(nan), 'p_vs_H': nan, 'H_vs_l': np.float64(nan), 'H_vs_p': nan}
# Amplitude metrics:
# 	Lower 5% percentile: 11.68 mJy, 13.67 mags
# 	Upper 5% percentile: 12.40 mJy, 13.73 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.71 mJy, 0.06 mags
# Amplitude metrics:
# 	Lower 1% percentile: 11.58 mJy, 13.65 mags
# 	Upper 1% percentile: 12.57 mJy, 13.74 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.99 mJy, 0.09 mags
# 	Largest amplitude of variability (g-band: True): 1.27 mJy, 0.11 mags
# 	Average amplitude across all periods: 0.595 mJy
# 	Standard deviation of amplitudes: 0.177 mJy
# 	Warning: average amplitude (0.595 mJy) is less than 5 sigma (0.177 mJy). This indicates significant variability in the amplitudes across periods.
# Target:  44
# Offsets for object 44 (g-band: True):
# {'l_vs_p': np.float64(nan), 'l_vs_H': np.float64(nan), 'p_vs_l': np.float64(nan), 'p_vs_H': nan, 'H_vs_l': np.float64(nan), 'H_vs_p': nan}
# Amplitude metrics:
# 	Lower 5% percentile: 13.91 mJy, 13.48 mags
# 	Upper 5% percentile: 14.68 mJy, 13.54 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.77 mJy, 0.06 mags
# Amplitude metrics:
# 	Lower 1% percentile: 13.77 mJy, 13.47 mags
# 	Upper 1% percentile: 14.89 mJy, 13.55 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 1.12 mJy, 0.08 mags
# 	Largest amplitude of variability (g-band: True): 1.51 mJy, 0.11 mags
# 	Average amplitude across all periods: 0.093 mJy
# 	Standard deviation of amplitudes: 0.174 mJy
# 	Warning: average amplitude (0.093 mJy) is less than 5 sigma (0.174 mJy). This indicates significant variability in the amplitudes across periods.
# Target:  45
# Offsets for object 45 (g-band: True):
# {'k_vs_l': np.float64(nan), 'k_vs_p': np.float64(nan), 'k_vs_H': np.float64(nan), 'l_vs_k': np.float64(nan), 'l_vs_p': nan, 'l_vs_H': nan, 'p_vs_k': np.float64(nan), 'p_vs_l': nan, 'p_vs_H': nan, 'H_vs_k': np.float64(nan), 'H_vs_l': nan, 'H_vs_p': nan}
# Amplitude metrics:
# 	Lower 5% percentile: 10.02 mJy, 13.82 mags
# 	Upper 5% percentile: 10.72 mJy, 13.90 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.69 mJy, 0.07 mags
# Amplitude metrics:
# 	Lower 1% percentile: 9.82 mJy, 13.81 mags
# 	Upper 1% percentile: 10.82 mJy, 13.92 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 1.00 mJy, 0.11 mags
# 	Largest amplitude of variability (g-band: True): 1.24 mJy, 0.13 mags
# 	Average amplitude across all periods: 0.269 mJy
# 	Standard deviation of amplitudes: 0.162 mJy
# 	Warning: average amplitude (0.269 mJy) is less than 5 sigma (0.162 mJy). This indicates significant variability in the amplitudes across periods.
# Target:  46
# Offsets for object 46 (g-band: True):
# {'l_vs_p': np.float64(nan), 'l_vs_H': np.float64(nan), 'p_vs_l': np.float64(nan), 'p_vs_H': nan, 'H_vs_l': np.float64(nan), 'H_vs_p': nan}
# Amplitude metrics:
# 	Lower 5% percentile: 6.76 mJy, 14.24 mags
# 	Upper 5% percentile: 7.31 mJy, 14.33 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.56 mJy, 0.09 mags
# Amplitude metrics:
# 	Lower 1% percentile: 6.60 mJy, 14.22 mags
# 	Upper 1% percentile: 7.42 mJy, 14.35 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.83 mJy, 0.13 mags
# 	Largest amplitude of variability (g-band: True): 1.09 mJy, 0.17 mags
# 	Average amplitude across all periods: 0.708 mJy
# 	Standard deviation of amplitudes: 0.119 mJy
# 	Average amplitude (0.708 mJy) is greater than 5 sigma (0.119 mJy). This indicates consistent variability across periods.
# Target:  47
# Offsets for object 47 (g-band: True):
# {'l_vs_p': np.float64(nan), 'l_vs_H': np.float64(nan), 'p_vs_l': np.float64(nan), 'p_vs_H': nan, 'H_vs_l': np.float64(nan), 'H_vs_p': nan}
# Amplitude metrics:
# 	Lower 5% percentile: 5.01 mJy, 14.56 mags
# 	Upper 5% percentile: 5.46 mJy, 14.65 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.45 mJy, 0.09 mags
# Amplitude metrics:
# 	Lower 1% percentile: 4.84 mJy, 14.54 mags
# 	Upper 1% percentile: 5.53 mJy, 14.69 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.69 mJy, 0.14 mags
# 	Largest amplitude of variability (g-band: True): 0.89 mJy, 0.19 mags
# 	Average amplitude across all periods: 0.022 mJy
# 	Standard deviation of amplitudes: 0.065 mJy
# 	Warning: average amplitude (0.022 mJy) is less than 5 sigma (0.065 mJy). This indicates significant variability in the amplitudes across periods.
# Target:  48
# Offsets for object 48 (g-band: True):
# {'k_vs_l': np.float64(nan), 'k_vs_p': np.float64(nan), 'k_vs_H': np.float64(nan), 'l_vs_k': np.float64(nan), 'l_vs_p': nan, 'l_vs_H': nan, 'p_vs_k': np.float64(nan), 'p_vs_l': nan, 'p_vs_H': nan, 'H_vs_k': np.float64(nan), 'H_vs_l': nan, 'H_vs_p': nan}
# Amplitude metrics:
# 	Lower 5% percentile: 37.40 mJy, 12.41 mags
# 	Upper 5% percentile: 39.36 mJy, 12.47 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 1.96 mJy, 0.06 mags
# Amplitude metrics:
# 	Lower 1% percentile: 36.99 mJy, 12.40 mags
# 	Upper 1% percentile: 39.77 mJy, 12.48 mags
# ...
# Amplitude metrics:
# 	Lower 1% percentile: 3.11 mJy, 14.92 mags
# 	Upper 1% percentile: 3.89 mJy, 15.17 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.78 mJy, 0.24 mags
# 	Largest amplitude of variability (g-band: True): 0.95 mJy, 0.30 mags
# 	Average amplitude across all periods: 0.773 mJy
# 	Standard deviation of amplitudes: 0.101 mJy
# 	Average amplitude (0.773 mJy) is greater than 5 sigma (0.101 mJy). This indicates consistent variability across periods.
# Target:  833
# Offsets for object 833 (g-band: True):
# {'k_vs_o': np.float64(nan), 'k_vs_n': np.float64(nan), 'o_vs_k': np.float64(nan), 'o_vs_n': nan, 'n_vs_k': np.float64(nan), 'n_vs_o': nan}
# Amplitude metrics:
# 	Lower 5% percentile: 4.48 mJy, 14.66 mags
# 	Upper 5% percentile: 4.98 mJy, 14.77 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.49 mJy, 0.11 mags
# Amplitude metrics:
# 	Lower 1% percentile: 4.34 mJy, 14.64 mags
# 	Upper 1% percentile: 5.08 mJy, 14.81 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.74 mJy, 0.17 mags
# 	Largest amplitude of variability (g-band: True): 1.00 mJy, 0.23 mags
# 	Average amplitude across all periods: 0.745 mJy
# 	Standard deviation of amplitudes: 0.087 mJy
# 	Average amplitude (0.745 mJy) is greater than 5 sigma (0.087 mJy). This indicates consistent variability across periods.
# Target:  834
# Offsets for object 834 (g-band: True):
# {'i_vs_j': np.float64(nan), 'i_vs_n': np.float64(nan), 'i_vs_m': np.float64(nan), 'i_vs_E': np.float64(nan), 'j_vs_i': np.float64(nan), 'j_vs_n': nan, 'j_vs_m': nan, 'j_vs_E': nan, 'n_vs_i': np.float64(nan), 'n_vs_j': nan, 'n_vs_m': nan, 'n_vs_E': nan, 'm_vs_i': np.float64(nan), 'm_vs_j': nan, 'm_vs_n': nan, 'm_vs_E': nan, 'E_vs_i': np.float64(nan), 'E_vs_j': nan, 'E_vs_n': nan, 'E_vs_m': nan}
# Amplitude metrics:
# 	Lower 5% percentile: 17.58 mJy, 13.17 mags
# 	Upper 5% percentile: 19.55 mJy, 13.29 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 1.97 mJy, 0.12 mags
# Amplitude metrics:
# 	Lower 1% percentile: 17.20 mJy, 13.15 mags
# 	Upper 1% percentile: 19.88 mJy, 13.31 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 2.68 mJy, 0.16 mags
# 	Largest amplitude of variability (g-band: True): 3.82 mJy, 0.23 mags
# 	Average amplitude across all periods: 2.058 mJy
# 	Standard deviation of amplitudes: 0.486 mJy
# 	Warning: average amplitude (2.058 mJy) is less than 5 sigma (0.486 mJy). This indicates significant variability in the amplitudes across periods.
# Target:  835
# Offsets for object 835 (g-band: True):
# {'i_vs_j': np.float64(nan), 'i_vs_n': np.float64(nan), 'i_vs_m': np.float64(nan), 'i_vs_E': np.float64(nan), 'j_vs_i': np.float64(nan), 'j_vs_n': nan, 'j_vs_m': nan, 'j_vs_E': nan, 'n_vs_i': np.float64(nan), 'n_vs_j': nan, 'n_vs_m': nan, 'n_vs_E': nan, 'm_vs_i': np.float64(nan), 'm_vs_j': nan, 'm_vs_n': nan, 'm_vs_E': nan, 'E_vs_i': np.float64(nan), 'E_vs_j': nan, 'E_vs_n': nan, 'E_vs_m': nan}
# Amplitude metrics:
# 	Lower 5% percentile: 57.87 mJy, 11.92 mags
# 	Upper 5% percentile: 61.91 mJy, 11.99 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 4.04 mJy, 0.07 mags
# Amplitude metrics:
# 	Lower 1% percentile: 56.53 mJy, 11.90 mags
# 	Upper 1% percentile: 63.29 mJy, 12.02 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 6.76 mJy, 0.12 mags
# 	Largest amplitude of variability (g-band: True): 9.37 mJy, 0.17 mags
# 	Average amplitude across all periods: 4.408 mJy
# 	Standard deviation of amplitudes: 1.233 mJy
# 	Warning: average amplitude (4.408 mJy) is less than 5 sigma (1.233 mJy). This indicates significant variability in the amplitudes across periods.
# Target:  836
# Offsets for object 836 (g-band: True):
# {'k_vs_i': np.float64(nan), 'k_vs_j': np.float64(nan), 'k_vs_o': np.float64(nan), 'k_vs_n': np.float64(nan), 'k_vs_m': np.float64(nan), 'k_vs_E': np.float64(nan), 'i_vs_k': np.float64(nan), 'i_vs_j': nan, 'i_vs_o': nan, 'i_vs_n': nan, 'i_vs_m': nan, 'i_vs_E': nan, 'j_vs_k': np.float64(nan), 'j_vs_i': nan, 'j_vs_o': nan, 'j_vs_n': nan, 'j_vs_m': nan, 'j_vs_E': nan, 'o_vs_k': np.float64(nan), 'o_vs_i': nan, 'o_vs_j': nan, 'o_vs_n': nan, 'o_vs_m': nan, 'o_vs_E': nan, 'n_vs_k': np.float64(nan), 'n_vs_i': nan, 'n_vs_j': nan, 'n_vs_o': nan, 'n_vs_m': nan, 'n_vs_E': nan, 'm_vs_k': np.float64(nan), 'm_vs_i': nan, 'm_vs_j': nan, 'm_vs_o': nan, 'm_vs_n': nan, 'm_vs_E': nan, 'E_vs_k': np.float64(nan), 'E_vs_i': nan, 'E_vs_j': nan, 'E_vs_o': nan, 'E_vs_n': nan, 'E_vs_m': nan}
# Amplitude metrics:
# 	Lower 5% percentile: 18.68 mJy, 13.11 mags
# 	Upper 5% percentile: 20.79 mJy, 13.22 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 2.11 mJy, 0.12 mags
# Amplitude metrics:
# 	Lower 1% percentile: 18.28 mJy, 13.08 mags
# 	Upper 1% percentile: 21.38 mJy, 13.25 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 3.10 mJy, 0.17 mags
# 	Largest amplitude of variability (g-band: True): 3.78 mJy, 0.21 mags
# 	Average amplitude across all periods: 3.094 mJy
# 	Standard deviation of amplitudes: 0.345 mJy
# 	Average amplitude (3.094 mJy) is greater than 5 sigma (0.345 mJy). This indicates consistent variability across periods.
# Target:  837
# Offsets for object 837 (g-band: True):
# {'k_vs_o': np.float64(nan), 'k_vs_n': np.float64(nan), 'o_vs_k': np.float64(nan), 'o_vs_n': nan, 'n_vs_k': np.float64(nan), 'n_vs_o': nan}
# Amplitude metrics:
# 	Lower 5% percentile: 5.20 mJy, 14.50 mags
# 	Upper 5% percentile: 5.73 mJy, 14.61 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.53 mJy, 0.11 mags
# Amplitude metrics:
# 	Lower 1% percentile: 5.10 mJy, 14.48 mags
# 	Upper 1% percentile: 5.88 mJy, 14.63 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.78 mJy, 0.16 mags
# 	Largest amplitude of variability (g-band: True): 1.07 mJy, 0.21 mags
# 	Average amplitude across all periods: 0.779 mJy
# 	Standard deviation of amplitudes: 0.160 mJy
# 	Warning: average amplitude (0.779 mJy) is less than 5 sigma (0.160 mJy). This indicates significant variability in the amplitudes across periods.
# Target:  838
# Offsets for object 838 (g-band: True):
# {'k_vs_o': np.float64(nan), 'k_vs_n': np.float64(nan), 'o_vs_k': np.float64(nan), 'o_vs_n': nan, 'n_vs_k': np.float64(nan), 'n_vs_o': nan}
# Amplitude metrics:
# 	Lower 5% percentile: 5.55 mJy, 14.45 mags
# 	Upper 5% percentile: 6.06 mJy, 14.54 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.51 mJy, 0.09 mags
# Amplitude metrics:
# 	Lower 1% percentile: 5.42 mJy, 14.42 mags
# 	Upper 1% percentile: 6.22 mJy, 14.57 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.80 mJy, 0.15 mags
# 	Largest amplitude of variability (g-band: True): 1.14 mJy, 0.21 mags
# 	Average amplitude across all periods: 0.801 mJy
# 	Standard deviation of amplitudes: 0.200 mJy
# 	Warning: average amplitude (0.801 mJy) is less than 5 sigma (0.200 mJy). This indicates significant variability in the amplitudes across periods.
# Target:  839
# Offsets for object 839 (g-band: True):
# {'i_vs_j': np.float64(nan), 'i_vs_n': np.float64(nan), 'i_vs_m': np.float64(nan), 'i_vs_E': np.float64(nan), 'j_vs_i': np.float64(nan), 'j_vs_n': nan, 'j_vs_m': nan, 'j_vs_E': nan, 'n_vs_i': np.float64(nan), 'n_vs_j': nan, 'n_vs_m': nan, 'n_vs_E': nan, 'm_vs_i': np.float64(nan), 'm_vs_j': nan, 'm_vs_n': nan, 'm_vs_E': nan, 'E_vs_i': np.float64(nan), 'E_vs_j': nan, 'E_vs_n': nan, 'E_vs_m': nan}
# Amplitude metrics:
# 	Lower 5% percentile: 37.07 mJy, 12.44 mags
# 	Upper 5% percentile: 38.48 mJy, 12.48 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 1.41 mJy, 0.04 mags
# Amplitude metrics:
# 	Lower 1% percentile: 36.61 mJy, 12.43 mags
# 	Upper 1% percentile: 38.80 mJy, 12.49 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 2.19 mJy, 0.06 mags
# 	Largest amplitude of variability (g-band: True): 2.96 mJy, 0.09 mags
# 	Average amplitude across all periods: 0.769 mJy
# 	Standard deviation of amplitudes: 0.343 mJy
# 	Warning: average amplitude (0.769 mJy) is less than 5 sigma (0.343 mJy). This indicates significant variability in the amplitudes across periods.
# Target:  840
# Offsets for object 840 (g-band: True):
# {'i_vs_j': np.float64(nan), 'i_vs_n': np.float64(nan), 'i_vs_m': np.float64(nan), 'i_vs_E': np.float64(nan), 'j_vs_i': np.float64(nan), 'j_vs_n': nan, 'j_vs_m': nan, 'j_vs_E': nan, 'n_vs_i': np.float64(nan), 'n_vs_j': nan, 'n_vs_m': nan, 'n_vs_E': nan, 'm_vs_i': np.float64(nan), 'm_vs_j': nan, 'm_vs_n': nan, 'm_vs_E': nan, 'E_vs_i': np.float64(nan), 'E_vs_j': nan, 'E_vs_n': nan, 'E_vs_m': nan}
# Amplitude metrics:
# 	Lower 5% percentile: 6.70 mJy, 14.22 mags
# 	Upper 5% percentile: 7.47 mJy, 14.34 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.77 mJy, 0.12 mags
# Amplitude metrics:
# 	Lower 1% percentile: 6.55 mJy, 14.19 mags
# 	Upper 1% percentile: 7.66 mJy, 14.36 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 1.11 mJy, 0.17 mags
# 	Largest amplitude of variability (g-band: True): 1.72 mJy, 0.26 mags
# 	Average amplitude across all periods: 1.070 mJy
# 	Standard deviation of amplitudes: 0.165 mJy
# 	Average amplitude (1.070 mJy) is greater than 5 sigma (0.165 mJy). This indicates consistent variability across periods.
# Target:  841
# Offsets for object 841 (g-band: True):
# {'j_vs_n': np.float64(nan), 'n_vs_j': np.float64(nan)}
# Amplitude metrics:
# 	Lower 5% percentile: 23.65 mJy, 12.90 mags
# 	Upper 5% percentile: 25.04 mJy, 12.97 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 1.39 mJy, 0.06 mags
# Amplitude metrics:
# 	Lower 1% percentile: 23.44 mJy, 12.89 mags
# 	Upper 1% percentile: 25.41 mJy, 12.98 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 1.96 mJy, 0.09 mags
# 	Largest amplitude of variability (g-band: True): 2.46 mJy, 0.11 mags
# 	Average amplitude across all periods: 1.785 mJy
# 	Standard deviation of amplitudes: 0.456 mJy
# 	Warning: average amplitude (1.785 mJy) is less than 5 sigma (0.456 mJy). This indicates significant variability in the amplitudes across periods.
# Target:  842
# Offsets for object 842 (g-band: True):
# {'j_vs_l': np.float64(nan), 'l_vs_j': np.float64(nan)}
# Amplitude metrics:
# 	Lower 5% percentile: 16.66 mJy, 13.30 mags
# 	Upper 5% percentile: 17.33 mJy, 13.35 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.67 mJy, 0.04 mags
# Amplitude metrics:
# 	Lower 1% percentile: 16.52 mJy, 13.28 mags
# 	Upper 1% percentile: 17.66 mJy, 13.36 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 1.14 mJy, 0.07 mags
# 	Largest amplitude of variability (g-band: True): 1.50 mJy, 0.10 mags
# 	Average amplitude across all periods: 0.648 mJy
# 	Standard deviation of amplitudes: 0.225 mJy
# 	Warning: average amplitude (0.648 mJy) is less than 5 sigma (0.225 mJy). This indicates significant variability in the amplitudes across periods.
# Target:  843
# Offsets for object 843 (g-band: True):
# {'j_vs_n': np.float64(nan), 'n_vs_j': np.float64(nan)}
# Amplitude metrics:
# 	Lower 5% percentile: 64.19 mJy, 11.84 mags
# 	Upper 5% percentile: 66.76 mJy, 11.88 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 2.58 mJy, 0.04 mags
# Amplitude metrics:
# 	Lower 1% percentile: 63.95 mJy, 11.83 mags
# 	Upper 1% percentile: 67.39 mJy, 11.89 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 3.43 mJy, 0.06 mags
# 	Largest amplitude of variability (g-band: True): 5.37 mJy, 0.09 mags
# 	Average amplitude across all periods: 0.892 mJy
# 	Standard deviation of amplitudes: 0.573 mJy
# 	Warning: average amplitude (0.892 mJy) is less than 5 sigma (0.573 mJy). This indicates significant variability in the amplitudes across periods.
# Target:  844
# Offsets for object 844 (g-band: True):
# {'j_vs_n': np.float64(nan), 'n_vs_j': np.float64(nan)}
# Amplitude metrics:
# 	Lower 5% percentile: 6.34 mJy, 14.30 mags
# 	Upper 5% percentile: 6.89 mJy, 14.39 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.55 mJy, 0.09 mags
# Amplitude metrics:
# 	Lower 1% percentile: 6.17 mJy, 14.29 mags
# 	Upper 1% percentile: 7.01 mJy, 14.43 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.85 mJy, 0.14 mags
# 	Largest amplitude of variability (g-band: True): 1.12 mJy, 0.18 mags
# 	Average amplitude across all periods: 0.902 mJy
# 	Standard deviation of amplitudes: 0.140 mJy
# 	Average amplitude (0.902 mJy) is greater than 5 sigma (0.140 mJy). This indicates consistent variability across periods.
# Target:  845
# Offsets for object 845 (g-band: True):
# {'j_vs_n': np.float64(nan), 'n_vs_j': np.float64(nan)}
# Amplitude metrics:
# 	Lower 5% percentile: 22.36 mJy, 12.99 mags
# 	Upper 5% percentile: 23.21 mJy, 13.03 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.85 mJy, 0.04 mags
# Amplitude metrics:
# 	Lower 1% percentile: 22.11 mJy, 12.98 mags
# 	Upper 1% percentile: 23.38 mJy, 13.04 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 1.27 mJy, 0.06 mags
# 	Largest amplitude of variability (g-band: True): 1.76 mJy, 0.08 mags
# 	Average amplitude across all periods: 1.265 mJy
# 	Standard deviation of amplitudes: 0.232 mJy
# 	Average amplitude (1.265 mJy) is greater than 5 sigma (0.232 mJy). This indicates consistent variability across periods.
# Target:  846
# Offsets for object 846 (g-band: True):
# {'j_vs_n': np.float64(nan), 'n_vs_j': np.float64(nan)}
# Amplitude metrics:
# 	Lower 5% percentile: 11.42 mJy, 13.70 mags
# 	Upper 5% percentile: 11.99 mJy, 13.76 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.57 mJy, 0.05 mags
# Amplitude metrics:
# 	Lower 1% percentile: 11.28 mJy, 13.69 mags
# 	Upper 1% percentile: 12.14 mJy, 13.77 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.85 mJy, 0.08 mags
# 	Largest amplitude of variability (g-band: True): 1.13 mJy, 0.11 mags
# 	Average amplitude across all periods: 0.016 mJy
# 	Standard deviation of amplitudes: 0.064 mJy
# 	Warning: average amplitude (0.016 mJy) is less than 5 sigma (0.064 mJy). This indicates significant variability in the amplitudes across periods.
# Target:  847
# Offsets for object 847 (g-band: True):
# {'j_vs_n': np.float64(nan), 'n_vs_j': np.float64(nan)}
# Amplitude metrics:
# 	Lower 5% percentile: 15.94 mJy, 13.33 mags
# 	Upper 5% percentile: 16.96 mJy, 13.39 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 1.02 mJy, 0.07 mags
# Amplitude metrics:
# 	Lower 1% percentile: 15.76 mJy, 13.31 mags
# 	Upper 1% percentile: 17.21 mJy, 13.41 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 1.45 mJy, 0.10 mags
# 	Largest amplitude of variability (g-band: True): 2.09 mJy, 0.14 mags
# 	Average amplitude across all periods: 1.934 mJy
# 	Standard deviation of amplitudes: 0.115 mJy
# 	Average amplitude (1.934 mJy) is greater than 5 sigma (0.115 mJy). This indicates consistent variability across periods.
# Analysis complete! Results saved to summary_results17.csv
# Shape: (848, 28)
# Memory usage: 0.2 MB

# %%
for target in range(0,150): # 848
# for target in range(0,100):  
    # fit_plotter_flux(target)
    df, teles = offset_corrector(target, additive=False, show=True)
    try:
        lombs = compute_lomb_scargle(target, df=df, telescopes=teles, auto=False, samples_per_peak=10)
        plot_periodogram(target, lombs['frequency'], lombs['power'], lombs['best_frequency'], lombs['false_alarm_level'], lombs['peaks'], lombs['observation_period'], show_best=True)
        plot_phase_fold(target, lombs['best_period'], phase_bins=2, df=df, telescopes=teles)
    except Exception as e:
        print(f"Discarded lightcurve at target {target}: {e}")

# %% [markdown]
# ### Adding logT, logL to the summary_results files

# %%
# stats = pd.read_csv('summary_results02.csv')
# stats = pd.read_csv('summary_results03.csv')
# stats = pd.read_csv('summary_results08.csv')
# stats = pd.read_csv('summary_results07.csv')
# summary_file = 'summary_results12.csv'
summary_file = 'summary_results17.csv'
stats = pd.read_csv(summary_file)

df_lmc = pd.read_csv('/Users/shannonbowes/Research/ysg/candidates_and_lcs/final_lmc_ysgcands.csv', comment='#') # , sep="\\s+"
df_smc = pd.read_csv('/Users/shannonbowes/Research/ysg/candidates_and_lcs/final_smc_ysgcands.csv', comment='#') # , sep="\\s+"

# Create coordinate keys for matching (using a small tolerance for floating point precision)
def round_coords(ra, dec, precision=6):
    """Round coordinates to specified decimal places for robust matching"""
    return (round(ra, precision), round(dec, precision))

# Create coordinate-to-logT/logL mapping from df_smc and df_lmc
coord_to_logT = {}
coord_to_logL = {}

# Add SMC data (indices 0-376 in the combined catalog)
for idx, row in df_smc.iterrows():
    coord_key = round_coords(row['ra'], row['dec'])
    coord_to_logT[coord_key] = row['logT']
    coord_to_logL[coord_key] = row['logL']

# Add LMC data (indices 377+ in the combined catalog)  
for idx, row in df_lmc.iterrows():
    coord_key = round_coords(row['ra'], row['dec'])
    coord_to_logT[coord_key] = row['logT']
    coord_to_logL[coord_key] = row['logL']

# Create new logT and logL columns in summary_df
stats['logT'] = np.nan
stats['logL'] = np.nan

# Match coordinates and assign logT/logL values
matches = 0
for idx, row in stats.iterrows():
    coord_key = round_coords(row['RA'], row['DEC'])
    
    if coord_key in coord_to_logT:
        stats.at[idx, 'logT'] = coord_to_logT[coord_key]
        stats.at[idx, 'logL'] = coord_to_logL[coord_key]
        matches += 1

print(f"Successfully matched {matches} out of {len(stats)} stars")
print(f"Missing logT/logL for {len(stats) - matches} stars")

# Save the updated dataframe back to summary_results09.csv
stats.to_csv(summary_file, index=False)
print(f"Updated {summary_file} with logT and logL columns")

# Show a preview of the new columns
print("\nPreview of updated dataframe:")
print(stats[['RA', 'DEC', 'logT', 'logL']].head(10))

# Check for any missing values
missing_logT = stats['logT'].isna().sum()
missing_logL = stats['logL'].isna().sum()
print(f"\nMissing values - logT: {missing_logT}, logL: {missing_logL}")
# Out:
# Successfully matched 848 out of 848 stars
# Missing logT/logL for 0 stars
# Updated summary_results17.csv with logT and logL columns
#
# Preview of updated dataframe:
#          RA        DEC      logT      logL
# 0  7.521702 -73.913918  3.773141  4.026600
# 1  7.746443 -73.741425  3.770847  4.010042
# 2  7.925977 -73.531670  3.634779  4.044608
# 3  7.948884 -73.599243  3.629099  4.026778
# 4  7.980047 -73.578545  3.609289  4.036388
# 5  7.981742 -73.585571  3.617613  4.323311
# 6  8.228736 -73.821953  3.794981  4.034392
# 7  8.560188 -73.619049  3.617889  4.098910
# 8  8.637665 -73.873337  3.879346  4.206012
# 9  8.763608 -73.549622  3.626272  4.272656
#
# Missing values - logT: 0, logL: 0

# %%
df15 = pd.read_csv('summary_results17.csv')
df16 = pd.read_csv('summary_results16.csv')
counter = 0
variable_diff_counter = 0
total_variable_counter = 0

# comparing summary_results17 to summary_results16
for target in range(0,848):
    # Compare the two DataFrames
    if df15.iloc[target]['best_period'] - df16.iloc[target]['best_period'] > 0.1:
        print(f"DataFrames differ at index {target}")
        print("summary_results17:")
        print(df15.iloc[target]['best_period'])
        print("summary_results16:")
        print(df16.iloc[target]['best_period'])
        counter += 1
        if df15.iloc[target]['alarm_level_flag'] != df16.iloc[target]['alarm_level_flag']:
            variable_diff_counter += 1
        if df15.iloc[target]['alarm_level_flag'] != 1:
            variable_counter += 1

print(f"Total differing entries found: {counter}")
print(f"Total variable differing entries found: {variable_diff_counter}")
print(f"Total variable entries found: {variable_counter}")
# Out:
# DataFrames differ at index 2
# summary_results17:
# 309.2481948431621
# summary_results16:
# 201.54708472066625
# DataFrames differ at index 7
# summary_results17:
# 27.929154328293713
# summary_results16:
# 6.9017019001918465
# DataFrames differ at index 9
# summary_results17:
# 419.45098250948786
# summary_results16:
# 388.6442267030881
# DataFrames differ at index 20
# summary_results17:
# 420.07804524263946
# summary_results16:
# 254.17285333168633
# DataFrames differ at index 21
# summary_results17:
# 511.08222110082954
# summary_results16:
# 254.29619338834365
# DataFrames differ at index 25
# summary_results17:
# 571.1333794468534
# summary_results16:
# 553.2609933870724
# DataFrames differ at index 26
# summary_results17:
# 753.3181307772339
# summary_results16:
# 341.55226943668276
# DataFrames differ at index 28
# summary_results17:
# 510.38891932520465
# summary_results16:
# 398.3916114597043
# DataFrames differ at index 29
# summary_results17:
# 1102.3752195635443
# summary_results16:
# 955.009064300603
# DataFrames differ at index 30
# summary_results17:
# 289.7725720699362
# summary_results16:
# 230.06421391922785
# DataFrames differ at index 39
# summary_results17:
# 420.07804524263946
# summary_results16:
# 399.0664252653187
# DataFrames differ at index 40
# summary_results17:
# 333.04305237208956
# summary_results16:
# 325.2350630189629
# DataFrames differ at index 45
# summary_results17:
# 4.826803601935724
# summary_results16:
# 3.330413143842146
# DataFrames differ at index 50
# summary_results17:
# 322.1961090096706
# summary_results16:
# 253.12197456977
# DataFrames differ at index 52
# summary_results17:
# 511.77448678669543
# summary_results16:
# 395.2558681204219
# DataFrames differ at index 54
# summary_results17:
# 4.079138064700549
# summary_results16:
# 1.454492437771146
# DataFrames differ at index 57
# summary_results17:
# 347.2223658178655
# summary_results16:
# 322.8868842325364
# DataFrames differ at index 59
# summary_results17:
# 181.18158238849296
# summary_results16:
# 93.8963710328224
# DataFrames differ at index 70
# summary_results17:
# 323.836712295718
# summary_results16:
# 83.64531165401203
# DataFrames differ at index 73
# summary_results17:
# 1093.4386742700906
# summary_results16:
# 4.082151971002008
# DataFrames differ at index 78
# summary_results17:
# 83.64083320643512
# summary_results16:
# 83.47463632071346
# DataFrames differ at index 88
# summary_results17:
# 1.7132125276255106
# summary_results16:
# 1.5196847154451152
# DataFrames differ at index 90
# summary_results17:
# 83.0244420942645
# summary_results16:
# 35.88037472418782
# DataFrames differ at index 92
# summary_results17:
# 895.3749897595534
# summary_results16:
# 402.2889937728333
# DataFrames differ at index 93
# summary_results17:
# 1095.150394223394
# summary_results16:
# 48.55409667728759
# DataFrames differ at index 96
# summary_results17:
# 183.16415563753569
# summary_results16:
# 180.50476693679252
# DataFrames differ at index 105
# summary_results17:
# 77.9906121008923
# summary_results16:
# 77.55888696859155
# DataFrames differ at index 106
# summary_results17:
# 411.2282628033962
# summary_results16:
# 402.4221579761894
# DataFrames differ at index 108
# summary_results17:
# 735.4830628546254
# summary_results16:
# 398.96362557421
# DataFrames differ at index 110
# summary_results17:
# 1104.5372957761458
# summary_results16:
# 1079.19509438792
# DataFrames differ at index 111
# summary_results17:
# 743.3504038064483
# summary_results16:
# 189.5285476271412
# DataFrames differ at index 113
# summary_results17:
# 52.79335426614145
# summary_results16:
# 2.0714862472817295
# DataFrames differ at index 118
# summary_results17:
# 410.5902410046536
# summary_results16:
# 409.1861377695308
# DataFrames differ at index 119
# summary_results17:
# 333.04305237208956
# summary_results16:
# 330.11112842744524
# DataFrames differ at index 122
# summary_results17:
# 559.3420740732912
# summary_results16:
# 433.54860852481454
# DataFrames differ at index 123
# summary_results17:
# 324.927769092836
# summary_results16:
# 323.92787824321766
# DataFrames differ at index 124
# summary_results17:
# 21.47426779351484
# summary_results16:
# 7.174396902170666
# DataFrames differ at index 126
# summary_results17:
# 753.3181307772339
# summary_results16:
# 294.51182051523807
# DataFrames differ at index 127
# summary_results17:
# 82.53064346253603
# summary_results16:
# 25.006583494968936
# DataFrames differ at index 130
# summary_results17:
# 1095.717189458993
# summary_results16:
# 984.5807590026754
# DataFrames differ at index 133
# summary_results17:
# 2.2619250464966036
# summary_results16:
# 1.331537061301968
# DataFrames differ at index 140
# summary_results17:
# 27.37860673193917
# summary_results16:
# 6.565064539059584
# DataFrames differ at index 145
# summary_results17:
# 2.817213764113934
# summary_results16:
# 1.540985093840495
# DataFrames differ at index 146
# summary_results17:
# 1099.6328209207088
# summary_results16:
# 1080.9756768281095
# DataFrames differ at index 147
# summary_results17:
# 4.823905897509741
# summary_results16:
# 1.257237406997748
# DataFrames differ at index 150
# summary_results17:
# 865.3267085339435
# summary_results16:
# 860.0479866747829
# DataFrames differ at index 151
# summary_results17:
# 740.2247241964118
# summary_results16:
# 541.2163555749149
# DataFrames differ at index 154
# summary_results17:
# 74.22975870077744
# summary_results16:
# 73.82057734643615
# DataFrames differ at index 155
# summary_results17:
# 315.1364757737887
# summary_results16:
# 1.910843520677456
# DataFrames differ at index 157
# summary_results17:
# 409.9514254446288
# summary_results16:
# 2.3240120312666086
# DataFrames differ at index 165
# summary_results17:
# 451.52314892109064
# summary_results16:
# 68.89499948345565
# DataFrames differ at index 171
# summary_results17:
# 737.861925511453
# summary_results16:
# 367.89665802512087
# DataFrames differ at index 174
# summary_results17:
# 378.1403920820812
# summary_results16:
# 212.9795276798204
# DataFrames differ at index 175
# summary_results17:
# 4.577138000441375
# summary_results16:
# 1.70441613870467
# DataFrames differ at index 177
# summary_results17:
# 410.5902410046536
# summary_results16:
# 5.002508040894186
# DataFrames differ at index 178
# summary_results17:
# 410.5902410046536
# summary_results16:
# 1.1155040523120627
# DataFrames differ at index 179
# summary_results17:
# 1.644467405933562
# summary_results16:
# 1.2606431224590395
# DataFrames differ at index 180
# summary_results17:
# 117.76912528321596
# summary_results16:
# 1.1510331166230945
# DataFrames differ at index 181
# summary_results17:
# 376.9311885221682
# summary_results16:
# 18.048420380310287
# DataFrames differ at index 183
# summary_results17:
# 324.927769092836
# summary_results16:
# 1.5413572820925157
# DataFrames differ at index 184
# summary_results17:
# 1.359345358663567
# summary_results16:
# 1.1656266375217337
# DataFrames differ at index 185
# summary_results17:
# 389.317161069552
# summary_results16:
# 389.1790107858771
# DataFrames differ at index 186
# summary_results17:
# 265.9259081180453
# summary_results16:
# 33.663025586373344
# DataFrames differ at index 191
# summary_results17:
# 1094.5817162216797
# summary_results16:
# 1.460595094185288
# DataFrames differ at index 192
# summary_results17:
# 742.5716131819812
# summary_results16:
# 394.7617789779898
# DataFrames differ at index 195
# summary_results17:
# 742.5716131819812
# summary_results16:
# 364.0699034320295
# DataFrames differ at index 201
# summary_results17:
# 411.8654923193725
# summary_results16:
# 390.7620713236968
# DataFrames differ at index 203
# summary_results17:
# 411.8654923193725
# summary_results16:
# 2.533476301461323
# DataFrames differ at index 208
# summary_results17:
# 3.256221500530691
# summary_results16:
# 1.201709777680348
# DataFrames differ at index 211
# summary_results17:
# 347.79777078712743
# summary_results16:
# 204.43711033338255
# DataFrames differ at index 213
# summary_results17:
# 228.47393229184308
# summary_results16:
# 225.28392254457992
# DataFrames differ at index 214
# summary_results17:
# 4.405608703401777
# summary_results16:
# 1.1791458107266295
# DataFrames differ at index 217
# summary_results17:
# 409.3118146411256
# summary_results16:
# 1.8556390950048287
# DataFrames differ at index 219
# summary_results17:
# 345.6511763094278
# summary_results16:
# 339.3413043703417
# DataFrames differ at index 222
# summary_results17:
# 1095.150394223394
# summary_results16:
# 1037.3631473932007
# DataFrames differ at index 223
# summary_results17:
# 1095.717189458993
# summary_results16:
# 522.9918318958795
# DataFrames differ at index 226
# summary_results17:
# 387.52776587459914
# summary_results16:
# 1.722085290299261
# DataFrames differ at index 227
# summary_results17:
# 409.3118146411256
# summary_results16:
# 394.2903057004273
# DataFrames differ at index 228
# summary_results17:
# 1095.717189458993
# summary_results16:
# 305.27213315683326
# DataFrames differ at index 229
# summary_results17:
# 1.7801216879503416
# summary_results16:
# 1.1628024296753618
# DataFrames differ at index 231
# summary_results17:
# 569.6418369301881
# summary_results16:
# 322.95451273131823
# DataFrames differ at index 243
# summary_results17:
# 253.56381953720415
# summary_results16:
# 1.8666603501721335
# DataFrames differ at index 245
# summary_results17:
# 859.8350196829713
# summary_results16:
# 778.4000436378727
# DataFrames differ at index 248
# summary_results17:
# 1.9152879361576605
# summary_results16:
# 1.5266397019026052
# DataFrames differ at index 250
# summary_results17:
# 1096.2821112631532
# summary_results16:
# 1075.861085924946
# DataFrames differ at index 255
# summary_results17:
# 885.9614552555552
# summary_results16:
# 390.8969452457893
# DataFrames differ at index 256
# summary_results17:
# 410.5902410046536
# summary_results16:
# 407.7610825909098
# DataFrames differ at index 258
# summary_results17:
# 267.82215205287986
# summary_results16:
# 263.51425290419854
# DataFrames differ at index 260
# summary_results17:
# 236.2948975714748
# summary_results16:
# 7.052042097335458
# DataFrames differ at index 263
# summary_results17:
# 884.4841282692767
# summary_results16:
# 28.972579201002876
# DataFrames differ at index 264
# summary_results17:
# 2.0116123128154
# summary_results16:
# 1.3008081538966354
# DataFrames differ at index 265
# summary_results17:
# 378.1403920820812
# summary_results16:
# 29.288948814018465
# DataFrames differ at index 267
# summary_results17:
# 267.3486667465947
# summary_results16:
# 4.186100694205487
# DataFrames differ at index 272
# summary_results17:
# 265.9259081180453
# summary_results16:
# 106.37327844255697
# DataFrames differ at index 276
# summary_results17:
# 1094.0111460570552
# summary_results16:
# 592.5137531175794
# DataFrames differ at index 282
# summary_results17:
# 408.6714071082547
# summary_results16:
# 399.23499120756014
# DataFrames differ at index 285
# summary_results17:
# 321.64816659851164
# summary_results16:
# 139.91750928485376
# DataFrames differ at index 298
# summary_results17:
# 20.83133871965491
# summary_results16:
# 1.2674931255855617
# DataFrames differ at index 301
# summary_results17:
# 341.90524423610617
# summary_results16:
# 6.566162041698656
# DataFrames differ at index 305
# summary_results17:
# 301.488832661206
# summary_results16:
# 229.7991347829795
# DataFrames differ at index 307
# summary_results17:
# 312.9741650766859
# summary_results16:
# 89.48492327779196
# DataFrames differ at index 308
# summary_results17:
# 324.927769092836
# summary_results16:
# 91.22808166319643
# DataFrames differ at index 312
# summary_results17:
# 267.3486667465947
# summary_results16:
# 22.811558894288908
# DataFrames differ at index 313
# summary_results17:
# 411.8654923193725
# summary_results16:
# 4.253340502807508
# DataFrames differ at index 315
# summary_results17:
# 1093.0040307360086
# summary_results16:
# 2.3596922894296273
# DataFrames differ at index 316
# summary_results17:
# 409.9514254446288
# summary_results16:
# 289.57007184359566
# DataFrames differ at index 321
# summary_results17:
# 344.33620213311553
# summary_results16:
# 329.26538406158085
# DataFrames differ at index 323
# summary_results17:
# 2.0024234321534244
# summary_results16:
# 1.7623649652406894
# DataFrames differ at index 324
# summary_results17:
# 411.8654923193725
# summary_results16:
# 383.415080156772
# DataFrames differ at index 326
# summary_results17:
# 323.2903810675172
# summary_results16:
# 319.49773731107365
# DataFrames differ at index 328
# summary_results17:
# 207.9022152818856
# summary_results16:
# 203.75527015213584
# DataFrames differ at index 332
# summary_results17:
# 323.2903810675172
# summary_results16:
# 316.7510024373302
# DataFrames differ at index 334
# summary_results17:
# 265.45088611594326
# summary_results16:
# 6.831167066973825
# DataFrames differ at index 342
# summary_results17:
# 14.336090565055676
# summary_results16:
# 1.1583931441467872
# DataFrames differ at index 343
# summary_results17:
# 884.4841282692767
# summary_results16:
# 253.3428215617376
# DataFrames differ at index 348
# summary_results17:
# 347.2223658178655
# summary_results16:
# 330.15741060879446
# DataFrames differ at index 349
# summary_results17:
# 29.811292234496833
# summary_results16:
# 1.4903255464720513
# DataFrames differ at index 351
# summary_results17:
# 324.38250804186185
# summary_results16:
# 92.9378739058005
# DataFrames differ at index 354
# summary_results17:
# 319.45100254866327
# summary_results16:
# 252.73591111211255
# DataFrames differ at index 355
# summary_results17:
# 302.0094421983405
# summary_results16:
# 224.2550899166054
# DataFrames differ at index 358
# summary_results17:
# 54.19413231794074
# summary_results16:
# 54.063647775206114
# DataFrames differ at index 359
# summary_results17:
# 881.505605734533
# summary_results16:
# 252.61445444958363
# DataFrames differ at index 361
# summary_results17:
# 884.4841282692767
# summary_results16:
# 820.2251072549412
# DataFrames differ at index 363
# summary_results17:
# 1087.60724024962
# summary_results16:
# 270.36228812576627
# DataFrames differ at index 365
# summary_results17:
# 284.34880307794475
# summary_results16:
# 283.2072791837755
# DataFrames differ at index 366
# summary_results17:
# 448.1485542777926
# summary_results16:
# 51.57856699613858
# DataFrames differ at index 371
# summary_results17:
# 736.2778123580409
# summary_results16:
# 13.987103270590636
# DataFrames differ at index 372
# summary_results17:
# 303.0492311343306
# summary_results16:
# 233.13237542149457
# DataFrames differ at index 376
# summary_results17:
# 728.2484195134608
# summary_results16:
# 29.3170055377777
# DataFrames differ at index 377
# summary_results17:
# 874.1016551155469
# summary_results16:
# 387.23710767538574
# DataFrames differ at index 381
# summary_results17:
# 1155.2618628636203
# summary_results16:
# 390.44851925140176
# DataFrames differ at index 382
# summary_results17:
# 340.2988062612709
# summary_results16:
# 327.6737874063188
# DataFrames differ at index 389
# summary_results17:
# 385.55902086125263
# summary_results16:
# 377.0808022053844
# DataFrames differ at index 390
# summary_results17:
# 340.2988062612709
# summary_results16:
# 328.4959390387857
# DataFrames differ at index 405
# summary_results17:
# 337.65303820218355
# summary_results16:
# 144.27286873062727
# DataFrames differ at index 406
# summary_results17:
# 340.7468221275116
# summary_results16:
# 338.1010009048675
# DataFrames differ at index 408
# summary_results17:
# 321.86302924665335
# summary_results16:
# 314.4685930399329
# DataFrames differ at index 409
# summary_results17:
# 304.96236916197734
# summary_results16:
# 297.28454020951773
# DataFrames differ at index 410
# summary_results17:
# 823.2470382663174
# summary_results16:
# 792.8954327181344
# DataFrames differ at index 415
# summary_results17:
# 379.1337232015508
# summary_results16:
# 374.2349587552403
# DataFrames differ at index 419
# summary_results17:
# 340.2988062612709
# summary_results16:
# 329.11175376264197
# DataFrames differ at index 423
# summary_results17:
# 525.8614372941325
# summary_results16:
# 522.2963911818972
# DataFrames differ at index 430
# summary_results17:
# 339.85042372617056
# summary_results16:
# 296.71187178722226
# DataFrames differ at index 432
# summary_results17:
# 1148.4382694427595
# summary_results16:
# 835.5168640331443
# DataFrames differ at index 434
# summary_results17:
# 385.55902086125263
# summary_results16:
# 380.24796863280307
# DataFrames differ at index 435
# summary_results17:
# 384.5844488059284
# summary_results16:
# 376.85384970282786
# DataFrames differ at index 440
# summary_results17:
# 642.1457898252096
# summary_results16:
# 602.5285303334341
# DataFrames differ at index 443
# summary_results17:
# 524.1352271860361
# summary_results16:
# 319.555806588771
# DataFrames differ at index 445
# summary_results17:
# 226.6893306527439
# summary_results16:
# 222.8001911735201
# DataFrames differ at index 446
# summary_results17:
# 316.1184378022112
# summary_results16:
# 276.45437881316656
# DataFrames differ at index 447
# summary_results17:
# 386.0456297038307
# summary_results16:
# 119.73529965140996
# DataFrames differ at index 450
# summary_results17:
# 960.311412397906
# summary_results16:
# 328.4959390387857
# DataFrames differ at index 455
# summary_results17:
# 1150.9463459377307
# summary_results16:
# 392.4987145608439
# DataFrames differ at index 456
# summary_results17:
# 435.63656286276614
# summary_results16:
# 381.8630962892324
# DataFrames differ at index 460
# summary_results17:
# 45.30658004891611
# summary_results16:
# 45.175441528324825
# DataFrames differ at index 464
# summary_results17:
# 437.7976317884379
# summary_results16:
# 382.5285556744198
# DataFrames differ at index 468
# summary_results17:
# 713.3511720783728
# summary_results16:
# 99.42675574688776
# DataFrames differ at index 469
# summary_results17:
# 39.63427444783384
# summary_results16:
# 29.476265263199025
# DataFrames differ at index 474
# summary_results17:
# 445.2350838018635
# summary_results16:
# 204.93335350594927
# DataFrames differ at index 476
# summary_results17:
# 36.98206941737247
# summary_results16:
# 36.87326225397722
# DataFrames differ at index 477
# summary_results17:
# 421.2194733051474
# summary_results16:
# 307.76658237690975
# DataFrames differ at index 478
# summary_results17:
# 516.1751286059811
# summary_results16:
# 377.67451700495326
# DataFrames differ at index 482
# summary_results17:
# 340.7468221275116
# summary_results16:
# 175.8007497450877
# DataFrames differ at index 483
# summary_results17:
# 702.3342569075508
# summary_results16:
# 655.5554280029111
# DataFrames differ at index 484
# summary_results17:
# 251.66946510316808
# summary_results16:
# 167.79855091507696
# DataFrames differ at index 485
# summary_results17:
# 721.9709259936095
# summary_results16:
# 297.6659998181975
# DataFrames differ at index 488
# summary_results17:
# 370.4187688337528
# summary_results16:
# 103.41954791281276
# DataFrames differ at index 491
# summary_results17:
# 134.92640930197177
# summary_results16:
# 133.2988471422112
# DataFrames differ at index 493
# summary_results17:
# 312.43629781234097
# summary_results16:
# 41.7967930094148
# DataFrames differ at index 496
# summary_results17:
# 296.54869701895785
# summary_results16:
# 4.117253116633346
# DataFrames differ at index 497
# summary_results17:
# 385.55902086125263
# summary_results16:
# 329.3168733720278
# DataFrames differ at index 498
# summary_results17:
# 960.311412397906
# summary_results16:
# 377.7610772827961
# DataFrames differ at index 500
# summary_results17:
# 588.4726736280246
# summary_results16:
# 378.0950411911445
# DataFrames differ at index 501
# summary_results17:
# 971.2228473822524
# summary_results16:
# 905.2907765455044
# DataFrames differ at index 503
# summary_results17:
# 1157.739676385222
# summary_results16:
# 1050.3659310165451
# DataFrames differ at index 504
# summary_results17:
# 126.13534726709956
# summary_results16:
# 125.0926017293234
# DataFrames differ at index 510
# summary_results17:
# 443.1132119093297
# summary_results16:
# 432.3914256579884
# DataFrames differ at index 513
# summary_results17:
# 164.21014744765856
# summary_results16:
# 163.4762334785321
# DataFrames differ at index 518
# summary_results17:
# 185.61975057776215
# summary_results16:
# 183.733977235331
# DataFrames differ at index 522
# summary_results17:
# 193.30810376929324
# summary_results16:
# 193.05720356961783
# DataFrames differ at index 524
# summary_results17:
# 492.2131247471206
# summary_results16:
# 18.24870264656578
# DataFrames differ at index 525
# summary_results17:
# 128.71989676404493
# summary_results16:
# 109.86936010063478
# DataFrames differ at index 527
# summary_results17:
# 584.9669945478715
# summary_results16:
# 576.3700151996184
# DataFrames differ at index 533
# summary_results17:
# 7.391036025181622
# summary_results16:
# 2.042841600352267
# DataFrames differ at index 534
# summary_results17:
# 578.2151002998168
# summary_results16:
# 417.6533652728872
# DataFrames differ at index 537
# summary_results17:
# 131.77348674545482
# summary_results16:
# 130.93098868209694
# DataFrames differ at index 538
# summary_results17:
# 532.346204966353
# summary_results16:
# 381.6019633997505
# DataFrames differ at index 539
# summary_results17:
# 102.1480151130928
# summary_results16:
# 101.11344988294243
# DataFrames differ at index 542
# summary_results17:
# 531.2110370256653
# summary_results16:
# 445.873080331775
# DataFrames differ at index 545
# summary_results17:
# 47.53114654785808
# summary_results16:
# 47.387416575573866
# DataFrames differ at index 547
# summary_results17:
# 72.83839508246686
# summary_results16:
# 19.634361611302477
# DataFrames differ at index 551
# summary_results17:
# 308.33452405749256
# summary_results16:
# 268.17282122686663
# DataFrames differ at index 554
# summary_results17:
# 256.7131531400537
# summary_results16:
# 127.54776520654757
# DataFrames differ at index 556
# summary_results17:
# 328.3605901588314
# summary_results16:
# 326.2562360011657
# DataFrames differ at index 557
# summary_results17:
# 328.3605901588314
# summary_results16:
# 321.76167265219095
# DataFrames differ at index 561
# summary_results17:
# 346.6271760018231
# summary_results16:
# 338.8214439019427
# DataFrames differ at index 562
# summary_results17:
# 451.6983952146354
# summary_results16:
# 125.63764743728328
# DataFrames differ at index 564
# summary_results17:
# 55.76794302499646
# summary_results16:
# 5.762900880568865
# DataFrames differ at index 565
# summary_results17:
# 391.9642057252736
# summary_results16:
# 375.6127022744725
# DataFrames differ at index 566
# summary_results17:
# 532.346204966353
# summary_results16:
# 324.1349865822991
# DataFrames differ at index 569
# summary_results17:
# 394.3651766693034
# summary_results16:
# 384.70522070732585
# DataFrames differ at index 572
# summary_results17:
# 1154.6732271203798
# summary_results16:
# 1000.3792980141964
# DataFrames differ at index 574
# summary_results17:
# 484.02831679978823
# summary_results16:
# 343.61198789997667
# DataFrames differ at index 575
# summary_results17:
# 965.897207590687
# summary_results16:
# 909.9239722771298
# DataFrames differ at index 576
# summary_results17:
# 320.21533593680465
# summary_results16:
# 316.6835372606271
# DataFrames differ at index 577
# summary_results17:
# 19.389726788764637
# summary_results16:
# 3.0247377452217163
# DataFrames differ at index 580
# summary_results17:
# 329.2110831759956
# summary_results16:
# 322.14659059149267
# DataFrames differ at index 584
# summary_results17:
# 174.2343229270304
# summary_results16:
# 173.68051202425832
# DataFrames differ at index 585
# summary_results17:
# 328.3605901588314
# summary_results16:
# 327.6853589363841
# DataFrames differ at index 588
# summary_results17:
# 323.6594557082535
# summary_results16:
# 319.46722695384216
# DataFrames differ at index 596
# summary_results17:
# 329.6358407742034
# summary_results16:
# 205.0515140443194
# DataFrames differ at index 604
# summary_results17:
# 832.1500294419425
# summary_results16:
# 391.23466814127033
# DataFrames differ at index 608
# summary_results17:
# 343.06890114847306
# summary_results16:
# 320.3500539338613
# DataFrames differ at index 609
# summary_results17:
# 488.41111346471007
# summary_results16:
# 452.9635733991587
# DataFrames differ at index 610
# summary_results17:
# 533.4785329336049
# summary_results16:
# 151.55668984575914
# DataFrames differ at index 613
# summary_results17:
# 175.26399192565802
# summary_results16:
# 130.74900773989276
# DataFrames differ at index 616
# summary_results17:
# 345.29553756023574
# summary_results16:
# 337.2328017051151
# DataFrames differ at index 618
# summary_results17:
# 348.39764249984955
# summary_results16:
# 342.21947039637206
# DataFrames differ at index 626
# summary_results17:
# 1156.9793869679177
# summary_results16:
# 2.1576646171158465
# DataFrames differ at index 628
# summary_results17:
# 453.7858054193174
# summary_results16:
# 312.09793426245443
# DataFrames differ at index 630
# summary_results17:
# 14.765239246257837
# summary_results16:
# 7.902895485982114
# DataFrames differ at index 633
# summary_results17:
# 965.3579386963776
# summary_results16:
# 952.6390546112096
# DataFrames differ at index 634
# summary_results17:
# 965.3579386963776
# summary_results16:
# 952.1480346690508
# DataFrames differ at index 635
# summary_results17:
# 725.4423077528592
# summary_results16:
# 483.8458189755811
# DataFrames differ at index 638
# summary_results17:
# 969.6378064599198
# summary_results16:
# 947.8035599573242
# DataFrames differ at index 641
# summary_results17:
# 148.1887301214058
# summary_results16:
# 103.87932640029872
# DataFrames differ at index 642
# summary_results17:
# 1156.597641766802
# summary_results16:
# 292.44651046839897
# DataFrames differ at index 643
# summary_results17:
# 966.4352461508172
# summary_results16:
# 954.7554223176944
# DataFrames differ at index 646
# summary_results17:
# 48.22569187795419
# summary_results16:
# 48.10395625726892
# DataFrames differ at index 649
# summary_results17:
# 23.883277110544785
# summary_results16:
# 1.759168058860482
# DataFrames differ at index 651
# summary_results17:
# 388.09956083568
# summary_results16:
# 2.596119756867864
# DataFrames differ at index 654
# summary_results17:
# 328.7859997625464
# summary_results16:
# 323.3888728397754
# DataFrames differ at index 656
# summary_results17:
# 954.9349355390908
# summary_results16:
# 333.5990127086874
# DataFrames differ at index 659
# summary_results17:
# 1155.8310264787926
# summary_results16:
# 768.5630567152083
# DataFrames differ at index 668
# summary_results17:
# 203.24821116507044
# summary_results16:
# 203.06168081248785
# DataFrames differ at index 669
# summary_results17:
# 203.83816131696975
# summary_results16:
# 203.23744843063457
# DataFrames differ at index 672
# summary_results17:
# 956.0602706246648
# summary_results16:
# 934.3911452028236
# DataFrames differ at index 677
# summary_results17:
# 326.6556900453167
# summary_results16:
# 91.35215426004837
# DataFrames differ at index 681
# summary_results17:
# 533.4785123032175
# summary_results16:
# 504.3549553357895
# DataFrames differ at index 682
# summary_results17:
# 832.1500294419425
# summary_results16:
# 96.72354437562014
# DataFrames differ at index 684
# summary_results17:
# 341.28103655019675
# summary_results16:
# 340.97797034527537
# DataFrames differ at index 688
# summary_results17:
# 97.19867351058824
# summary_results16:
# 96.69441589938968
# DataFrames differ at index 690
# summary_results17:
# 335.9324825235652
# summary_results16:
# 321.94002302669827
# DataFrames differ at index 691
# summary_results17:
# 404.497118290396
# summary_results16:
# 332.2292185139345
# DataFrames differ at index 695
# summary_results17:
# 488.41111346471007
# summary_results16:
# 475.1307167891137
# DataFrames differ at index 696
# summary_results17:
# 1157.7397736563269
# summary_results16:
# 416.8249035793174
# DataFrames differ at index 698
# summary_results17:
# 440.11681177633267
# summary_results16:
# 425.839199593349
# DataFrames differ at index 699
# summary_results17:
# 125.40731296838318
# summary_results16:
# 117.48539817369762
# DataFrames differ at index 700
# summary_results17:
# 969.107130469966
# summary_results16:
# 593.5170305920901
# DataFrames differ at index 705
# summary_results17:
# 325.4357310328251
# summary_results16:
# 321.58170364119934
# DataFrames differ at index 713
# summary_results17:
# 818.9165951017322
# summary_results16:
# 332.2624825313605
# DataFrames differ at index 714
# summary_results17:
# 285.85402995139907
# summary_results16:
# 274.10705638795133
# DataFrames differ at index 717
# summary_results17:
# 476.3223662362957
# summary_results16:
# 468.1033770688631
# DataFrames differ at index 720
# summary_results17:
# 439.58120130355945
# summary_results16:
# 285.91613509957057
# DataFrames differ at index 722
# summary_results17:
# 327.08240819209993
# summary_results16:
# 326.5542800205165
# DataFrames differ at index 723
# summary_results17:
# 390.0354477604769
# summary_results16:
# 380.21755439854536
# DataFrames differ at index 727
# summary_results17:
# 818.9165951017322
# summary_results16:
# 469.6195237538376
# DataFrames differ at index 728
# summary_results17:
# 408.6151634777048
# summary_results16:
# 323.0769004363632
# DataFrames differ at index 729
# summary_results17:
# 650.9337013143845
# summary_results16:
# 317.04681588704165
# DataFrames differ at index 730
# summary_results17:
# 408.1022041867221
# summary_results16:
# 10.903423719970192
# DataFrames differ at index 731
# summary_results17:
# 968.0420217873768
# summary_results16:
# 942.4753421542237
# DataFrames differ at index 733
# summary_results17:
# 1156.9793869679177
# summary_results16:
# 1040.4404550729016
# DataFrames differ at index 737
# summary_results17:
# 392.9259236422608
# summary_results16:
# 391.1601025599632
# DataFrames differ at index 738
# summary_results17:
# 1156.9793869679177
# summary_results16:
# 390.9705102231139
# DataFrames differ at index 739
# summary_results17:
# 419.7166082991888
# summary_results16:
# 399.1913671123167
# DataFrames differ at index 740
# summary_results17:
# 417.7058435406126
# summary_results16:
# 282.1403012167101
# DataFrames differ at index 741
# summary_results17:
# 1152.471493879578
# summary_results16:
# 1116.8204932364704
# DataFrames differ at index 746
# summary_results17:
# 140.72665289733183
# summary_results16:
# 84.72692194904975
# DataFrames differ at index 748
# summary_results17:
# 833.3309980533596
# summary_results16:
# 246.3487254888613
# DataFrames differ at index 750
# summary_results17:
# 344.4059710577701
# summary_results16:
# 333.7388980007576
# DataFrames differ at index 753
# summary_results17:
# 419.21466081779374
# summary_results16:
# 333.8244714445464
# DataFrames differ at index 757
# summary_results17:
# 327.08240819209993
# summary_results16:
# 76.19372418084218
# DataFrames differ at index 761
# summary_results17:
# 969.107130469966
# summary_results16:
# 568.5219085305623
# DataFrames differ at index 763
# summary_results17:
# 256.7131531400537
# summary_results16:
# 252.91382898349508
# DataFrames differ at index 765
# summary_results17:
# 816.4355404009526
# summary_results16:
# 331.4453846452756
# DataFrames differ at index 766
# summary_results17:
# 729.1069699665032
# summary_results16:
# 716.7342030070258
# DataFrames differ at index 767
# summary_results17:
# 436.89449723473626
# summary_results16:
# 321.8719478657228
# DataFrames differ at index 768
# summary_results17:
# 452.743213914322
# summary_results16:
# 436.58024506469104
# DataFrames differ at index 771
# summary_results17:
# 452.743213914322
# summary_results16:
# 418.3631697564838
# DataFrames differ at index 774
# summary_results17:
# 315.4931310491345
# summary_results16:
# 137.41884122287902
# DataFrames differ at index 783
# summary_results17:
# 86.03040951060983
# summary_results16:
# 11.100898766711609
# DataFrames differ at index 787
# summary_results17:
# 347.0703342280204
# summary_results16:
# 64.97950444007847
# DataFrames differ at index 788
# summary_results17:
# 1157.7397736563269
# summary_results16:
# 655.3634704617048
# DataFrames differ at index 791
# summary_results17:
# 1156.9793869679177
# summary_results16:
# 1117.8240805030748
# DataFrames differ at index 795
# summary_results17:
# 826.3399721395157
# summary_results16:
# 383.85588765326975
# DataFrames differ at index 796
# summary_results17:
# 833.3309980533596
# summary_results16:
# 752.9513702580357
# DataFrames differ at index 797
# summary_results17:
# 1157.7397736563269
# summary_results16:
# 578.6710116058405
# DataFrames differ at index 798
# summary_results17:
# 344.4059710577701
# summary_results16:
# 333.13951278513764
# DataFrames differ at index 801
# summary_results17:
# 1157.3600961939565
# summary_results16:
# 1077.783677743943
# DataFrames differ at index 804
# summary_results17:
# 334.5745910032365
# summary_results16:
# 1.924025917066827
# DataFrames differ at index 808
# summary_results17:
# 585.5532875343645
# summary_results16:
# 232.31456298659947
# DataFrames differ at index 809
# summary_results17:
# 336.3843703493979
# summary_results16:
# 1.4124788698509647
# DataFrames differ at index 811
# summary_results17:
# 367.19211092942936
# summary_results16:
# 356.8185235697887
# DataFrames differ at index 812
# summary_results17:
# 294.5750844632306
# summary_results16:
# 209.53624587099716
# DataFrames differ at index 816
# summary_results17:
# 583.7919845390284
# summary_results16:
# 577.8621741650827
# DataFrames differ at index 817
# summary_results17:
# 74.1687099719494
# summary_results16:
# 73.70963712223875
# DataFrames differ at index 819
# summary_results17:
# 380.3385932949456
# summary_results16:
# 329.97810411117234
# DataFrames differ at index 821
# summary_results17:
# 570.7171953037468
# summary_results16:
# 3.0488240469069225
# DataFrames differ at index 823
# summary_results17:
# 158.01736731282895
# summary_results16:
# 156.9270231003223
# DataFrames differ at index 826
# summary_results17:
# 452.743213914322
# summary_results16:
# 415.630084462743
# DataFrames differ at index 827
# summary_results17:
# 955.4982598414596
# summary_results16:
# 2.1110163999246123
# DataFrames differ at index 830
# summary_results17:
# 953.8043279141422
# summary_results16:
# 912.9708221983814
# DataFrames differ at index 833
# summary_results17:
# 631.9756759050074
# summary_results16:
# 95.75612727548685
# DataFrames differ at index 836
# summary_results17:
# 381.3218061156647
# summary_results16:
# 358.8335775503816
# DataFrames differ at index 837
# summary_results17:
# 333.66746870630476
# summary_results16:
# 175.950477070169
# DataFrames differ at index 838
# summary_results17:
# 406.0452422644076
# summary_results16:
# 398.2279953783563
# DataFrames differ at index 841
# summary_results17:
# 580.3286393179691
# summary_results16:
# 336.6247888774008
# DataFrames differ at index 845
# summary_results17:
# 528.4279338324782
# summary_results16:
# 39.71368307191771
# DataFrames differ at index 847
# summary_results17:
# 962.8666667682792
# summary_results16:
# 201.87537490026008
# Total differing entries found: 309
# Total variable differing entries found: 59
# Total variable entries found: 519

# %% [markdown]
# ### Old data:

# %%
results = []
for target in range(0,848):
    print("Target: ", target)
    overall_mean, means, overall_median, medians, overall_mags_mean, overall_mags_median, mags_means, mags_medians = mean_med_flux(target, g=True, newfiles=False)
    chi_squared_95, chi2_threshold_95, dof_95, chi_flag_95 = chi(target, g=True, newfiles=False)
    chi_squared_997, chi2_threshold_997, dof_997, chi_flag_997 = chi(target, confidence=0.997, g=True, newfiles=False)
    chi_squared_68, chi2_threshold_68, dof_68, chi_flag_68 = chi(target, confidence=0.68, g=True, newfiles=False)
    # largest_amp = curve_fitter_flux(target)
    offset_flag = offset_warning(target, newfiles=False)
    amplitude_5, lower_percentile_5, upper_percentile_5, mag_amplitude_5 = percentile_amplitude(target, tails=5, g=True, newfiles=False)
    amplitude_1, lower_percentile_1, upper_percentile_1, mag_amplitude_1 = percentile_amplitude(target, tails=1, g=True, newfiles=False)
    # plot_percentile_amplitude(target, tails=1)
    largest_amp = largest_amplitude(target, g=True, newfiles=False)
    # lombs = compute_lomb_scargle(target, auto=True, samples_per_peak=5) #freq_range=(0.0, 0.05),
    # plot_periodogram(lombs['frequency'], lombs['power'], lombs['false_alarm_level'], lombs['peaks'], lombs['observation_period'], auto = True, show_best=True)
    lombs = compute_lomb_scargle(target, auto=False, median=False, subtract_median=False, samples_per_peak=10, report=False, newfiles=False)
    best_period = lombs['best_period']
    alarm_level_flag = lombs['alarm_level_flag']
    result = amplitude_per_period(target, report = False, newfiles=False)
    std_amp = result['std_amplitude']
    # amplitude_per_period_plot(target, result)

    # fit_plotter_flux(target)
    # plot_periodogram(lombs['frequency'], lombs['power'], lombs['false_alarm_level'], lombs['peaks'], lombs['observation_period'], show_best=True)
    # plot_phase_fold(target, phase_bins=2)

        # Get RA and DEC for this target
    RA = coords['ra'][target]
    DEC = coords['dec'][target]

    results.append({
        'RA': RA,
        'DEC': DEC,
        'overall_mean': overall_mean,
        'overall_median': overall_median,
        'overall_mean_mag': overall_mags_mean,
        'overall_median_mag': overall_mags_median,
        'offset_flag': offset_flag,
        'chi_squared_68': chi_squared_68,
        'chi2_threshold_68': chi2_threshold_68,
        'chi_flag_68': chi_flag_68,
        'chi_squared_95': chi_squared_95,
        'chi2_threshold_95': chi2_threshold_95,
        'chi_flag_95': chi_flag_95,
        'chi_squared_997': chi_squared_997,
        'chi2_threshold_997': chi2_threshold_997,
        'chi_flag_997': chi_flag_997,
        'amplitude_5': amplitude_5,
        'lower_percentile_5': lower_percentile_5,
        'upper_percentile_5': upper_percentile_5,
        'mag_amplitude_5': mag_amplitude_5,
        'amplitude_1': amplitude_1,
        'lower_percentile_1': lower_percentile_1,
        'upper_percentile_1': upper_percentile_1,
        'mag_amplitude_1': mag_amplitude_1,
        'largest_amp': largest_amp,
        'best_period': best_period,
        'alarm_level_flag': alarm_level_flag,
        'std_amplitude': std_amp
    })

# print(results)

# Convert to DataFrame and save to CSV
df_results = pd.DataFrame(results)
df_results.to_csv('summary_results07.csv', index=False)

# %%
print(df)

# %% [markdown]
# # sorting

# %%
# create three new columns in summary_results15.csv called 'cephied_like', 'ir_variable_like', and 'other_variable_like' and leave them empty for now
summary_file = 'summary_results15.csv'
stats = pd.read_csv(summary_file)
stats['cephied_like'] = ''
stats['ir_variable_like'] = ''
stats['other_variable_like'] = ''
stats.to_csv(summary_file, index=False)
