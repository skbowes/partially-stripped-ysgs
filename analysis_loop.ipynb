# %%
import numpy as np
import os
import sys
import astropy as ast
from astropy.io import ascii
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import pandas as pd
import scipy as sp
from astropy.timeseries import LombScargle
from astropy import units as u
import gc

# %%
from view_and_clean import get_telescope, find_header_line, modified_zscore, df_extract, individual_plotter, grid_plotter, offset_corrector, offset_corrector_window
from metrics import mean_med_flux, fit_plotter_flux, curve_fitter_flux,\
    largest_amplitude, offset_warning, chi, percentile_amplitude, plot_percentile_amplitude, \
        compute_lomb_scargle, plot_periodogram, plot_phase_fold, amplitude_per_period, amplitude_per_period_plot, info_to_pdf, info_to_pdf_batch

# %% [markdown]
# ### Extracting data from files and plotting:

# %%
# coords = pd.read_csv('ysg_coords_with_lcs.dat', comment='#', sep="\\s+", names=['RA', 'DEC'])
# coords = pd.read_csv('/Users/shannonbowes/Research/ysg/candidates_and_lcs/final_smc_ysgcands.csv', comment='#', sep="\\s+", names=['ra', 'dec'])
coords = pd.read_csv('merged_smc_lmc_coords.csv', comment='#', sep="\\s+", names=['ra', 'dec'])
coords = pd.read_csv('merged_smc_lmc_coords_all.csv', comment='#', sep="\\s+", names=['ra', 'dec'])

# Diagnostic check
print(f"Loaded {len(coords)} coordinates from file")
print(f"First few rows:\n{coords.head()}")
print(f"Shape: {coords.shape}")
# Out:
# Loaded 1270 coordinates from file
# First few rows:
#          ra        dec
# 0  7.521702 -73.913918
# 1  7.746443 -73.741425
# 2  7.925977 -73.531670
# 3  7.948884 -73.599243
# 4  7.980047 -73.578545
# Shape: (1270, 2)

# %%
results = []

# %% [markdown]
# ### New data:

# %%
# Create DataFrame structure once before the loop
columns = [
    'RA', 'DEC', 'overall_mean', 'overall_median', 'overall_mean_mag', 'overall_median_mag',
    'offset_flag', 'chi_squared_68', 'chi2_threshold_68', 'chi_flag_68',
    'chi_squared_95', 'chi2_threshold_95', 'chi_flag_95', 
    'chi_squared_997', 'chi2_threshold_997', 'chi_flag_997',
    'amplitude_5', 'lower_percentile_5', 'upper_percentile_5', 'mag_amplitude_5',
    'amplitude_1', 'lower_percentile_1', 'upper_percentile_1', 'mag_amplitude_1',
    'largest_amp', 'best_period', 'alarm_level_flag', 'std_amplitude', 'best_logT', 'best_logL', 'best_logL_err'
]

# Use actual number of coordinates instead of hardcoded value
n_targets = len(coords)
print(f"Initializing DataFrame for {n_targets} targets")

# Initialize DataFrame with NaN values and pre-populate coordinates
results_df = pd.DataFrame(index=range(n_targets), columns=columns, dtype=float)
results_df['RA'] = coords['ra'].values
results_df['DEC'] = coords['dec'].values

# Main analysis loop
for target in range(0, n_targets):
    print("Target: ", target)
    
    try:
        df, telescopes = offset_corrector(target, additive=False, show=False)
        print("loaded data successfully")
        # if target in [375, 376, 377, 378, 379, 380]:
        #     print(f"\n=== DETAILED TARGET {target} ANALYSIS ===")
        #     print(f"Dataset: {'SMC' if target <= 376 else 'LMC'}")
        #     print(f"DataFrame shape: {df.shape}")
        #     print(f"Telescopes: {telescopes}")
        #     print(f"Time range: {df['HJD'].min():.1f} to {df['HJD'].max():.1f}")
        #     print(f"Unique telescope count: {len(telescopes)}")
        #     print(f"Data points per telescope: {[len(df[df['telescope']==t]) for t in telescopes]}")
        
        # analysis
        overall_mean, means, overall_median, medians, overall_mags_mean, overall_mags_median, mags_means, mags_medians = mean_med_flux(target, df=df, telescopes=telescopes)
        print("calculated mean and median successfully")
        chi_squared_95, chi2_threshold_95, dof_95, chi_flag_95 = chi(target, df=df, telescopes=telescopes, confidence=0.95)
        chi_squared_997, chi2_threshold_997, dof_997, chi_flag_997 = chi(target, df=df, telescopes=telescopes, confidence=0.997)
        chi_squared_68, chi2_threshold_68, dof_68, chi_flag_68 = chi(target, df=df, telescopes=telescopes, confidence=0.68)
        print("calculated chi-squared 95 successfully")
        offset_flag = offset_warning(target)
        print("calculated offset warning successfully")
        amplitude_5, lower_percentile_5, upper_percentile_5, mag_amplitude_5 = percentile_amplitude(target, df=df, telescopes=telescopes, tails=5)
        amplitude_1, lower_percentile_1, upper_percentile_1, mag_amplitude_1 = percentile_amplitude(target, df=df, telescopes=telescopes, tails=1)
        largest_amp, largest_amp_mag = largest_amplitude(target, df=df, telescopes=telescopes)
        lombs = compute_lomb_scargle(target, df=df, telescopes=telescopes, auto=False, median=False, subtract_median=False, samples_per_peak=10, report=False)
        best_period = lombs['best_period']
        alarm_level_flag = lombs['alarm_level_flag']
        result = amplitude_per_period(target, best_period, df=df, telescopes=telescopes, report=False)
        std_amp = result['std_amplitude']
        
        results_df.loc[target, 'overall_mean'] = overall_mean
        results_df.loc[target, 'overall_median'] = overall_median
        results_df.loc[target, 'overall_mean_mag'] = overall_mags_mean
        results_df.loc[target, 'overall_median_mag'] = overall_mags_median
        results_df.loc[target, 'offset_flag'] = offset_flag
        results_df.loc[target, 'chi_squared_68'] = chi_squared_68
        results_df.loc[target, 'chi2_threshold_68'] = chi2_threshold_68
        results_df.loc[target, 'chi_flag_68'] = chi_flag_68
        results_df.loc[target, 'chi_squared_95'] = chi_squared_95
        results_df.loc[target, 'chi2_threshold_95'] = chi2_threshold_95
        results_df.loc[target, 'chi_flag_95'] = chi_flag_95
        results_df.loc[target, 'chi_squared_997'] = chi_squared_997
        results_df.loc[target, 'chi2_threshold_997'] = chi2_threshold_997
        results_df.loc[target, 'chi_flag_997'] = chi_flag_997
        results_df.loc[target, 'amplitude_5'] = amplitude_5
        results_df.loc[target, 'lower_percentile_5'] = lower_percentile_5
        results_df.loc[target, 'upper_percentile_5'] = upper_percentile_5
        results_df.loc[target, 'mag_amplitude_5'] = mag_amplitude_5
        results_df.loc[target, 'amplitude_1'] = amplitude_1
        results_df.loc[target, 'lower_percentile_1'] = lower_percentile_1
        results_df.loc[target, 'upper_percentile_1'] = upper_percentile_1
        results_df.loc[target, 'mag_amplitude_1'] = mag_amplitude_1
        results_df.loc[target, 'largest_amp'] = largest_amp
        results_df.loc[target, 'largest_amp_mag'] = largest_amp_mag
        results_df.loc[target, 'best_period'] = best_period
        results_df.loc[target, 'alarm_level_flag'] = alarm_level_flag
        results_df.loc[target, 'std_amplitude'] = std_amp
        
        # Explicit memory cleanup to prevent accumulation
        del df, telescopes, lombs, result
        del overall_mean, means, overall_median, medians
        del overall_mags_mean, overall_mags_median, mags_means, mags_medians
        del amplitude_5, amplitude_1, largest_amp, std_amp
        
    except Exception as e:
        print(f"Target {target} failed: {e}")
        import traceback
        traceback.print_exc()  # Print full traceback to see exactly where error occurs
        # Values remain NaN in DataFrame - no action needed
        continue
    
    # More frequent garbage collection for better memory management
    if target % 25 == 0:
        gc.collect()
        # Optional: Memory monitoring
        if target % 100 == 0:
            import psutil, os
            process = psutil.Process(os.getpid())
            memory_mb = process.memory_info().rss / 1024 / 1024
            print(f"Memory usage at target {target}: {memory_mb:.1f} MB")

# Save results
results_df.to_csv('summary_results03062026.csv', index=False)
print(f"Analysis complete! Results saved to summary_results03062026.csv")
print(f"Shape: {results_df.shape}")
print(f"Memory usage: {results_df.memory_usage(deep=True).sum() / 1024**2:.1f} MB")
# Out:
# Initializing DataFrame for 1270 targets
# Target:  0
# loaded data successfully
# calculated mean and median successfully
# calculated chi-squared 95 successfully
# Offsets for object 0 (g-band: True):
# {'k_vs_l': np.float64(0.018124781320764782), 'k_vs_o': np.float64(-0.06304853337320715), 'k_vs_p': np.float64(-0.041626978650684876), 'k_vs_G': np.float64(-0.054843315953952754), 'k_vs_H': np.float64(0.03191661992473627), 'l_vs_k': np.float64(-0.018124781320764782), 'l_vs_o': np.float64(-0.08117331469397193), 'l_vs_p': np.float64(-0.05975175997144966), 'l_vs_G': np.float64(-0.07296809727471754), 'l_vs_H': np.float64(0.013791838603971485), 'o_vs_k': np.float64(0.06304853337320715), 'o_vs_l': np.float64(0.08117331469397193), 'o_vs_p': np.float64(0.021421554722522274), 'o_vs_G': np.float64(0.008205217419254396), 'o_vs_H': np.float64(0.09496515329794342), 'p_vs_k': np.float64(0.041626978650684876), 'p_vs_l': np.float64(0.05975175997144966), 'p_vs_o': np.float64(-0.021421554722522274), 'p_vs_G': np.float64(-0.013216337303267878), 'p_vs_H': np.float64(0.07354359857542114), 'G_vs_k': np.float64(0.054843315953952754), 'G_vs_l': np.float64(0.07296809727471754), 'G_vs_o': np.float64(-0.008205217419254396), 'G_vs_p': np.float64(0.013216337303267878), 'G_vs_H': np.float64(0.08675993587868902), 'H_vs_k': np.float64(-0.03191661992473627), 'H_vs_l': np.float64(-0.013791838603971485), 'H_vs_o': np.float64(-0.09496515329794342), 'H_vs_p': np.float64(-0.07354359857542114), 'H_vs_G': np.float64(-0.08675993587868902)}
# calculated offset warning successfully
# Amplitude metrics:
# 	Lower 5% percentile: 9.96 mJy, 13.83 mags
# 	Upper 5% percentile: 10.65 mJy, 13.91 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.69 mJy, 0.07 mags
# Amplitude metrics:
# 	Lower 1% percentile: 9.74 mJy, 13.81 mags
# 	Upper 1% percentile: 10.83 mJy, 13.93 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 1.08 mJy, 0.11 mags
# 	Largest amplitude of variability (g-band: True): 1.43 mJy, 0.15 mags
# 	Average amplitude across all periods: 0.420 mJy
# 	Standard deviation of amplitudes: 0.216 mJy
# 	Warning: average amplitude (0.420 mJy) is less than 5 sigma (0.216 mJy). This indicates significant variability in the amplitudes across periods.
# Memory usage at target 0: 230.1 MB
# Target:  1
# loaded data successfully
# calculated mean and median successfully
# calculated chi-squared 95 successfully
# Offsets for object 1 (g-band: True):
# {'l_vs_o': np.float64(-0.01056971097136028), 'l_vs_p': np.float64(-0.04274640698688792), 'l_vs_G': np.float64(-0.039950546519119), 'l_vs_H': np.float64(0.012683454984607323), 'o_vs_l': np.float64(0.01056971097136028), 'o_vs_p': np.float64(-0.03217669601552764), 'o_vs_G': np.float64(-0.02938083554775872), 'o_vs_H': np.float64(0.023253165955967603), 'p_vs_l': np.float64(0.04274640698688792), 'p_vs_o': np.float64(0.03217669601552764), 'p_vs_G': np.float64(0.002795860467768918), 'p_vs_H': np.float64(0.05542986197149524), 'G_vs_l': np.float64(0.039950546519119), 'G_vs_o': np.float64(0.02938083554775872), 'G_vs_p': np.float64(-0.002795860467768918), 'G_vs_H': np.float64(0.052634001503726324), 'H_vs_l': np.float64(-0.012683454984607323), 'H_vs_o': np.float64(-0.023253165955967603), 'H_vs_p': np.float64(-0.05542986197149524), 'H_vs_G': np.float64(-0.052634001503726324)}
# calculated offset warning successfully
# Amplitude metrics:
# 	Lower 5% percentile: 7.95 mJy, 14.08 mags
# 	Upper 5% percentile: 8.49 mJy, 14.15 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.55 mJy, 0.07 mags
# Amplitude metrics:
# 	Lower 1% percentile: 7.77 mJy, 14.06 mags
# 	Upper 1% percentile: 8.64 mJy, 14.17 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.88 mJy, 0.12 mags
# 	Largest amplitude of variability (g-band: True): 1.14 mJy, 0.15 mags
# 	Average amplitude across all periods: 0.706 mJy
# 	Standard deviation of amplitudes: 0.141 mJy
# 	Average amplitude (0.706 mJy) is greater than 5 sigma (0.141 mJy). This indicates consistent variability across periods.
# Target:  2
# loaded data successfully
# calculated mean and median successfully
# calculated chi-squared 95 successfully
# Offsets for object 2 (g-band: True):
# {'l_vs_o': np.float64(-0.07746333477766187), 'l_vs_p': np.float64(-0.06283243693462381), 'l_vs_G': np.float64(-0.04644312876080736), 'l_vs_H': np.float64(-0.09603686309447257), 'o_vs_l': np.float64(0.07746333477766187), 'o_vs_p': np.float64(0.01463089784303806), 'o_vs_G': np.float64(0.031020206016854512), 'o_vs_H': np.float64(-0.018573528316810695), 'p_vs_l': np.float64(0.06283243693462381), 'p_vs_o': np.float64(-0.01463089784303806), 'p_vs_G': np.float64(0.016389308173816453), 'p_vs_H': np.float64(-0.033204426159848754), 'G_vs_l': np.float64(0.04644312876080736), 'G_vs_o': np.float64(-0.031020206016854512), 'G_vs_p': np.float64(-0.016389308173816453), 'G_vs_H': np.float64(-0.04959373433366521), 'H_vs_l': np.float64(0.09603686309447257), 'H_vs_o': np.float64(0.018573528316810695), 'H_vs_p': np.float64(0.033204426159848754), 'H_vs_G': np.float64(0.04959373433366521)}
# calculated offset warning successfully
# Amplitude metrics:
# 	Lower 5% percentile: 3.50 mJy, 14.90 mags
# 	Upper 5% percentile: 3.99 mJy, 15.04 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.49 mJy, 0.14 mags
# Amplitude metrics:
# 	Lower 1% percentile: 3.37 mJy, 14.86 mags
# 	Upper 1% percentile: 4.15 mJy, 15.08 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.78 mJy, 0.23 mags
# 	Largest amplitude of variability (g-band: True): 0.99 mJy, 0.29 mags
# 	Average amplitude across all periods: 0.853 mJy
# 	Standard deviation of amplitudes: 0.072 mJy
# 	Average amplitude (0.853 mJy) is greater than 5 sigma (0.072 mJy). This indicates consistent variability across periods.
# Target:  3
# loaded data successfully
# calculated mean and median successfully
# calculated chi-squared 95 successfully
# Offsets for object 3 (g-band: True):
# {'l_vs_o': np.float64(-0.014548072386064703), 'l_vs_p': np.float64(-0.0002343599108991512), 'l_vs_G': np.float64(-0.026537631431483355), 'l_vs_H': np.float64(-0.05816059104235638), 'o_vs_l': np.float64(0.014548072386064703), 'o_vs_p': np.float64(0.014313712475165552), 'o_vs_G': np.float64(-0.011989559045418652), 'o_vs_H': np.float64(-0.04361251865629168), 'p_vs_l': np.float64(0.0002343599108991512), 'p_vs_o': np.float64(-0.014313712475165552), 'p_vs_G': np.float64(-0.026303271520584204), 'p_vs_H': np.float64(-0.05792623113145723), 'G_vs_l': np.float64(0.026537631431483355), 'G_vs_o': np.float64(0.011989559045418652), 'G_vs_p': np.float64(0.026303271520584204), 'G_vs_H': np.float64(-0.031622959610873025), 'H_vs_l': np.float64(0.05816059104235638), 'H_vs_o': np.float64(0.04361251865629168), 'H_vs_p': np.float64(0.05792623113145723), 'H_vs_G': np.float64(0.031622959610873025)}
# calculated offset warning successfully
# Amplitude metrics:
# 	Lower 5% percentile: 4.17 mJy, 14.74 mags
# 	Upper 5% percentile: 4.61 mJy, 14.85 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.44 mJy, 0.11 mags
# Amplitude metrics:
# 	Lower 1% percentile: 4.03 mJy, 14.71 mags
# 	Upper 1% percentile: 4.73 mJy, 14.89 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.70 mJy, 0.17 mags
# 	Largest amplitude of variability (g-band: True): 0.93 mJy, 0.23 mags
# 	Average amplitude across all periods: 0.852 mJy
# 	Standard deviation of amplitudes: 0.079 mJy
# 	Average amplitude (0.852 mJy) is greater than 5 sigma (0.079 mJy). This indicates consistent variability across periods.
# Target:  4
# loaded data successfully
# calculated mean and median successfully
# calculated chi-squared 95 successfully
# Offsets for object 4 (g-band: True):
# {'l_vs_o': np.float64(-0.013807484521259017), 'l_vs_p': np.float64(0.018685313014246585), 'l_vs_G': np.float64(0.00336200878308901), 'l_vs_H': np.float64(-0.04231571326716255), 'o_vs_l': np.float64(0.013807484521259017), 'o_vs_p': np.float64(0.0324927975355056), 'o_vs_G': np.float64(0.017169493304348027), 'o_vs_H': np.float64(-0.02850822874590353), 'p_vs_l': np.float64(-0.018685313014246585), 'p_vs_o': np.float64(-0.0324927975355056), 'p_vs_G': np.float64(-0.015323304231157575), 'p_vs_H': np.float64(-0.06100102628140913), 'G_vs_l': np.float64(-0.00336200878308901), 'G_vs_o': np.float64(-0.017169493304348027), 'G_vs_p': np.float64(0.015323304231157575), 'G_vs_H': np.float64(-0.04567772205025156), 'H_vs_l': np.float64(0.04231571326716255), 'H_vs_o': np.float64(0.02850822874590353), 'H_vs_p': np.float64(0.06100102628140913), 'H_vs_G': np.float64(0.04567772205025156)}
# calculated offset warning successfully
# Amplitude metrics:
# 	Lower 5% percentile: 2.85 mJy, 15.11 mags
# 	Upper 5% percentile: 3.27 mJy, 15.26 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.42 mJy, 0.15 mags
# Amplitude metrics:
# 	Lower 1% percentile: 2.72 mJy, 15.07 mags
# 	Upper 1% percentile: 3.40 mJy, 15.31 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.68 mJy, 0.24 mags
# 	Largest amplitude of variability (g-band: True): 0.85 mJy, 0.31 mags
# 	Average amplitude across all periods: 0.750 mJy
# 	Standard deviation of amplitudes: 0.072 mJy
# 	Average amplitude (0.750 mJy) is greater than 5 sigma (0.072 mJy). This indicates consistent variability across periods.
# Target:  5
# loaded data successfully
# calculated mean and median successfully
# calculated chi-squared 95 successfully
# Offsets for object 5 (g-band: True):
# {'l_vs_o': np.float64(0.028941289371373635), 'l_vs_p': np.float64(0.05045753143898768), 'l_vs_G': np.float64(0.04095257655444673), 'l_vs_H': np.float64(-0.022086526058291867), 'o_vs_l': np.float64(-0.028941289371373635), 'o_vs_p': np.float64(0.021516242067614044), 'o_vs_G': np.float64(0.012011287183073094), 'o_vs_H': np.float64(-0.0510278154296655), 'p_vs_l': np.float64(-0.05045753143898768), 'p_vs_o': np.float64(-0.021516242067614044), 'p_vs_G': np.float64(-0.00950495488454095), 'p_vs_H': np.float64(-0.07254405749727955), 'G_vs_l': np.float64(-0.04095257655444673), 'G_vs_o': np.float64(-0.012011287183073094), 'G_vs_p': np.float64(0.00950495488454095), 'G_vs_H': np.float64(-0.0630391026127386), 'H_vs_l': np.float64(0.022086526058291867), 'H_vs_o': np.float64(0.0510278154296655), 'H_vs_p': np.float64(0.07254405749727955), 'H_vs_G': np.float64(0.0630391026127386)}
# calculated offset warning successfully
# Amplitude metrics:
# 	Lower 5% percentile: 5.29 mJy, 14.47 mags
# 	Upper 5% percentile: 5.89 mJy, 14.59 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.60 mJy, 0.12 mags
# Amplitude metrics:
# 	Lower 1% percentile: 5.16 mJy, 14.44 mags
# 	Upper 1% percentile: 6.05 mJy, 14.62 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.90 mJy, 0.17 mags
# 	Largest amplitude of variability (g-band: True): 1.34 mJy, 0.26 mags
# 	Average amplitude across all periods: 1.302 mJy
# 	Standard deviation of amplitudes: 0.041 mJy
# 	Average amplitude (1.302 mJy) is greater than 5 sigma (0.041 mJy). This indicates consistent variability across periods.
# Target:  6
# loaded data successfully
# calculated mean and median successfully
# calculated chi-squared 95 successfully
# Offsets for object 6 (g-band: True):
# {'l_vs_o': np.float64(-0.1574758187444223), 'l_vs_p': np.float64(0.16091736909256227), 'l_vs_G': np.float64(0.09947237637672668), 'l_vs_H': np.float64(-0.0488389694114133), 'o_vs_l': np.float64(0.1574758187444223), 'o_vs_p': np.float64(0.31839318783698456), 'o_vs_G': np.float64(0.25694819512114897), 'o_vs_H': np.float64(0.10863684933300899), 'p_vs_l': np.float64(-0.16091736909256227), 'p_vs_o': np.float64(-0.31839318783698456), 'p_vs_G': np.float64(-0.06144499271583559), 'p_vs_H': np.float64(-0.20975633850397557), 'G_vs_l': np.float64(-0.09947237637672668), 'G_vs_o': np.float64(-0.25694819512114897), 'G_vs_p': np.float64(0.06144499271583559), 'G_vs_H': np.float64(-0.14831134578813998), 'H_vs_l': np.float64(0.0488389694114133), 'H_vs_o': np.float64(-0.10863684933300899), 'H_vs_p': np.float64(0.20975633850397557), 'H_vs_G': np.float64(0.14831134578813998)}
# calculated offset warning successfully
# Amplitude metrics:
# 	Lower 5% percentile: 4.74 mJy, 13.87 mags
# 	Upper 5% percentile: 10.30 mJy, 14.71 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 5.56 mJy, 0.84 mags
# Amplitude metrics:
# 	Lower 1% percentile: 4.52 mJy, 13.82 mags
# 	Upper 1% percentile: 10.77 mJy, 14.76 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 6.25 mJy, 0.94 mags
# 	Largest amplitude of variability (g-band: True): 8.66 mJy, 1.59 mags
# 	Average amplitude across all periods: 5.668 mJy
# 	Standard deviation of amplitudes: 0.733 mJy
# 	Average amplitude (5.668 mJy) is greater than 5 sigma (0.733 mJy). This indicates consistent variability across periods.
# Target:  7
# loaded data successfully
# calculated mean and median successfully
# calculated chi-squared 95 successfully
# Offsets for object 7 (g-band: True):
# {'l_vs_p': np.float64(0.008482936204176283), 'l_vs_G': np.float64(-0.04066070543192879), 'l_vs_H': np.float64(-0.05891830653943764), 'p_vs_l': np.float64(-0.008482936204176283), 'p_vs_G': np.float64(-0.04914364163610507), 'p_vs_H': np.float64(-0.06740124274361392), 'G_vs_l': np.float64(0.04066070543192879), 'G_vs_p': np.float64(0.04914364163610507), 'G_vs_H': np.float64(-0.018257601107508847), 'H_vs_l': np.float64(0.05891830653943764), 'H_vs_p': np.float64(0.06740124274361392), 'H_vs_G': np.float64(0.018257601107508847)}
# calculated offset warning successfully
# Amplitude metrics:
# 	Lower 5% percentile: 3.90 mJy, 14.79 mags
# 	Upper 5% percentile: 4.39 mJy, 14.92 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.49 mJy, 0.13 mags
# Amplitude metrics:
# 	Lower 1% percentile: 3.76 mJy, 14.77 mags
# 	Upper 1% percentile: 4.49 mJy, 14.96 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.73 mJy, 0.19 mags
# 	Largest amplitude of variability (g-band: True): 0.98 mJy, 0.26 mags
# 	Average amplitude across all periods: 0.382 mJy
# 	Standard deviation of amplitudes: 0.160 mJy
# 	Warning: average amplitude (0.382 mJy) is less than 5 sigma (0.160 mJy). This indicates significant variability in the amplitudes across periods.
# Target:  8
# loaded data successfully
# calculated mean and median successfully
# calculated chi-squared 95 successfully
# Offsets for object 8 (g-band: True):
# {}
# calculated offset warning successfully
# Amplitude metrics:
# 	Lower 5% percentile: 24.63 mJy, 12.88 mags
# 	Upper 5% percentile: 25.64 mJy, 12.92 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 1.01 mJy, 0.04 mags
# Amplitude metrics:
# 	Lower 1% percentile: 24.39 mJy, 12.87 mags
# 	Upper 1% percentile: 25.85 mJy, 12.93 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 1.46 mJy, 0.06 mags
# 	Largest amplitude of variability (g-band: True): 2.40 mJy, 0.10 mags
# 	Average amplitude across all periods: 1.817 mJy
# 	Standard deviation of amplitudes: 0.355 mJy
# 	Average amplitude (1.817 mJy) is greater than 5 sigma (0.355 mJy). This indicates consistent variability across periods.
# Target:  9
# loaded data successfully
# calculated mean and median successfully
# calculated chi-squared 95 successfully
# Offsets for object 9 (g-band: True):
# {'l_vs_p': np.float64(0.07508787815758478), 'l_vs_H': np.float64(-0.01136733585289118), 'p_vs_l': np.float64(-0.07508787815758478), 'p_vs_H': np.float64(-0.08645521401047596), 'H_vs_l': np.float64(0.01136733585289118), 'H_vs_p': np.float64(0.08645521401047596)}
# calculated offset warning successfully
# Amplitude metrics:
# 	Lower 5% percentile: 5.57 mJy, 14.44 mags
# 	Upper 5% percentile: 6.10 mJy, 14.54 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.54 mJy, 0.10 mags
# Amplitude metrics:
# 	Lower 1% percentile: 5.44 mJy, 14.40 mags
# 	Upper 1% percentile: 6.28 mJy, 14.56 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.84 mJy, 0.16 mags
# 	Largest amplitude of variability (g-band: True): 1.06 mJy, 0.20 mags
# 	Average amplitude across all periods: 0.977 mJy
# 	Standard deviation of amplitudes: 0.071 mJy
# 	Average amplitude (0.977 mJy) is greater than 5 sigma (0.071 mJy). This indicates consistent variability across periods.
# Target:  10
# loaded data successfully
# calculated mean and median successfully
# calculated chi-squared 95 successfully
# Offsets for object 10 (g-band: True):
# {'l_vs_o': np.float64(-0.01959337014402962), 'l_vs_p': np.float64(0.0057380762857768275), 'l_vs_G': np.float64(0.10503782579361065), 'l_vs_H': np.float64(0.0013290263781282619), 'o_vs_l': np.float64(0.01959337014402962), 'o_vs_p': np.float64(0.025331446429806448), 'o_vs_G': np.float64(0.12463119593764027), 'o_vs_H': np.float64(0.020922396522157882), 'p_vs_l': np.float64(-0.0057380762857768275), 'p_vs_o': np.float64(-0.025331446429806448), 'p_vs_G': np.float64(0.09929974950783382), 'p_vs_H': np.float64(-0.004409049907648566), 'G_vs_l': np.float64(-0.10503782579361065), 'G_vs_o': np.float64(-0.12463119593764027), 'G_vs_p': np.float64(-0.09929974950783382), 'G_vs_H': np.float64(-0.10370879941548239), 'H_vs_l': np.float64(-0.0013290263781282619), 'H_vs_o': np.float64(-0.020922396522157882), 'H_vs_p': np.float64(0.004409049907648566), 'H_vs_G': np.float64(0.10370879941548239)}
# calculated offset warning successfully
# Amplitude metrics:
# 	Lower 5% percentile: 7.94 mJy, 14.03 mags
# 	Upper 5% percentile: 8.90 mJy, 14.15 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.95 mJy, 0.12 mags
# Amplitude metrics:
# 	Lower 1% percentile: 7.70 mJy, 14.00 mags
# 	Upper 1% percentile: 9.13 mJy, 14.18 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 1.43 mJy, 0.19 mags
# 	Largest amplitude of variability (g-band: True): 2.28 mJy, 0.30 mags
# 	Average amplitude across all periods: 2.173 mJy
# 	Standard deviation of amplitudes: 0.105 mJy
# 	Average amplitude (2.173 mJy) is greater than 5 sigma (0.105 mJy). This indicates consistent variability across periods.
# Target:  11
# loaded data successfully
# calculated mean and median successfully
# calculated chi-squared 95 successfully
# Offsets for object 11 (g-band: True):
# {'l_vs_p': np.float64(0.012007777085880633), 'l_vs_H': np.float64(-0.0007404753141937448), 'p_vs_l': np.float64(-0.012007777085880633), 'p_vs_H': np.float64(-0.012748252400074378), 'H_vs_l': np.float64(0.0007404753141937448), 'H_vs_p': np.float64(0.012748252400074378)}
# calculated offset warning successfully
# Amplitude metrics:
# 	Lower 5% percentile: 4.34 mJy, 14.71 mags
# 	Upper 5% percentile: 4.76 mJy, 14.81 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.43 mJy, 0.10 mags
# Amplitude metrics:
# 	Lower 1% percentile: 4.21 mJy, 14.68 mags
# 	Upper 1% percentile: 4.89 mJy, 14.84 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.68 mJy, 0.16 mags
# 	Largest amplitude of variability (g-band: True): 0.94 mJy, 0.22 mags
# 	Average amplitude across all periods: 0.930 mJy
# 	Standard deviation of amplitudes: 0.005 mJy
# 	Average amplitude (0.930 mJy) is greater than 5 sigma (0.005 mJy). This indicates consistent variability across periods.
# Target:  12
# loaded data successfully
# calculated mean and median successfully
# calculated chi-squared 95 successfully
# Offsets for object 12 (g-band: True):
# {'l_vs_p': np.float64(0.008705276965667252), 'l_vs_H': np.float64(0.12405088363755823), 'p_vs_l': np.float64(-0.008705276965667252), 'p_vs_H': np.float64(0.11534560667189098), 'H_vs_l': np.float64(-0.12405088363755823), 'H_vs_p': np.float64(-0.11534560667189098)}
# calculated offset warning successfully
# Amplitude metrics:
# 	Lower 5% percentile: 10.44 mJy, 13.79 mags
# 	Upper 5% percentile: 11.12 mJy, 13.85 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.68 mJy, 0.07 mags
# Amplitude metrics:
# 	Lower 1% percentile: 10.25 mJy, 13.77 mags
# 	Upper 1% percentile: 11.32 mJy, 13.87 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 1.07 mJy, 0.11 mags
# 	Largest amplitude of variability (g-band: True): 1.34 mJy, 0.13 mags
# 	Average amplitude across all periods: 1.171 mJy
# 	Standard deviation of amplitudes: 0.145 mJy
# 	Average amplitude (1.171 mJy) is greater than 5 sigma (0.145 mJy). This indicates consistent variability across periods.
# Target:  13
# loaded data successfully
# calculated mean and median successfully
# calculated chi-squared 95 successfully
# Offsets for object 13 (g-band: True):
# {'l_vs_p': np.float64(-0.009924288297246342), 'l_vs_G': np.float64(-0.07349364199874397), 'l_vs_H': np.float64(-0.03617733860462513), 'p_vs_l': np.float64(0.009924288297246342), 'p_vs_G': np.float64(-0.06356935370149763), 'p_vs_H': np.float64(-0.02625305030737879), 'G_vs_l': np.float64(0.07349364199874397), 'G_vs_p': np.float64(0.06356935370149763), 'G_vs_H': np.float64(0.037316303394118844), 'H_vs_l': np.float64(0.03617733860462513), 'H_vs_p': np.float64(0.02625305030737879), 'H_vs_G': np.float64(-0.037316303394118844)}
# calculated offset warning successfully
# Amplitude metrics:
# 	Lower 5% percentile: 3.53 mJy, 14.90 mags
# 	Upper 5% percentile: 3.98 mJy, 15.03 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.45 mJy, 0.13 mags
# Amplitude metrics:
# 	Lower 1% percentile: 3.39 mJy, 14.86 mags
# 	Upper 1% percentile: 4.12 mJy, 15.08 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.73 mJy, 0.21 mags
# 	Largest amplitude of variability (g-band: True): 0.94 mJy, 0.27 mags
# 	Average amplitude across all periods: 0.831 mJy
# 	Standard deviation of amplitudes: 0.059 mJy
# 	Average amplitude (0.831 mJy) is greater than 5 sigma (0.059 mJy). This indicates consistent variability across periods.
# Target:  14
# loaded data successfully
# calculated mean and median successfully
# calculated chi-squared 95 successfully
# Offsets for object 14 (g-band: True):
# {'l_vs_p': np.float64(0.07794313363893757), 'l_vs_H': np.float64(0.05848619829434121), 'p_vs_l': np.float64(-0.07794313363893757), 'p_vs_H': np.float64(-0.01945693534459636), 'H_vs_l': np.float64(-0.05848619829434121), 'H_vs_p': np.float64(0.01945693534459636)}
# calculated offset warning successfully
# Amplitude metrics:
# 	Lower 5% percentile: 9.72 mJy, 13.86 mags
# 	Upper 5% percentile: 10.42 mJy, 13.93 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.70 mJy, 0.08 mags
# Amplitude metrics:
# 	Lower 1% percentile: 9.56 mJy, 13.84 mags
# 	Upper 1% percentile: 10.60 mJy, 13.95 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 1.03 mJy, 0.11 mags
# 	Largest amplitude of variability (g-band: True): 1.61 mJy, 0.17 mags
# 	Average amplitude across all periods: 1.169 mJy
# 	Standard deviation of amplitudes: 0.227 mJy
# 	Average amplitude (1.169 mJy) is greater than 5 sigma (0.227 mJy). This indicates consistent variability across periods.
# Target:  15
# loaded data successfully
# calculated mean and median successfully
# calculated chi-squared 95 successfully
# Offsets for object 15 (g-band: True):
# {'l_vs_p': np.float64(0.007503050941670253), 'l_vs_H': np.float64(-0.08784291938872713), 'p_vs_l': np.float64(-0.007503050941670253), 'p_vs_H': np.float64(-0.09534597033039738), 'H_vs_l': np.float64(0.08784291938872713), 'H_vs_p': np.float64(0.09534597033039738)}
# calculated offset warning successfully
# Amplitude metrics:
# 	Lower 5% percentile: 4.46 mJy, 14.65 mags
# 	Upper 5% percentile: 5.02 mJy, 14.78 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.56 mJy, 0.13 mags
# Amplitude metrics:
# 	Lower 1% percentile: 4.31 mJy, 14.62 mags
# 	Upper 1% percentile: 5.17 mJy, 14.81 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.86 mJy, 0.20 mags
# 	Largest amplitude of variability (g-band: True): 1.17 mJy, 0.27 mags
# 	Average amplitude across all periods: 1.028 mJy
# 	Standard deviation of amplitudes: 0.116 mJy
# 	Average amplitude (1.028 mJy) is greater than 5 sigma (0.116 mJy). This indicates consistent variability across periods.
# Target:  16
# loaded data successfully
# calculated mean and median successfully
# calculated chi-squared 95 successfully
# Offsets for object 16 (g-band: True):
# {'l_vs_p': np.float64(0.24240754334945258), 'l_vs_H': np.float64(0.20153752560132343), 'p_vs_l': np.float64(-0.24240754334945258), 'p_vs_H': np.float64(-0.04087001774812915), 'H_vs_l': np.float64(-0.20153752560132343), 'H_vs_p': np.float64(0.04087001774812915)}
# calculated offset warning successfully
# Amplitude metrics:
# 	Lower 5% percentile: 5.69 mJy, 13.99 mags
# 	Upper 5% percentile: 9.17 mJy, 14.51 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 3.48 mJy, 0.52 mags
# Amplitude metrics:
# 	Lower 1% percentile: 5.45 mJy, 13.96 mags
# 	Upper 1% percentile: 9.48 mJy, 14.56 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 4.03 mJy, 0.60 mags
# 	Largest amplitude of variability (g-band: True): 6.34 mJy, 1.09 mags
# 	Average amplitude across all periods: 3.739 mJy
# 	Standard deviation of amplitudes: 0.469 mJy
# 	Average amplitude (3.739 mJy) is greater than 5 sigma (0.469 mJy). This indicates consistent variability across periods.
# Target:  17
# loaded data successfully
# calculated mean and median successfully
# calculated chi-squared 95 successfully
# Offsets for object 17 (g-band: True):
# {'i_vs_l': np.float64(-0.5058410796663342), 'i_vs_p': np.float64(-0.12607518983230293), 'i_vs_m': np.float64(-0.35218976737527186), 'i_vs_E': np.float64(0.05435560142935891), 'i_vs_H': np.float64(0.09713253833592006), 'l_vs_i': np.float64(0.5058410796663342), 'l_vs_p': np.float64(0.37976588983403126), 'l_vs_m': np.float64(0.15365131229106233), 'l_vs_E': np.float64(0.5601966810956931), 'l_vs_H': np.float64(0.6029736180022542), 'p_vs_i': np.float64(0.12607518983230293), 'p_vs_l': np.float64(-0.37976588983403126), 'p_vs_m': np.float64(-0.22611457754296893), 'p_vs_E': np.float64(0.18043079126166184), 'p_vs_H': np.float64(0.22320772816822299), 'm_vs_i': np.float64(0.35218976737527186), 'm_vs_l': np.float64(-0.15365131229106233), 'm_vs_p': np.float64(0.22611457754296893), 'm_vs_E': np.float64(0.40654536880463077), 'm_vs_H': np.float64(0.4493223057111919), 'E_vs_i': np.float64(-0.05435560142935891), 'E_vs_l': np.float64(-0.5601966810956931), 'E_vs_p': np.float64(-0.18043079126166184), 'E_vs_m': np.float64(-0.40654536880463077), 'E_vs_H': np.float64(0.04277693690656115), 'H_vs_i': np.float64(-0.09713253833592006), 'H_vs_l': np.float64(-0.6029736180022542), 'H_vs_p': np.float64(-0.22320772816822299), 'H_vs_m': np.float64(-0.4493223057111919), 'H_vs_E': np.float64(-0.04277693690656115)}
# calculated offset warning successfully
# Amplitude metrics:
# 	Lower 5% percentile: 5.49 mJy, 13.50 mags
# 	Upper 5% percentile: 14.44 mJy, 14.55 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 8.95 mJy, 1.05 mags
# Amplitude metrics:
# 	Lower 1% percentile: 5.26 mJy, 13.44 mags
# 	Upper 1% percentile: 15.29 mJy, 14.60 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 10.02 mJy, 1.16 mags
# 	Largest amplitude of variability (g-band: True): 10.98 mJy, 1.26 mags
# 	Average amplitude across all periods: 9.189 mJy
# 	Standard deviation of amplitudes: 1.203 mJy
# 	Average amplitude (9.189 mJy) is greater than 5 sigma (1.203 mJy). This indicates consistent variability across periods.
# Target:  18
# loaded data successfully
# calculated mean and median successfully
# calculated chi-squared 95 successfully
# Offsets for object 18 (g-band: True):
# {'l_vs_p': np.float64(-0.02916089861667981), 'l_vs_H': np.float64(-0.06401297410964979), 'p_vs_l': np.float64(0.02916089861667981), 'p_vs_H': np.float64(-0.03485207549296998), 'H_vs_l': np.float64(0.06401297410964979), 'H_vs_p': np.float64(0.03485207549296998)}
# calculated offset warning successfully
# Amplitude metrics:
# 	Lower 5% percentile: 5.12 mJy, 14.51 mags
# 	Upper 5% percentile: 5.71 mJy, 14.63 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.59 mJy, 0.12 mags
# Amplitude metrics:
# 	Lower 1% percentile: 4.94 mJy, 14.47 mags
# 	Upper 1% percentile: 5.93 mJy, 14.67 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.99 mJy, 0.20 mags
# 	Largest amplitude of variability (g-band: True): 1.33 mJy, 0.27 mags
# 	Average amplitude across all periods: 1.146 mJy
# 	Standard deviation of amplitudes: 0.158 mJy
# 	Average amplitude (1.146 mJy) is greater than 5 sigma (0.158 mJy). This indicates consistent variability across periods.
# Target:  19
# loaded data successfully
# calculated mean and median successfully
# calculated chi-squared 95 successfully
# Offsets for object 19 (g-band: True):
# {'l_vs_p': np.float64(0.15678264139689269), 'l_vs_H': np.float64(0.22160583010418655), 'p_vs_l': np.float64(-0.15678264139689269), 'p_vs_H': np.float64(0.06482318870729387), 'H_vs_l': np.float64(-0.22160583010418655), 'H_vs_p': np.float64(-0.06482318870729387)}
# calculated offset warning successfully
# Amplitude metrics:
# 	Lower 5% percentile: 5.42 mJy, 13.68 mags
# 	Upper 5% percentile: 12.29 mJy, 14.57 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 6.87 mJy, 0.89 mags
# Amplitude metrics:
# 	Lower 1% percentile: 5.20 mJy, 13.62 mags
# 	Upper 1% percentile: 12.93 mJy, 14.61 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 7.72 mJy, 0.99 mags
# 	Largest amplitude of variability (g-band: True): 9.09 mJy, 1.16 mags
# 	Average amplitude across all periods: 7.121 mJy
# 	Standard deviation of amplitudes: 0.704 mJy
# 	Average amplitude (7.121 mJy) is greater than 5 sigma (0.704 mJy). This indicates consistent variability across periods.
# Target:  20
# loaded data successfully
# calculated mean and median successfully
# calculated chi-squared 95 successfully
# Offsets for object 20 (g-band: True):
# {'l_vs_p': np.float64(-0.016031176137770053), 'l_vs_H': np.float64(-0.09998413752346114), 'p_vs_l': np.float64(0.016031176137770053), 'p_vs_H': np.float64(-0.08395296138569108), 'H_vs_l': np.float64(0.09998413752346114), 'H_vs_p': np.float64(0.08395296138569108)}
# calculated offset warning successfully
# Amplitude metrics:
# 	Lower 5% percentile: 3.88 mJy, 14.81 mags
# 	Upper 5% percentile: 4.34 mJy, 14.93 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.46 mJy, 0.12 mags
# Amplitude metrics:
# 	Lower 1% percentile: 3.76 mJy, 14.77 mags
# 	Upper 1% percentile: 4.47 mJy, 14.96 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.71 mJy, 0.19 mags
# 	Largest amplitude of variability (g-band: True): 1.00 mJy, 0.26 mags
# 	Average amplitude across all periods: 0.811 mJy
# 	Standard deviation of amplitudes: 0.069 mJy
# 	Average amplitude (0.811 mJy) is greater than 5 sigma (0.069 mJy). This indicates consistent variability across periods.
# Target:  21
# loaded data successfully
# calculated mean and median successfully
# calculated chi-squared 95 successfully
# Offsets for object 21 (g-band: True):
# {'l_vs_p': np.float64(-0.0018801024689185653), 'l_vs_H': np.float64(-0.09704816425643692), 'p_vs_l': np.float64(0.0018801024689185653), 'p_vs_H': np.float64(-0.09516806178751835), 'H_vs_l': np.float64(0.09704816425643692), 'H_vs_p': np.float64(0.09516806178751835)}
# calculated offset warning successfully
# Amplitude metrics:
# 	Lower 5% percentile: 4.08 mJy, 14.74 mags
# 	Upper 5% percentile: 4.60 mJy, 14.87 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.52 mJy, 0.13 mags
# Amplitude metrics:
# 	Lower 1% percentile: 3.92 mJy, 14.70 mags
# 	Upper 1% percentile: 4.78 mJy, 14.92 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.86 mJy, 0.22 mags
# 	Largest amplitude of variability (g-band: True): 1.14 mJy, 0.29 mags
# 	Average amplitude across all periods: 0.914 mJy
# 	Standard deviation of amplitudes: 0.137 mJy
# 	Average amplitude (0.914 mJy) is greater than 5 sigma (0.137 mJy). This indicates consistent variability across periods.
# Target:  22
# loaded data successfully
# calculated mean and median successfully
# calculated chi-squared 95 successfully
# Offsets for object 22 (g-band: True):
# {'l_vs_p': np.float64(-0.021247779619091745), 'l_vs_H': np.float64(-0.049054344312230214), 'p_vs_l': np.float64(0.021247779619091745), 'p_vs_H': np.float64(-0.02780656469313847), 'H_vs_l': np.float64(0.049054344312230214), 'H_vs_p': np.float64(0.02780656469313847)}
# calculated offset warning successfully
# Amplitude metrics:
# 	Lower 5% percentile: 14.18 mJy, 13.47 mags
# 	Upper 5% percentile: 14.91 mJy, 13.52 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.73 mJy, 0.05 mags
# Amplitude metrics:
# 	Lower 1% percentile: 13.99 mJy, 13.45 mags
# 	Upper 1% percentile: 15.14 mJy, 13.54 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 1.15 mJy, 0.09 mags
# 	Largest amplitude of variability (g-band: True): 1.48 mJy, 0.11 mags
# 	Average amplitude across all periods: 1.238 mJy
# 	Standard deviation of amplitudes: 0.217 mJy
# 	Average amplitude (1.238 mJy) is greater than 5 sigma (0.217 mJy). This indicates consistent variability across periods.
# Target:  23
# loaded data successfully
# calculated mean and median successfully
# calculated chi-squared 95 successfully
# Offsets for object 23 (g-band: True):
# {'l_vs_p': np.float64(0.05926915575329694), 'l_vs_H': np.float64(0.10638506364009004), 'p_vs_l': np.float64(-0.05926915575329694), 'p_vs_H': np.float64(0.047115907886793096), 'H_vs_l': np.float64(-0.10638506364009004), 'H_vs_p': np.float64(-0.047115907886793096)}
# calculated offset warning successfully
# Amplitude metrics:
# 	Lower 5% percentile: 10.01 mJy, 13.84 mags
# 	Upper 5% percentile: 10.60 mJy, 13.90 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.59 mJy, 0.06 mags
# Amplitude metrics:
# 	Lower 1% percentile: 9.82 mJy, 13.82 mags
# 	Upper 1% percentile: 10.78 mJy, 13.92 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.97 mJy, 0.10 mags
# 	Largest amplitude of variability (g-band: True): 1.36 mJy, 0.14 mags
# 	Average amplitude across all periods: 1.262 mJy
# 	Standard deviation of amplitudes: 0.075 mJy
# 	Average amplitude (1.262 mJy) is greater than 5 sigma (0.075 mJy). This indicates consistent variability across periods.
# Target:  24
# loaded data successfully
# calculated mean and median successfully
# calculated chi-squared 95 successfully
# Offsets for object 24 (g-band: True):
# {'l_vs_p': np.float64(0.566997891593835), 'l_vs_H': np.float64(0.5358898460521075), 'p_vs_l': np.float64(-0.566997891593835), 'p_vs_H': np.float64(-0.031108045541727414), 'H_vs_l': np.float64(-0.5358898460521075), 'H_vs_p': np.float64(0.031108045541727414)}
# calculated offset warning successfully
# Amplitude metrics:
# 	Lower 5% percentile: 4.32 mJy, 13.61 mags
# 	Upper 5% percentile: 13.11 mJy, 14.81 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 8.80 mJy, 1.21 mags
# Amplitude metrics:
# 	Lower 1% percentile: 4.04 mJy, 13.54 mags
# 	Upper 1% percentile: 13.92 mJy, 14.88 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 9.88 mJy, 1.34 mags
# 	Largest amplitude of variability (g-band: True): 12.57 mJy, 1.82 mags
# 	Average amplitude across all periods: 9.310 mJy
# 	Standard deviation of amplitudes: 0.947 mJy
# 	Average amplitude (9.310 mJy) is greater than 5 sigma (0.947 mJy). This indicates consistent variability across periods.
# Target:  25
# loaded data successfully
# calculated mean and median successfully
# calculated chi-squared 95 successfully
# Offsets for object 25 (g-band: True):
# {'l_vs_p': np.float64(-0.039675765985400346), 'l_vs_H': np.float64(-0.13781860326064788), 'p_vs_l': np.float64(0.039675765985400346), 'p_vs_H': np.float64(-0.09814283727524753), 'H_vs_l': np.float64(0.13781860326064788), 'H_vs_p': np.float64(0.09814283727524753)}
# calculated offset warning successfully
# Amplitude metrics:
# 	Lower 5% percentile: 5.39 mJy, 14.45 mags
# 	Upper 5% percentile: 6.03 mJy, 14.57 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.64 mJy, 0.12 mags
# Amplitude metrics:
# 	Lower 1% percentile: 5.23 mJy, 14.42 mags
# 	Upper 1% percentile: 6.22 mJy, 14.60 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.99 mJy, 0.19 mags
# 	Largest amplitude of variability (g-band: True): 1.37 mJy, 0.26 mags
# 	Average amplitude across all periods: 1.184 mJy
# 	Standard deviation of amplitudes: 0.120 mJy
# 	Average amplitude (1.184 mJy) is greater than 5 sigma (0.120 mJy). This indicates consistent variability across periods.
# Target:  26
# loaded data successfully
# calculated mean and median successfully
# calculated chi-squared 95 successfully
# Offsets for object 26 (g-band: True):
# {'l_vs_p': np.float64(-0.009545909307227873), 'l_vs_H': np.float64(-0.03402423728173165), 'p_vs_l': np.float64(0.009545909307227873), 'p_vs_H': np.float64(-0.024478327974503777), 'H_vs_l': np.float64(0.03402423728173165), 'H_vs_p': np.float64(0.024478327974503777)}
# calculated offset warning successfully
# Amplitude metrics:
# 	Lower 5% percentile: 4.88 mJy, 14.57 mags
# 	Upper 5% percentile: 5.41 mJy, 14.68 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.53 mJy, 0.11 mags
# Amplitude metrics:
# 	Lower 1% percentile: 4.74 mJy, 14.54 mags
# 	Upper 1% percentile: 5.55 mJy, 14.71 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.81 mJy, 0.17 mags
# 	Largest amplitude of variability (g-band: True): 1.12 mJy, 0.24 mags
# 	Average amplitude across all periods: 0.932 mJy
# 	Standard deviation of amplitudes: 0.141 mJy
# 	Average amplitude (0.932 mJy) is greater than 5 sigma (0.141 mJy). This indicates consistent variability across periods.
# Target:  27
# loaded data successfully
# calculated mean and median successfully
# calculated chi-squared 95 successfully
# Offsets for object 27 (g-band: True):
# {'l_vs_p': np.float64(0.0019846838375512377), 'l_vs_H': np.float64(-0.030765378687576117), 'p_vs_l': np.float64(-0.0019846838375512377), 'p_vs_H': np.float64(-0.032750062525127355), 'H_vs_l': np.float64(0.030765378687576117), 'H_vs_p': np.float64(0.032750062525127355)}
# calculated offset warning successfully
# Amplitude metrics:
# 	Lower 5% percentile: 4.05 mJy, 14.75 mags
# 	Upper 5% percentile: 4.55 mJy, 14.88 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.50 mJy, 0.13 mags
# Amplitude metrics:
# 	Lower 1% percentile: 3.92 mJy, 14.72 mags
# 	Upper 1% percentile: 4.68 mJy, 14.92 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.76 mJy, 0.19 mags
# 	Largest amplitude of variability (g-band: True): 1.08 mJy, 0.28 mags
# 	Average amplitude across all periods: 0.963 mJy
# 	Standard deviation of amplitudes: 0.139 mJy
# 	Average amplitude (0.963 mJy) is greater than 5 sigma (0.139 mJy). This indicates consistent variability across periods.
# Target:  28
# loaded data successfully
# calculated mean and median successfully
# calculated chi-squared 95 successfully
# Offsets for object 28 (g-band: True):
# {'l_vs_p': np.float64(0.043304081974790964), 'l_vs_H': np.float64(-0.03013071639221243), 'p_vs_l': np.float64(-0.043304081974790964), 'p_vs_H': np.float64(-0.0734347983670034), 'H_vs_l': np.float64(0.03013071639221243), 'H_vs_p': np.float64(0.0734347983670034)}
# calculated offset warning successfully
# Amplitude metrics:
# 	Lower 5% percentile: 3.12 mJy, 14.97 mags
# 	Upper 5% percentile: 3.74 mJy, 15.17 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.62 mJy, 0.20 mags
# Amplitude metrics:
# 	Lower 1% percentile: 2.99 mJy, 14.93 mags
# 	Upper 1% percentile: 3.87 mJy, 15.21 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.88 mJy, 0.28 mags
# 	Largest amplitude of variability (g-band: True): 1.28 mJy, 0.41 mags
# 	Average amplitude across all periods: 1.049 mJy
# 	Standard deviation of amplitudes: 0.162 mJy
# 	Average amplitude (1.049 mJy) is greater than 5 sigma (0.162 mJy). This indicates consistent variability across periods.
# Target:  29
# loaded data successfully
# calculated mean and median successfully
# calculated chi-squared 95 successfully
# Offsets for object 29 (g-band: True):
# {'l_vs_p': np.float64(0.03308972633757801), 'l_vs_H': np.float64(0.037624570370612176), 'p_vs_l': np.float64(-0.03308972633757801), 'p_vs_H': np.float64(0.004534844033034169), 'H_vs_l': np.float64(-0.037624570370612176), 'H_vs_p': np.float64(-0.004534844033034169)}
# calculated offset warning successfully
# Amplitude metrics:
# 	Lower 5% percentile: 4.68 mJy, 14.62 mags
# 	Upper 5% percentile: 5.17 mJy, 14.72 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.48 mJy, 0.11 mags
# Amplitude metrics:
# 	Lower 1% percentile: 4.53 mJy, 14.59 mags
# 	Upper 1% percentile: 5.31 mJy, 14.76 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.78 mJy, 0.17 mags
# 	Largest amplitude of variability (g-band: True): 1.01 mJy, 0.22 mags
# 	Average amplitude across all periods: 0.976 mJy
# 	Standard deviation of amplitudes: 0.023 mJy
# 	Average amplitude (0.976 mJy) is greater than 5 sigma (0.023 mJy). This indicates consistent variability across periods.
# Target:  30
# loaded data successfully
# calculated mean and median successfully
# calculated chi-squared 95 successfully
# Offsets for object 30 (g-band: True):
# {'l_vs_p': np.float64(-0.0045007880779692755), 'l_vs_H': np.float64(-0.11142366526169933), 'p_vs_l': np.float64(0.0045007880779692755), 'p_vs_H': np.float64(-0.10692287718373006), 'H_vs_l': np.float64(0.11142366526169933), 'H_vs_p': np.float64(0.10692287718373006)}
# calculated offset warning successfully
# Amplitude metrics:
# 	Lower 5% percentile: 6.66 mJy, 14.25 mags
# 	Upper 5% percentile: 7.27 mJy, 14.34 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.61 mJy, 0.09 mags
# Amplitude metrics:
# 	Lower 1% percentile: 6.45 mJy, 14.22 mags
# 	Upper 1% percentile: 7.44 mJy, 14.38 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.99 mJy, 0.15 mags
# 	Largest amplitude of variability (g-band: True): 1.28 mJy, 0.20 mags
# 	Average amplitude across all periods: 1.026 mJy
# 	Standard deviation of amplitudes: 0.118 mJy
# 	Average amplitude (1.026 mJy) is greater than 5 sigma (0.118 mJy). This indicates consistent variability across periods.
# Target:  31
# loaded data successfully
# calculated mean and median successfully
# calculated chi-squared 95 successfully
# Offsets for object 31 (g-band: True):
# {'l_vs_p': np.float64(0.006968264288996551), 'l_vs_H': np.float64(0.11595768472167123), 'p_vs_l': np.float64(-0.006968264288996551), 'p_vs_H': np.float64(0.10898942043267468), 'H_vs_l': np.float64(-0.11595768472167123), 'H_vs_p': np.float64(-0.10898942043267468)}
# calculated offset warning successfully
# Amplitude metrics:
# 	Lower 5% percentile: 22.29 mJy, 12.98 mags
# 	Upper 5% percentile: 23.39 mJy, 13.03 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 1.10 mJy, 0.05 mags
# Amplitude metrics:
# 	Lower 1% percentile: 21.99 mJy, 12.97 mags
# 	Upper 1% percentile: 23.63 mJy, 13.04 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 1.64 mJy, 0.08 mags
# 	Largest amplitude of variability (g-band: True): 2.35 mJy, 0.11 mags
# 	Average amplitude across all periods: 2.000 mJy
# 	Standard deviation of amplitudes: 0.145 mJy
# 	Average amplitude (2.000 mJy) is greater than 5 sigma (0.145 mJy). This indicates consistent variability across periods.
# Target:  32
# loaded data successfully
# calculated mean and median successfully
# calculated chi-squared 95 successfully
# Offsets for object 32 (g-band: True):
# {}
# calculated offset warning successfully
# Target 32 failed: index -1 is out of bounds for axis 0 with size 0
# Target:  33
# loaded data successfully
# calculated mean and median successfully
# calculated chi-squared 95 successfully
# Traceback (most recent call last):
#   File "/var/folders/34/3847lqd14j78mfm70_z1c_r00000gn/T/ipykernel_72537/2197387227.py", line 46, in <module>
#     amplitude_5, lower_percentile_5, upper_percentile_5, mag_amplitude_5 = percentile_amplitude(target, df=df, telescopes=telescopes, tails=5)
#                                                                            ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/shannonbowes/Research/ysg/candidates_and_lcs/2022_asassn_lc_data/metrics.py", line 358, in percentile_amplitude
#     lower_percentile = np.percentile(fluxes, 0+tails)
#   File "/opt/anaconda3/envs/ysg/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py", line 4273, in percentile
#     return _quantile_unchecked(
#         a, q, axis, out, overwrite_input, method, keepdims, weights)
#   File "/opt/anaconda3/envs/ysg/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py", line 4550, in _quantile_unchecked
#     return _ureduce(a,
#                     func=_quantile_ureduce_func,
#     ...<5 lines>...
#                     overwrite_input=overwrite_input,
#                     method=method)
#   File "/opt/anaconda3/envs/ysg/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py", line 3894, in _ureduce
#     r = func(a, **kwargs)
#   File "/opt/anaconda3/envs/ysg/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py", line 4727, in _quantile_ureduce_func
#     result = _quantile(arr,
#                        quantiles=q,
#     ...<2 lines>...
#                        out=out,
#                        weights=wgt)
#   File "/opt/anaconda3/envs/ysg/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py", line 4849, in _quantile
#     slices_having_nans = np.isnan(arr[-1, ...])
#                                   ~~~^^^^^^^^^
# IndexError: index -1 is out of bounds for axis 0 with size 0
# Offsets for object 33 (g-band: True):
# {'l_vs_p': np.float64(-0.020885918440146867), 'l_vs_H': np.float64(0.08124925899387847), 'p_vs_l': np.float64(0.020885918440146867), 'p_vs_H': np.float64(0.10213517743402534), 'H_vs_l': np.float64(-0.08124925899387847), 'H_vs_p': np.float64(-0.10213517743402534)}
# calculated offset warning successfully
# Amplitude metrics:
# 	Lower 5% percentile: 15.76 mJy, 13.35 mags
# 	Upper 5% percentile: 16.61 mJy, 13.41 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.85 mJy, 0.06 mags
# Amplitude metrics:
# 	Lower 1% percentile: 15.60 mJy, 13.34 mags
# 	Upper 1% percentile: 16.82 mJy, 13.42 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 1.22 mJy, 0.08 mags
# 	Largest amplitude of variability (g-band: True): 1.79 mJy, 0.12 mags
# 	Average amplitude across all periods: 1.421 mJy
# 	Standard deviation of amplitudes: 0.144 mJy
# 	Average amplitude (1.421 mJy) is greater than 5 sigma (0.144 mJy). This indicates consistent variability across periods.
# Target:  34
# loaded data successfully
# calculated mean and median successfully
# calculated chi-squared 95 successfully
# Offsets for object 34 (g-band: True):
# {'l_vs_p': np.float64(0.01288748129016426), 'l_vs_H': np.float64(0.19115375756295627), 'p_vs_l': np.float64(-0.01288748129016426), 'p_vs_H': np.float64(0.178266276272792), 'H_vs_l': np.float64(-0.19115375756295627), 'H_vs_p': np.float64(-0.178266276272792)}
# calculated offset warning successfully
# Amplitude metrics:
# 	Lower 5% percentile: 13.26 mJy, 13.53 mags
# 	Upper 5% percentile: 14.06 mJy, 13.59 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.80 mJy, 0.06 mags
# Amplitude metrics:
# 	Lower 1% percentile: 13.08 mJy, 13.51 mags
# 	Upper 1% percentile: 14.28 mJy, 13.61 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 1.20 mJy, 0.10 mags
# 	Largest amplitude of variability (g-band: True): 1.77 mJy, 0.14 mags
# 	Average amplitude across all periods: 1.511 mJy
# 	Standard deviation of amplitudes: 0.050 mJy
# 	Average amplitude (1.511 mJy) is greater than 5 sigma (0.050 mJy). This indicates consistent variability across periods.
# Target:  35
# loaded data successfully
# calculated mean and median successfully
# calculated chi-squared 95 successfully
# Offsets for object 35 (g-band: True):
# {'l_vs_p': np.float64(-0.02167174738757982), 'l_vs_H': np.float64(-0.018446965424533168), 'p_vs_l': np.float64(0.02167174738757982), 'p_vs_H': np.float64(0.0032247819630466523), 'H_vs_l': np.float64(0.018446965424533168), 'H_vs_p': np.float64(-0.0032247819630466523)}
# calculated offset warning successfully
# Amplitude metrics:
# 	Lower 5% percentile: 3.41 mJy, 14.95 mags
# 	Upper 5% percentile: 3.81 mJy, 15.07 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.40 mJy, 0.12 mags
# Amplitude metrics:
# 	Lower 1% percentile: 3.30 mJy, 14.91 mags
# 	Upper 1% percentile: 3.93 mJy, 15.10 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.63 mJy, 0.19 mags
# 	Largest amplitude of variability (g-band: True): 0.86 mJy, 0.26 mags
# 	Average amplitude across all periods: 0.735 mJy
# 	Standard deviation of amplitudes: 0.101 mJy
# 	Average amplitude (0.735 mJy) is greater than 5 sigma (0.101 mJy). This indicates consistent variability across periods.
# Target:  36
# loaded data successfully
# calculated mean and median successfully
# calculated chi-squared 95 successfully
# Offsets for object 36 (g-band: True):
# {'l_vs_p': np.float64(-0.48540968864555367), 'l_vs_H': np.float64(-0.5447396781259215), 'p_vs_l': np.float64(0.48540968864555367), 'p_vs_H': np.float64(-0.05932998948036783), 'H_vs_l': np.float64(0.5447396781259215), 'H_vs_p': np.float64(0.05932998948036783)}
# calculated offset warning successfully
# Amplitude metrics:
# 	Lower 5% percentile: 16.97 mJy, 12.27 mags
# 	Upper 5% percentile: 44.98 mJy, 13.33 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 28.01 mJy, 1.06 mags
# Amplitude metrics:
# 	Lower 1% percentile: 16.18 mJy, 12.24 mags
# 	Upper 1% percentile: 46.35 mJy, 13.38 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 30.17 mJy, 1.14 mags
# 	Largest amplitude of variability (g-band: True): 31.89 mJy, 1.22 mags
# 	Average amplitude across all periods: 28.375 mJy
# 	Standard deviation of amplitudes: 4.116 mJy
# 	Average amplitude (28.375 mJy) is greater than 5 sigma (4.116 mJy). This indicates consistent variability across periods.
# Target:  37
# loaded data successfully
# calculated mean and median successfully
# calculated chi-squared 95 successfully
# Offsets for object 37 (g-band: True):
# {'l_vs_p': np.float64(-0.03036369108037107), 'l_vs_H': np.float64(-0.0005206493080613939), 'p_vs_l': np.float64(0.03036369108037107), 'p_vs_H': np.float64(0.029843041772309675), 'H_vs_l': np.float64(0.0005206493080613939), 'H_vs_p': np.float64(-0.029843041772309675)}
# calculated offset warning successfully
# Amplitude metrics:
# 	Lower 5% percentile: 18.23 mJy, 13.19 mags
# 	Upper 5% percentile: 19.19 mJy, 13.25 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.96 mJy, 0.06 mags
# Amplitude metrics:
# 	Lower 1% percentile: 18.04 mJy, 13.18 mags
# 	Upper 1% percentile: 19.43 mJy, 13.26 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 1.39 mJy, 0.08 mags
# 	Largest amplitude of variability (g-band: True): 2.09 mJy, 0.12 mags
# 	Average amplitude across all periods: 1.810 mJy
# 	Standard deviation of amplitudes: 0.219 mJy
# 	Average amplitude (1.810 mJy) is greater than 5 sigma (0.219 mJy). This indicates consistent variability across periods.
# Target:  38
# loaded data successfully
# calculated mean and median successfully
# calculated chi-squared 95 successfully
# Offsets for object 38 (g-band: True):
# {'l_vs_p': np.float64(0.024347344026335094), 'l_vs_H': np.float64(0.015198121290730171), 'p_vs_l': np.float64(-0.024347344026335094), 'p_vs_H': np.float64(-0.009149222735604923), 'H_vs_l': np.float64(-0.015198121290730171), 'H_vs_p': np.float64(0.009149222735604923)}
# calculated offset warning successfully
# Amplitude metrics:
# 	Lower 5% percentile: 16.22 mJy, 13.32 mags
# 	Upper 5% percentile: 17.03 mJy, 13.38 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.81 mJy, 0.05 mags
# Amplitude metrics:
# 	Lower 1% percentile: 16.01 mJy, 13.31 mags
# 	Upper 1% percentile: 17.21 mJy, 13.39 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 1.20 mJy, 0.08 mags
# 	Largest amplitude of variability (g-band: True): 1.79 mJy, 0.12 mags
# 	Average amplitude across all periods: 1.140 mJy
# 	Standard deviation of amplitudes: 0.238 mJy
# 	Warning: average amplitude (1.140 mJy) is less than 5 sigma (0.238 mJy). This indicates significant variability in the amplitudes across periods.
# Target:  39
# loaded data successfully
# calculated mean and median successfully
# calculated chi-squared 95 successfully
# Offsets for object 39 (g-band: True):
# {'l_vs_p': np.float64(-0.06948300711847288), 'l_vs_H': np.float64(-0.13431150032559458), 'p_vs_l': np.float64(0.06948300711847288), 'p_vs_H': np.float64(-0.0648284932071217), 'H_vs_l': np.float64(0.13431150032559458), 'H_vs_p': np.float64(0.0648284932071217)}
# calculated offset warning successfully
# Amplitude metrics:
# 	Lower 5% percentile: 8.39 mJy, 14.01 mags
# 	Upper 5% percentile: 9.04 mJy, 14.09 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.65 mJy, 0.08 mags
# Amplitude metrics:
# 	Lower 1% percentile: 8.24 mJy, 13.99 mags
# 	Upper 1% percentile: 9.24 mJy, 14.11 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 1.00 mJy, 0.12 mags
# 	Largest amplitude of variability (g-band: True): 1.39 mJy, 0.17 mags
# 	Average amplitude across all periods: 1.151 mJy
# 	Standard deviation of amplitudes: 0.164 mJy
# 	Average amplitude (1.151 mJy) is greater than 5 sigma (0.164 mJy). This indicates consistent variability across periods.
# Target:  40
# loaded data successfully
# calculated mean and median successfully
# calculated chi-squared 95 successfully
# Offsets for object 40 (g-band: True):
# {'l_vs_p': np.float64(0.10779802560155716), 'l_vs_H': np.float64(0.07446312132896615), 'p_vs_l': np.float64(-0.10779802560155716), 'p_vs_H': np.float64(-0.033334904272591004), 'H_vs_l': np.float64(-0.07446312132896615), 'H_vs_p': np.float64(0.033334904272591004)}
# calculated offset warning successfully
# Amplitude metrics:
# 	Lower 5% percentile: 14.46 mJy, 13.42 mags
# 	Upper 5% percentile: 15.53 mJy, 13.50 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 1.07 mJy, 0.08 mags
# Amplitude metrics:
# 	Lower 1% percentile: 14.23 mJy, 13.41 mags
# 	Upper 1% percentile: 15.78 mJy, 13.52 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 1.55 mJy, 0.11 mags
# 	Largest amplitude of variability (g-band: True): 2.21 mJy, 0.16 mags
# 	Average amplitude across all periods: 1.739 mJy
# 	Standard deviation of amplitudes: 0.297 mJy
# 	Average amplitude (1.739 mJy) is greater than 5 sigma (0.297 mJy). This indicates consistent variability across periods.
# Target:  41
# loaded data successfully
# calculated mean and median successfully
# calculated chi-squared 95 successfully
# Offsets for object 41 (g-band: True):
# {'l_vs_p': np.float64(-0.28100698243234046), 'l_vs_H': np.float64(-0.3150029530134324), 'p_vs_l': np.float64(0.28100698243234046), 'p_vs_H': np.float64(-0.03399597058109194), 'H_vs_l': np.float64(0.3150029530134324), 'H_vs_p': np.float64(0.03399597058109194)}
# calculated offset warning successfully
# Amplitude metrics:
# 	Lower 5% percentile: 3.31 mJy, 13.99 mags
# 	Upper 5% percentile: 9.20 mJy, 15.10 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 5.88 mJy, 1.11 mags
# Amplitude metrics:
# 	Lower 1% percentile: 3.18 mJy, 13.93 mags
# 	Upper 1% percentile: 9.75 mJy, 15.14 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 6.57 mJy, 1.22 mags
# 	Largest amplitude of variability (g-band: True): 9.13 mJy, 1.73 mags
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 49
#      47 amplitude_1, lower_percentile_1, upper_percentile_1, mag_amplitude_1 = percentile_amplitude(target, df=df, telescopes=telescopes, tails=1)
#      48 largest_amp, largest_amp_mag = largest_amplitude(target, df=df, telescopes=telescopes)
# ---> 49 lombs = compute_lomb_scargle(target, df=df, telescopes=telescopes, auto=False, median=False, subtract_median=False, samples_per_peak=10, report=False)
#      50 best_period = lombs['best_period']
#      51 alarm_level_flag = lombs['alarm_level_flag']
#
# File ~/Research/ysg/candidates_and_lcs/2022_asassn_lc_data/metrics.py:527, in compute_lomb_scargle(index, df, telescopes, g, auto, median, samples_per_peak, report, show, subtract_median, correct_offsets)
#     524 if auto is not True:
#     525     frequency = np.linspace(min_freq, max_freq,
#     526                           int((max_freq - min_freq) * len(time) * samples_per_peak))
# --> 527     power = ls.power(frequency)
#     528 else:
#     529     frequency, power = ls.autopower(samples_per_peak=samples_per_peak)
#
# File /opt/anaconda3/envs/ysg/lib/python3.13/site-packages/astropy/timeseries/periodograms/lombscargle/core.py:381, in LombScargle.power(self, frequency, normalization, method, assume_regular_frequency, method_kwds)
#     379     normalization = self.normalization
#     380 frequency = self._validate_frequency(frequency)
# --> 381 power = lombscargle(
#     382     *strip_units(self._trel, self.y, self.dy),
#     383     frequency=strip_units(frequency),
#     384     center_data=self.center_data,
#     385     fit_mean=self.fit_mean,
#     386     nterms=self.nterms,
#     387     normalization=normalization,
#     388     method=method,
#     389     method_kwds=method_kwds,
#     390     assume_regular_frequency=assume_regular_frequency,
#     391 )
#     392 return power * self._power_unit(normalization)
#
# File /opt/anaconda3/envs/ysg/lib/python3.13/site-packages/astropy/timeseries/periodograms/lombscargle/implementations/main.py:228, in lombscargle(t, y, dy, frequency, method, assume_regular_frequency, normalization, fit_mean, center_data, method_kwds, nterms)
#     223     if kwds.pop("nterms") != 1:
#     224         raise ValueError(
#     225             "nterms != 1 only supported with 'chi2' or 'fastchi2' methods"
#     226         )
# --> 228 PLS = METHODS[method](*args, **kwds)
#     229 return PLS.reshape(output_shape)
#
# File /opt/anaconda3/envs/ysg/lib/python3.13/site-packages/astropy/timeseries/periodograms/lombscargle/implementations/fast_impl.py:98, in lombscargle_fast(t, y, dy, f0, df, Nf, center_data, fit_mean, normalization, use_fft, trig_sum_kwds)
#      95 # ----------------------------------------------------------------------
#      96 # 1. compute functions of the time-shift tau at each frequency
#      97 Sh, Ch = trig_sum(t, w * y, **kwargs)
# ---> 98 S2, C2 = trig_sum(t, w, freq_factor=2, **kwargs)
#     100 if fit_mean:
#     101     S, C = trig_sum(t, w, **kwargs)
#
# File /opt/anaconda3/envs/ysg/lib/python3.13/site-packages/astropy/timeseries/periodograms/lombscargle/implementations/utils.py:147, in trig_sum(t, h, df, N, f0, freq_factor, oversampling, use_fft, Mfft)
#     144 tnorm = ((t - t0) * Nfft * df) % Nfft
#     145 grid = extirpolate(tnorm, h, Nfft, Mfft)
# --> 147 fftgrid = np.fft.ifft(grid)[:N]
#     148 if t0 != 0:
#     149     f = f0 + df * np.arange(N)
#
# File /opt/anaconda3/envs/ysg/lib/python3.13/site-packages/numpy/fft/_pocketfft.py:314, in ifft(a, n, axis, norm, out)
#     312 if n is None:
#     313     n = a.shape[axis]
# --> 314 output = _raw_fft(a, n, axis, False, False, norm, out=out)
#     315 return output
#
# File /opt/anaconda3/envs/ysg/lib/python3.13/site-packages/numpy/fft/_pocketfft.py:88, in _raw_fft(a, n, axis, is_real, is_forward, norm, out)
#      86     else:  # Others, complex output.
#      87         out_dtype = result_type(a.dtype, 1j)
# ---> 88     out = empty_like(a, shape=a.shape[:axis] + (n_out,) + a.shape[axis+1:],
#      89                      dtype=out_dtype)
#      90 elif ((shape := getattr(out, "shape", None)) is not None
#      91       and (len(shape) != a.ndim or shape[axis] != n_out)):
#      92     raise ValueError("output array has wrong shape.")
#
# File /opt/anaconda3/envs/ysg/lib/python3.13/site-packages/numpy/_core/multiarray.py:107, in empty_like(prototype, dtype, order, subok, shape, device)
#     100 # We can't verify dispatcher signatures because NumPy's C functions don't
#     101 # support introspection.
#     102 array_function_from_c_func_and_dispatcher = functools.partial(
#     103     overrides.array_function_from_dispatcher,
#     104     module='numpy', docs_from_dispatcher=True, verify=False)
# --> 107 @array_function_from_c_func_and_dispatcher(_multiarray_umath.empty_like)
#     108 def empty_like(
#     109     prototype, dtype=None, order=None, subok=None, shape=None, *, device=None
#     110 ):
#     111     """
#     112     empty_like(prototype, dtype=None, order='K', subok=True, shape=None, *,
#     113                device=None)
#    (...)    175
#     176     """   # NOQA
#     177     return (prototype,)
#
# KeyboardInterrupt:

# %%
for target in range(0,150): # 848
# for target in range(0,100):  
    # fit_plotter_flux(target)
    df, teles = offset_corrector(target, additive=False, show=True)
    try:
        lombs = compute_lomb_scargle(target, df=df, telescopes=teles, auto=False, samples_per_peak=10)
        plot_periodogram(target, lombs['frequency'], lombs['power'], lombs['best_frequency'], lombs['false_alarm_level'], lombs['peaks'], lombs['observation_period'], show_best=True)
        plot_phase_fold(target, lombs['best_period'], phase_bins=2, df=df, telescopes=teles)
    except Exception as e:
        print(f"Discarded lightcurve at target {target}: {e}")

# %% [markdown]
# ### Adding logT, logL to the summary_results files

# %%
# stats = pd.read_csv('summary_results02.csv')
# stats = pd.read_csv('summary_results03.csv')
# stats = pd.read_csv('summary_results08.csv')
# stats = pd.read_csv('summary_results07.csv')
# summary_file = 'summary_results12.csv'
summary_file = 'summary_results17.csv'
stats = pd.read_csv(summary_file)

df_lmc = pd.read_csv('/Users/shannonbowes/Research/ysg/candidates_and_lcs/final_lmc_ysgcands.csv', comment='#') # , sep="\\s+"
df_smc = pd.read_csv('/Users/shannonbowes/Research/ysg/candidates_and_lcs/final_smc_ysgcands.csv', comment='#') # , sep="\\s+"

# Create coordinate keys for matching (using a small tolerance for floating point precision)
def round_coords(ra, dec, precision=6):
    """Round coordinates to specified decimal places for robust matching"""
    return (round(ra, precision), round(dec, precision))

# Create coordinate-to-logT/logL mapping from df_smc and df_lmc
coord_to_logT = {}
coord_to_logL = {}

# Add SMC data (indices 0-376 in the combined catalog)
for idx, row in df_smc.iterrows():
    coord_key = round_coords(row['ra'], row['dec'])
    coord_to_logT[coord_key] = row['logT']
    coord_to_logL[coord_key] = row['logL']

# Add LMC data (indices 377+ in the combined catalog)  
for idx, row in df_lmc.iterrows():
    coord_key = round_coords(row['ra'], row['dec'])
    coord_to_logT[coord_key] = row['logT']
    coord_to_logL[coord_key] = row['logL']

# Create new logT and logL columns in summary_df
stats['logT'] = np.nan
stats['logL'] = np.nan

# Match coordinates and assign logT/logL values
matches = 0
for idx, row in stats.iterrows():
    coord_key = round_coords(row['RA'], row['DEC'])
    
    if coord_key in coord_to_logT:
        stats.at[idx, 'logT'] = coord_to_logT[coord_key]
        stats.at[idx, 'logL'] = coord_to_logL[coord_key]
        matches += 1

print(f"Successfully matched {matches} out of {len(stats)} stars")
print(f"Missing logT/logL for {len(stats) - matches} stars")

# Save the updated dataframe back to summary_results09.csv
stats.to_csv(summary_file, index=False)
print(f"Updated {summary_file} with logT and logL columns")

# Show a preview of the new columns
print("\nPreview of updated dataframe:")
print(stats[['RA', 'DEC', 'logT', 'logL']].head(10))

# Check for any missing values
missing_logT = stats['logT'].isna().sum()
missing_logL = stats['logL'].isna().sum()
print(f"\nMissing values - logT: {missing_logT}, logL: {missing_logL}")
# Out:
# Successfully matched 848 out of 848 stars
# Missing logT/logL for 0 stars
# Updated summary_results17.csv with logT and logL columns
#
# Preview of updated dataframe:
#          RA        DEC      logT      logL
# 0  7.521702 -73.913918  3.773141  4.026600
# 1  7.746443 -73.741425  3.770847  4.010042
# 2  7.925977 -73.531670  3.634779  4.044608
# 3  7.948884 -73.599243  3.629099  4.026778
# 4  7.980047 -73.578545  3.609289  4.036388
# 5  7.981742 -73.585571  3.617613  4.323311
# 6  8.228736 -73.821953  3.794981  4.034392
# 7  8.560188 -73.619049  3.617889  4.098910
# 8  8.637665 -73.873337  3.879346  4.206012
# 9  8.763608 -73.549622  3.626272  4.272656
#
# Missing values - logT: 0, logL: 0

# %%
df15 = pd.read_csv('summary_results17.csv')
df16 = pd.read_csv('summary_results16.csv')
counter = 0
variable_diff_counter = 0
total_variable_counter = 0

# comparing summary_results17 to summary_results16
for target in range(0,848):
    # Compare the two DataFrames
    if df15.iloc[target]['best_period'] - df16.iloc[target]['best_period'] > 0.1:
        print(f"DataFrames differ at index {target}")
        print("summary_results17:")
        print(df15.iloc[target]['best_period'])
        print("summary_results16:")
        print(df16.iloc[target]['best_period'])
        counter += 1
        if df15.iloc[target]['alarm_level_flag'] != df16.iloc[target]['alarm_level_flag']:
            variable_diff_counter += 1
        if df15.iloc[target]['alarm_level_flag'] != 1:
            variable_counter += 1

print(f"Total differing entries found: {counter}")
print(f"Total variable differing entries found: {variable_diff_counter}")
print(f"Total variable entries found: {variable_counter}")
# Out:
# DataFrames differ at index 2
# summary_results17:
# 309.2481948431621
# summary_results16:
# 201.54708472066625
# DataFrames differ at index 7
# summary_results17:
# 27.929154328293713
# summary_results16:
# 6.9017019001918465
# DataFrames differ at index 9
# summary_results17:
# 419.45098250948786
# summary_results16:
# 388.6442267030881
# DataFrames differ at index 20
# summary_results17:
# 420.07804524263946
# summary_results16:
# 254.17285333168633
# DataFrames differ at index 21
# summary_results17:
# 511.08222110082954
# summary_results16:
# 254.29619338834365
# DataFrames differ at index 25
# summary_results17:
# 571.1333794468534
# summary_results16:
# 553.2609933870724
# DataFrames differ at index 26
# summary_results17:
# 753.3181307772339
# summary_results16:
# 341.55226943668276
# DataFrames differ at index 28
# summary_results17:
# 510.38891932520465
# summary_results16:
# 398.3916114597043
# DataFrames differ at index 29
# summary_results17:
# 1102.3752195635443
# summary_results16:
# 955.009064300603
# DataFrames differ at index 30
# summary_results17:
# 289.7725720699362
# summary_results16:
# 230.06421391922785
# DataFrames differ at index 39
# summary_results17:
# 420.07804524263946
# summary_results16:
# 399.0664252653187
# DataFrames differ at index 40
# summary_results17:
# 333.04305237208956
# summary_results16:
# 325.2350630189629
# DataFrames differ at index 45
# summary_results17:
# 4.826803601935724
# summary_results16:
# 3.330413143842146
# DataFrames differ at index 50
# summary_results17:
# 322.1961090096706
# summary_results16:
# 253.12197456977
# DataFrames differ at index 52
# summary_results17:
# 511.77448678669543
# summary_results16:
# 395.2558681204219
# DataFrames differ at index 54
# summary_results17:
# 4.079138064700549
# summary_results16:
# 1.454492437771146
# DataFrames differ at index 57
# summary_results17:
# 347.2223658178655
# summary_results16:
# 322.8868842325364
# DataFrames differ at index 59
# summary_results17:
# 181.18158238849296
# summary_results16:
# 93.8963710328224
# DataFrames differ at index 70
# summary_results17:
# 323.836712295718
# summary_results16:
# 83.64531165401203
# DataFrames differ at index 73
# summary_results17:
# 1093.4386742700906
# summary_results16:
# 4.082151971002008
# DataFrames differ at index 78
# summary_results17:
# 83.64083320643512
# summary_results16:
# 83.47463632071346
# DataFrames differ at index 88
# summary_results17:
# 1.7132125276255106
# summary_results16:
# 1.5196847154451152
# DataFrames differ at index 90
# summary_results17:
# 83.0244420942645
# summary_results16:
# 35.88037472418782
# DataFrames differ at index 92
# summary_results17:
# 895.3749897595534
# summary_results16:
# 402.2889937728333
# DataFrames differ at index 93
# summary_results17:
# 1095.150394223394
# summary_results16:
# 48.55409667728759
# DataFrames differ at index 96
# summary_results17:
# 183.16415563753569
# summary_results16:
# 180.50476693679252
# DataFrames differ at index 105
# summary_results17:
# 77.9906121008923
# summary_results16:
# 77.55888696859155
# DataFrames differ at index 106
# summary_results17:
# 411.2282628033962
# summary_results16:
# 402.4221579761894
# DataFrames differ at index 108
# summary_results17:
# 735.4830628546254
# summary_results16:
# 398.96362557421
# DataFrames differ at index 110
# summary_results17:
# 1104.5372957761458
# summary_results16:
# 1079.19509438792
# DataFrames differ at index 111
# summary_results17:
# 743.3504038064483
# summary_results16:
# 189.5285476271412
# DataFrames differ at index 113
# summary_results17:
# 52.79335426614145
# summary_results16:
# 2.0714862472817295
# DataFrames differ at index 118
# summary_results17:
# 410.5902410046536
# summary_results16:
# 409.1861377695308
# DataFrames differ at index 119
# summary_results17:
# 333.04305237208956
# summary_results16:
# 330.11112842744524
# DataFrames differ at index 122
# summary_results17:
# 559.3420740732912
# summary_results16:
# 433.54860852481454
# DataFrames differ at index 123
# summary_results17:
# 324.927769092836
# summary_results16:
# 323.92787824321766
# DataFrames differ at index 124
# summary_results17:
# 21.47426779351484
# summary_results16:
# 7.174396902170666
# DataFrames differ at index 126
# summary_results17:
# 753.3181307772339
# summary_results16:
# 294.51182051523807
# DataFrames differ at index 127
# summary_results17:
# 82.53064346253603
# summary_results16:
# 25.006583494968936
# DataFrames differ at index 130
# summary_results17:
# 1095.717189458993
# summary_results16:
# 984.5807590026754
# DataFrames differ at index 133
# summary_results17:
# 2.2619250464966036
# summary_results16:
# 1.331537061301968
# DataFrames differ at index 140
# summary_results17:
# 27.37860673193917
# summary_results16:
# 6.565064539059584
# DataFrames differ at index 145
# summary_results17:
# 2.817213764113934
# summary_results16:
# 1.540985093840495
# DataFrames differ at index 146
# summary_results17:
# 1099.6328209207088
# summary_results16:
# 1080.9756768281095
# DataFrames differ at index 147
# summary_results17:
# 4.823905897509741
# summary_results16:
# 1.257237406997748
# DataFrames differ at index 150
# summary_results17:
# 865.3267085339435
# summary_results16:
# 860.0479866747829
# DataFrames differ at index 151
# summary_results17:
# 740.2247241964118
# summary_results16:
# 541.2163555749149
# DataFrames differ at index 154
# summary_results17:
# 74.22975870077744
# summary_results16:
# 73.82057734643615
# DataFrames differ at index 155
# summary_results17:
# 315.1364757737887
# summary_results16:
# 1.910843520677456
# DataFrames differ at index 157
# summary_results17:
# 409.9514254446288
# summary_results16:
# 2.3240120312666086
# DataFrames differ at index 165
# summary_results17:
# 451.52314892109064
# summary_results16:
# 68.89499948345565
# DataFrames differ at index 171
# summary_results17:
# 737.861925511453
# summary_results16:
# 367.89665802512087
# DataFrames differ at index 174
# summary_results17:
# 378.1403920820812
# summary_results16:
# 212.9795276798204
# DataFrames differ at index 175
# summary_results17:
# 4.577138000441375
# summary_results16:
# 1.70441613870467
# DataFrames differ at index 177
# summary_results17:
# 410.5902410046536
# summary_results16:
# 5.002508040894186
# DataFrames differ at index 178
# summary_results17:
# 410.5902410046536
# summary_results16:
# 1.1155040523120627
# DataFrames differ at index 179
# summary_results17:
# 1.644467405933562
# summary_results16:
# 1.2606431224590395
# DataFrames differ at index 180
# summary_results17:
# 117.76912528321596
# summary_results16:
# 1.1510331166230945
# DataFrames differ at index 181
# summary_results17:
# 376.9311885221682
# summary_results16:
# 18.048420380310287
# DataFrames differ at index 183
# summary_results17:
# 324.927769092836
# summary_results16:
# 1.5413572820925157
# DataFrames differ at index 184
# summary_results17:
# 1.359345358663567
# summary_results16:
# 1.1656266375217337
# DataFrames differ at index 185
# summary_results17:
# 389.317161069552
# summary_results16:
# 389.1790107858771
# DataFrames differ at index 186
# summary_results17:
# 265.9259081180453
# summary_results16:
# 33.663025586373344
# DataFrames differ at index 191
# summary_results17:
# 1094.5817162216797
# summary_results16:
# 1.460595094185288
# DataFrames differ at index 192
# summary_results17:
# 742.5716131819812
# summary_results16:
# 394.7617789779898
# DataFrames differ at index 195
# summary_results17:
# 742.5716131819812
# summary_results16:
# 364.0699034320295
# DataFrames differ at index 201
# summary_results17:
# 411.8654923193725
# summary_results16:
# 390.7620713236968
# DataFrames differ at index 203
# summary_results17:
# 411.8654923193725
# summary_results16:
# 2.533476301461323
# DataFrames differ at index 208
# summary_results17:
# 3.256221500530691
# summary_results16:
# 1.201709777680348
# DataFrames differ at index 211
# summary_results17:
# 347.79777078712743
# summary_results16:
# 204.43711033338255
# DataFrames differ at index 213
# summary_results17:
# 228.47393229184308
# summary_results16:
# 225.28392254457992
# DataFrames differ at index 214
# summary_results17:
# 4.405608703401777
# summary_results16:
# 1.1791458107266295
# DataFrames differ at index 217
# summary_results17:
# 409.3118146411256
# summary_results16:
# 1.8556390950048287
# DataFrames differ at index 219
# summary_results17:
# 345.6511763094278
# summary_results16:
# 339.3413043703417
# DataFrames differ at index 222
# summary_results17:
# 1095.150394223394
# summary_results16:
# 1037.3631473932007
# DataFrames differ at index 223
# summary_results17:
# 1095.717189458993
# summary_results16:
# 522.9918318958795
# DataFrames differ at index 226
# summary_results17:
# 387.52776587459914
# summary_results16:
# 1.722085290299261
# DataFrames differ at index 227
# summary_results17:
# 409.3118146411256
# summary_results16:
# 394.2903057004273
# DataFrames differ at index 228
# summary_results17:
# 1095.717189458993
# summary_results16:
# 305.27213315683326
# DataFrames differ at index 229
# summary_results17:
# 1.7801216879503416
# summary_results16:
# 1.1628024296753618
# DataFrames differ at index 231
# summary_results17:
# 569.6418369301881
# summary_results16:
# 322.95451273131823
# DataFrames differ at index 243
# summary_results17:
# 253.56381953720415
# summary_results16:
# 1.8666603501721335
# DataFrames differ at index 245
# summary_results17:
# 859.8350196829713
# summary_results16:
# 778.4000436378727
# DataFrames differ at index 248
# summary_results17:
# 1.9152879361576605
# summary_results16:
# 1.5266397019026052
# DataFrames differ at index 250
# summary_results17:
# 1096.2821112631532
# summary_results16:
# 1075.861085924946
# DataFrames differ at index 255
# summary_results17:
# 885.9614552555552
# summary_results16:
# 390.8969452457893
# DataFrames differ at index 256
# summary_results17:
# 410.5902410046536
# summary_results16:
# 407.7610825909098
# DataFrames differ at index 258
# summary_results17:
# 267.82215205287986
# summary_results16:
# 263.51425290419854
# DataFrames differ at index 260
# summary_results17:
# 236.2948975714748
# summary_results16:
# 7.052042097335458
# DataFrames differ at index 263
# summary_results17:
# 884.4841282692767
# summary_results16:
# 28.972579201002876
# DataFrames differ at index 264
# summary_results17:
# 2.0116123128154
# summary_results16:
# 1.3008081538966354
# DataFrames differ at index 265
# summary_results17:
# 378.1403920820812
# summary_results16:
# 29.288948814018465
# DataFrames differ at index 267
# summary_results17:
# 267.3486667465947
# summary_results16:
# 4.186100694205487
# DataFrames differ at index 272
# summary_results17:
# 265.9259081180453
# summary_results16:
# 106.37327844255697
# DataFrames differ at index 276
# summary_results17:
# 1094.0111460570552
# summary_results16:
# 592.5137531175794
# DataFrames differ at index 282
# summary_results17:
# 408.6714071082547
# summary_results16:
# 399.23499120756014
# DataFrames differ at index 285
# summary_results17:
# 321.64816659851164
# summary_results16:
# 139.91750928485376
# DataFrames differ at index 298
# summary_results17:
# 20.83133871965491
# summary_results16:
# 1.2674931255855617
# DataFrames differ at index 301
# summary_results17:
# 341.90524423610617
# summary_results16:
# 6.566162041698656
# DataFrames differ at index 305
# summary_results17:
# 301.488832661206
# summary_results16:
# 229.7991347829795
# DataFrames differ at index 307
# summary_results17:
# 312.9741650766859
# summary_results16:
# 89.48492327779196
# DataFrames differ at index 308
# summary_results17:
# 324.927769092836
# summary_results16:
# 91.22808166319643
# DataFrames differ at index 312
# summary_results17:
# 267.3486667465947
# summary_results16:
# 22.811558894288908
# DataFrames differ at index 313
# summary_results17:
# 411.8654923193725
# summary_results16:
# 4.253340502807508
# DataFrames differ at index 315
# summary_results17:
# 1093.0040307360086
# summary_results16:
# 2.3596922894296273
# DataFrames differ at index 316
# summary_results17:
# 409.9514254446288
# summary_results16:
# 289.57007184359566
# DataFrames differ at index 321
# summary_results17:
# 344.33620213311553
# summary_results16:
# 329.26538406158085
# DataFrames differ at index 323
# summary_results17:
# 2.0024234321534244
# summary_results16:
# 1.7623649652406894
# DataFrames differ at index 324
# summary_results17:
# 411.8654923193725
# summary_results16:
# 383.415080156772
# DataFrames differ at index 326
# summary_results17:
# 323.2903810675172
# summary_results16:
# 319.49773731107365
# DataFrames differ at index 328
# summary_results17:
# 207.9022152818856
# summary_results16:
# 203.75527015213584
# DataFrames differ at index 332
# summary_results17:
# 323.2903810675172
# summary_results16:
# 316.7510024373302
# DataFrames differ at index 334
# summary_results17:
# 265.45088611594326
# summary_results16:
# 6.831167066973825
# DataFrames differ at index 342
# summary_results17:
# 14.336090565055676
# summary_results16:
# 1.1583931441467872
# DataFrames differ at index 343
# summary_results17:
# 884.4841282692767
# summary_results16:
# 253.3428215617376
# DataFrames differ at index 348
# summary_results17:
# 347.2223658178655
# summary_results16:
# 330.15741060879446
# DataFrames differ at index 349
# summary_results17:
# 29.811292234496833
# summary_results16:
# 1.4903255464720513
# DataFrames differ at index 351
# summary_results17:
# 324.38250804186185
# summary_results16:
# 92.9378739058005
# DataFrames differ at index 354
# summary_results17:
# 319.45100254866327
# summary_results16:
# 252.73591111211255
# DataFrames differ at index 355
# summary_results17:
# 302.0094421983405
# summary_results16:
# 224.2550899166054
# DataFrames differ at index 358
# summary_results17:
# 54.19413231794074
# summary_results16:
# 54.063647775206114
# DataFrames differ at index 359
# summary_results17:
# 881.505605734533
# summary_results16:
# 252.61445444958363
# DataFrames differ at index 361
# summary_results17:
# 884.4841282692767
# summary_results16:
# 820.2251072549412
# DataFrames differ at index 363
# summary_results17:
# 1087.60724024962
# summary_results16:
# 270.36228812576627
# DataFrames differ at index 365
# summary_results17:
# 284.34880307794475
# summary_results16:
# 283.2072791837755
# DataFrames differ at index 366
# summary_results17:
# 448.1485542777926
# summary_results16:
# 51.57856699613858
# DataFrames differ at index 371
# summary_results17:
# 736.2778123580409
# summary_results16:
# 13.987103270590636
# DataFrames differ at index 372
# summary_results17:
# 303.0492311343306
# summary_results16:
# 233.13237542149457
# DataFrames differ at index 376
# summary_results17:
# 728.2484195134608
# summary_results16:
# 29.3170055377777
# DataFrames differ at index 377
# summary_results17:
# 874.1016551155469
# summary_results16:
# 387.23710767538574
# DataFrames differ at index 381
# summary_results17:
# 1155.2618628636203
# summary_results16:
# 390.44851925140176
# DataFrames differ at index 382
# summary_results17:
# 340.2988062612709
# summary_results16:
# 327.6737874063188
# DataFrames differ at index 389
# summary_results17:
# 385.55902086125263
# summary_results16:
# 377.0808022053844
# DataFrames differ at index 390
# summary_results17:
# 340.2988062612709
# summary_results16:
# 328.4959390387857
# DataFrames differ at index 405
# summary_results17:
# 337.65303820218355
# summary_results16:
# 144.27286873062727
# DataFrames differ at index 406
# summary_results17:
# 340.7468221275116
# summary_results16:
# 338.1010009048675
# DataFrames differ at index 408
# summary_results17:
# 321.86302924665335
# summary_results16:
# 314.4685930399329
# DataFrames differ at index 409
# summary_results17:
# 304.96236916197734
# summary_results16:
# 297.28454020951773
# DataFrames differ at index 410
# summary_results17:
# 823.2470382663174
# summary_results16:
# 792.8954327181344
# DataFrames differ at index 415
# summary_results17:
# 379.1337232015508
# summary_results16:
# 374.2349587552403
# DataFrames differ at index 419
# summary_results17:
# 340.2988062612709
# summary_results16:
# 329.11175376264197
# DataFrames differ at index 423
# summary_results17:
# 525.8614372941325
# summary_results16:
# 522.2963911818972
# DataFrames differ at index 430
# summary_results17:
# 339.85042372617056
# summary_results16:
# 296.71187178722226
# DataFrames differ at index 432
# summary_results17:
# 1148.4382694427595
# summary_results16:
# 835.5168640331443
# DataFrames differ at index 434
# summary_results17:
# 385.55902086125263
# summary_results16:
# 380.24796863280307
# DataFrames differ at index 435
# summary_results17:
# 384.5844488059284
# summary_results16:
# 376.85384970282786
# DataFrames differ at index 440
# summary_results17:
# 642.1457898252096
# summary_results16:
# 602.5285303334341
# DataFrames differ at index 443
# summary_results17:
# 524.1352271860361
# summary_results16:
# 319.555806588771
# DataFrames differ at index 445
# summary_results17:
# 226.6893306527439
# summary_results16:
# 222.8001911735201
# DataFrames differ at index 446
# summary_results17:
# 316.1184378022112
# summary_results16:
# 276.45437881316656
# DataFrames differ at index 447
# summary_results17:
# 386.0456297038307
# summary_results16:
# 119.73529965140996
# DataFrames differ at index 450
# summary_results17:
# 960.311412397906
# summary_results16:
# 328.4959390387857
# DataFrames differ at index 455
# summary_results17:
# 1150.9463459377307
# summary_results16:
# 392.4987145608439
# DataFrames differ at index 456
# summary_results17:
# 435.63656286276614
# summary_results16:
# 381.8630962892324
# DataFrames differ at index 460
# summary_results17:
# 45.30658004891611
# summary_results16:
# 45.175441528324825
# DataFrames differ at index 464
# summary_results17:
# 437.7976317884379
# summary_results16:
# 382.5285556744198
# DataFrames differ at index 468
# summary_results17:
# 713.3511720783728
# summary_results16:
# 99.42675574688776
# DataFrames differ at index 469
# summary_results17:
# 39.63427444783384
# summary_results16:
# 29.476265263199025
# DataFrames differ at index 474
# summary_results17:
# 445.2350838018635
# summary_results16:
# 204.93335350594927
# DataFrames differ at index 476
# summary_results17:
# 36.98206941737247
# summary_results16:
# 36.87326225397722
# DataFrames differ at index 477
# summary_results17:
# 421.2194733051474
# summary_results16:
# 307.76658237690975
# DataFrames differ at index 478
# summary_results17:
# 516.1751286059811
# summary_results16:
# 377.67451700495326
# DataFrames differ at index 482
# summary_results17:
# 340.7468221275116
# summary_results16:
# 175.8007497450877
# DataFrames differ at index 483
# summary_results17:
# 702.3342569075508
# summary_results16:
# 655.5554280029111
# DataFrames differ at index 484
# summary_results17:
# 251.66946510316808
# summary_results16:
# 167.79855091507696
# DataFrames differ at index 485
# summary_results17:
# 721.9709259936095
# summary_results16:
# 297.6659998181975
# DataFrames differ at index 488
# summary_results17:
# 370.4187688337528
# summary_results16:
# 103.41954791281276
# DataFrames differ at index 491
# summary_results17:
# 134.92640930197177
# summary_results16:
# 133.2988471422112
# DataFrames differ at index 493
# summary_results17:
# 312.43629781234097
# summary_results16:
# 41.7967930094148
# DataFrames differ at index 496
# summary_results17:
# 296.54869701895785
# summary_results16:
# 4.117253116633346
# DataFrames differ at index 497
# summary_results17:
# 385.55902086125263
# summary_results16:
# 329.3168733720278
# DataFrames differ at index 498
# summary_results17:
# 960.311412397906
# summary_results16:
# 377.7610772827961
# DataFrames differ at index 500
# summary_results17:
# 588.4726736280246
# summary_results16:
# 378.0950411911445
# DataFrames differ at index 501
# summary_results17:
# 971.2228473822524
# summary_results16:
# 905.2907765455044
# DataFrames differ at index 503
# summary_results17:
# 1157.739676385222
# summary_results16:
# 1050.3659310165451
# DataFrames differ at index 504
# summary_results17:
# 126.13534726709956
# summary_results16:
# 125.0926017293234
# DataFrames differ at index 510
# summary_results17:
# 443.1132119093297
# summary_results16:
# 432.3914256579884
# DataFrames differ at index 513
# summary_results17:
# 164.21014744765856
# summary_results16:
# 163.4762334785321
# DataFrames differ at index 518
# summary_results17:
# 185.61975057776215
# summary_results16:
# 183.733977235331
# DataFrames differ at index 522
# summary_results17:
# 193.30810376929324
# summary_results16:
# 193.05720356961783
# DataFrames differ at index 524
# summary_results17:
# 492.2131247471206
# summary_results16:
# 18.24870264656578
# DataFrames differ at index 525
# summary_results17:
# 128.71989676404493
# summary_results16:
# 109.86936010063478
# DataFrames differ at index 527
# summary_results17:
# 584.9669945478715
# summary_results16:
# 576.3700151996184
# DataFrames differ at index 533
# summary_results17:
# 7.391036025181622
# summary_results16:
# 2.042841600352267
# DataFrames differ at index 534
# summary_results17:
# 578.2151002998168
# summary_results16:
# 417.6533652728872
# DataFrames differ at index 537
# summary_results17:
# 131.77348674545482
# summary_results16:
# 130.93098868209694
# DataFrames differ at index 538
# summary_results17:
# 532.346204966353
# summary_results16:
# 381.6019633997505
# DataFrames differ at index 539
# summary_results17:
# 102.1480151130928
# summary_results16:
# 101.11344988294243
# DataFrames differ at index 542
# summary_results17:
# 531.2110370256653
# summary_results16:
# 445.873080331775
# DataFrames differ at index 545
# summary_results17:
# 47.53114654785808
# summary_results16:
# 47.387416575573866
# DataFrames differ at index 547
# summary_results17:
# 72.83839508246686
# summary_results16:
# 19.634361611302477
# DataFrames differ at index 551
# summary_results17:
# 308.33452405749256
# summary_results16:
# 268.17282122686663
# DataFrames differ at index 554
# summary_results17:
# 256.7131531400537
# summary_results16:
# 127.54776520654757
# DataFrames differ at index 556
# summary_results17:
# 328.3605901588314
# summary_results16:
# 326.2562360011657
# DataFrames differ at index 557
# summary_results17:
# 328.3605901588314
# summary_results16:
# 321.76167265219095
# DataFrames differ at index 561
# summary_results17:
# 346.6271760018231
# summary_results16:
# 338.8214439019427
# DataFrames differ at index 562
# summary_results17:
# 451.6983952146354
# summary_results16:
# 125.63764743728328
# DataFrames differ at index 564
# summary_results17:
# 55.76794302499646
# summary_results16:
# 5.762900880568865
# DataFrames differ at index 565
# summary_results17:
# 391.9642057252736
# summary_results16:
# 375.6127022744725
# DataFrames differ at index 566
# summary_results17:
# 532.346204966353
# summary_results16:
# 324.1349865822991
# DataFrames differ at index 569
# summary_results17:
# 394.3651766693034
# summary_results16:
# 384.70522070732585
# DataFrames differ at index 572
# summary_results17:
# 1154.6732271203798
# summary_results16:
# 1000.3792980141964
# DataFrames differ at index 574
# summary_results17:
# 484.02831679978823
# summary_results16:
# 343.61198789997667
# DataFrames differ at index 575
# summary_results17:
# 965.897207590687
# summary_results16:
# 909.9239722771298
# DataFrames differ at index 576
# summary_results17:
# 320.21533593680465
# summary_results16:
# 316.6835372606271
# DataFrames differ at index 577
# summary_results17:
# 19.389726788764637
# summary_results16:
# 3.0247377452217163
# DataFrames differ at index 580
# summary_results17:
# 329.2110831759956
# summary_results16:
# 322.14659059149267
# DataFrames differ at index 584
# summary_results17:
# 174.2343229270304
# summary_results16:
# 173.68051202425832
# DataFrames differ at index 585
# summary_results17:
# 328.3605901588314
# summary_results16:
# 327.6853589363841
# DataFrames differ at index 588
# summary_results17:
# 323.6594557082535
# summary_results16:
# 319.46722695384216
# DataFrames differ at index 596
# summary_results17:
# 329.6358407742034
# summary_results16:
# 205.0515140443194
# DataFrames differ at index 604
# summary_results17:
# 832.1500294419425
# summary_results16:
# 391.23466814127033
# DataFrames differ at index 608
# summary_results17:
# 343.06890114847306
# summary_results16:
# 320.3500539338613
# DataFrames differ at index 609
# summary_results17:
# 488.41111346471007
# summary_results16:
# 452.9635733991587
# DataFrames differ at index 610
# summary_results17:
# 533.4785329336049
# summary_results16:
# 151.55668984575914
# DataFrames differ at index 613
# summary_results17:
# 175.26399192565802
# summary_results16:
# 130.74900773989276
# DataFrames differ at index 616
# summary_results17:
# 345.29553756023574
# summary_results16:
# 337.2328017051151
# DataFrames differ at index 618
# summary_results17:
# 348.39764249984955
# summary_results16:
# 342.21947039637206
# DataFrames differ at index 626
# summary_results17:
# 1156.9793869679177
# summary_results16:
# 2.1576646171158465
# DataFrames differ at index 628
# summary_results17:
# 453.7858054193174
# summary_results16:
# 312.09793426245443
# DataFrames differ at index 630
# summary_results17:
# 14.765239246257837
# summary_results16:
# 7.902895485982114
# DataFrames differ at index 633
# summary_results17:
# 965.3579386963776
# summary_results16:
# 952.6390546112096
# DataFrames differ at index 634
# summary_results17:
# 965.3579386963776
# summary_results16:
# 952.1480346690508
# DataFrames differ at index 635
# summary_results17:
# 725.4423077528592
# summary_results16:
# 483.8458189755811
# DataFrames differ at index 638
# summary_results17:
# 969.6378064599198
# summary_results16:
# 947.8035599573242
# DataFrames differ at index 641
# summary_results17:
# 148.1887301214058
# summary_results16:
# 103.87932640029872
# DataFrames differ at index 642
# summary_results17:
# 1156.597641766802
# summary_results16:
# 292.44651046839897
# DataFrames differ at index 643
# summary_results17:
# 966.4352461508172
# summary_results16:
# 954.7554223176944
# DataFrames differ at index 646
# summary_results17:
# 48.22569187795419
# summary_results16:
# 48.10395625726892
# DataFrames differ at index 649
# summary_results17:
# 23.883277110544785
# summary_results16:
# 1.759168058860482
# DataFrames differ at index 651
# summary_results17:
# 388.09956083568
# summary_results16:
# 2.596119756867864
# DataFrames differ at index 654
# summary_results17:
# 328.7859997625464
# summary_results16:
# 323.3888728397754
# DataFrames differ at index 656
# summary_results17:
# 954.9349355390908
# summary_results16:
# 333.5990127086874
# DataFrames differ at index 659
# summary_results17:
# 1155.8310264787926
# summary_results16:
# 768.5630567152083
# DataFrames differ at index 668
# summary_results17:
# 203.24821116507044
# summary_results16:
# 203.06168081248785
# DataFrames differ at index 669
# summary_results17:
# 203.83816131696975
# summary_results16:
# 203.23744843063457
# DataFrames differ at index 672
# summary_results17:
# 956.0602706246648
# summary_results16:
# 934.3911452028236
# DataFrames differ at index 677
# summary_results17:
# 326.6556900453167
# summary_results16:
# 91.35215426004837
# DataFrames differ at index 681
# summary_results17:
# 533.4785123032175
# summary_results16:
# 504.3549553357895
# DataFrames differ at index 682
# summary_results17:
# 832.1500294419425
# summary_results16:
# 96.72354437562014
# DataFrames differ at index 684
# summary_results17:
# 341.28103655019675
# summary_results16:
# 340.97797034527537
# DataFrames differ at index 688
# summary_results17:
# 97.19867351058824
# summary_results16:
# 96.69441589938968
# DataFrames differ at index 690
# summary_results17:
# 335.9324825235652
# summary_results16:
# 321.94002302669827
# DataFrames differ at index 691
# summary_results17:
# 404.497118290396
# summary_results16:
# 332.2292185139345
# DataFrames differ at index 695
# summary_results17:
# 488.41111346471007
# summary_results16:
# 475.1307167891137
# DataFrames differ at index 696
# summary_results17:
# 1157.7397736563269
# summary_results16:
# 416.8249035793174
# DataFrames differ at index 698
# summary_results17:
# 440.11681177633267
# summary_results16:
# 425.839199593349
# DataFrames differ at index 699
# summary_results17:
# 125.40731296838318
# summary_results16:
# 117.48539817369762
# DataFrames differ at index 700
# summary_results17:
# 969.107130469966
# summary_results16:
# 593.5170305920901
# DataFrames differ at index 705
# summary_results17:
# 325.4357310328251
# summary_results16:
# 321.58170364119934
# DataFrames differ at index 713
# summary_results17:
# 818.9165951017322
# summary_results16:
# 332.2624825313605
# DataFrames differ at index 714
# summary_results17:
# 285.85402995139907
# summary_results16:
# 274.10705638795133
# DataFrames differ at index 717
# summary_results17:
# 476.3223662362957
# summary_results16:
# 468.1033770688631
# DataFrames differ at index 720
# summary_results17:
# 439.58120130355945
# summary_results16:
# 285.91613509957057
# DataFrames differ at index 722
# summary_results17:
# 327.08240819209993
# summary_results16:
# 326.5542800205165
# DataFrames differ at index 723
# summary_results17:
# 390.0354477604769
# summary_results16:
# 380.21755439854536
# DataFrames differ at index 727
# summary_results17:
# 818.9165951017322
# summary_results16:
# 469.6195237538376
# DataFrames differ at index 728
# summary_results17:
# 408.6151634777048
# summary_results16:
# 323.0769004363632
# DataFrames differ at index 729
# summary_results17:
# 650.9337013143845
# summary_results16:
# 317.04681588704165
# DataFrames differ at index 730
# summary_results17:
# 408.1022041867221
# summary_results16:
# 10.903423719970192
# DataFrames differ at index 731
# summary_results17:
# 968.0420217873768
# summary_results16:
# 942.4753421542237
# DataFrames differ at index 733
# summary_results17:
# 1156.9793869679177
# summary_results16:
# 1040.4404550729016
# DataFrames differ at index 737
# summary_results17:
# 392.9259236422608
# summary_results16:
# 391.1601025599632
# DataFrames differ at index 738
# summary_results17:
# 1156.9793869679177
# summary_results16:
# 390.9705102231139
# DataFrames differ at index 739
# summary_results17:
# 419.7166082991888
# summary_results16:
# 399.1913671123167
# DataFrames differ at index 740
# summary_results17:
# 417.7058435406126
# summary_results16:
# 282.1403012167101
# DataFrames differ at index 741
# summary_results17:
# 1152.471493879578
# summary_results16:
# 1116.8204932364704
# DataFrames differ at index 746
# summary_results17:
# 140.72665289733183
# summary_results16:
# 84.72692194904975
# DataFrames differ at index 748
# summary_results17:
# 833.3309980533596
# summary_results16:
# 246.3487254888613
# DataFrames differ at index 750
# summary_results17:
# 344.4059710577701
# summary_results16:
# 333.7388980007576
# DataFrames differ at index 753
# summary_results17:
# 419.21466081779374
# summary_results16:
# 333.8244714445464
# DataFrames differ at index 757
# summary_results17:
# 327.08240819209993
# summary_results16:
# 76.19372418084218
# DataFrames differ at index 761
# summary_results17:
# 969.107130469966
# summary_results16:
# 568.5219085305623
# DataFrames differ at index 763
# summary_results17:
# 256.7131531400537
# summary_results16:
# 252.91382898349508
# DataFrames differ at index 765
# summary_results17:
# 816.4355404009526
# summary_results16:
# 331.4453846452756
# DataFrames differ at index 766
# summary_results17:
# 729.1069699665032
# summary_results16:
# 716.7342030070258
# DataFrames differ at index 767
# summary_results17:
# 436.89449723473626
# summary_results16:
# 321.8719478657228
# DataFrames differ at index 768
# summary_results17:
# 452.743213914322
# summary_results16:
# 436.58024506469104
# DataFrames differ at index 771
# summary_results17:
# 452.743213914322
# summary_results16:
# 418.3631697564838
# DataFrames differ at index 774
# summary_results17:
# 315.4931310491345
# summary_results16:
# 137.41884122287902
# DataFrames differ at index 783
# summary_results17:
# 86.03040951060983
# summary_results16:
# 11.100898766711609
# DataFrames differ at index 787
# summary_results17:
# 347.0703342280204
# summary_results16:
# 64.97950444007847
# DataFrames differ at index 788
# summary_results17:
# 1157.7397736563269
# summary_results16:
# 655.3634704617048
# DataFrames differ at index 791
# summary_results17:
# 1156.9793869679177
# summary_results16:
# 1117.8240805030748
# DataFrames differ at index 795
# summary_results17:
# 826.3399721395157
# summary_results16:
# 383.85588765326975
# DataFrames differ at index 796
# summary_results17:
# 833.3309980533596
# summary_results16:
# 752.9513702580357
# DataFrames differ at index 797
# summary_results17:
# 1157.7397736563269
# summary_results16:
# 578.6710116058405
# DataFrames differ at index 798
# summary_results17:
# 344.4059710577701
# summary_results16:
# 333.13951278513764
# DataFrames differ at index 801
# summary_results17:
# 1157.3600961939565
# summary_results16:
# 1077.783677743943
# DataFrames differ at index 804
# summary_results17:
# 334.5745910032365
# summary_results16:
# 1.924025917066827
# DataFrames differ at index 808
# summary_results17:
# 585.5532875343645
# summary_results16:
# 232.31456298659947
# DataFrames differ at index 809
# summary_results17:
# 336.3843703493979
# summary_results16:
# 1.4124788698509647
# DataFrames differ at index 811
# summary_results17:
# 367.19211092942936
# summary_results16:
# 356.8185235697887
# DataFrames differ at index 812
# summary_results17:
# 294.5750844632306
# summary_results16:
# 209.53624587099716
# DataFrames differ at index 816
# summary_results17:
# 583.7919845390284
# summary_results16:
# 577.8621741650827
# DataFrames differ at index 817
# summary_results17:
# 74.1687099719494
# summary_results16:
# 73.70963712223875
# DataFrames differ at index 819
# summary_results17:
# 380.3385932949456
# summary_results16:
# 329.97810411117234
# DataFrames differ at index 821
# summary_results17:
# 570.7171953037468
# summary_results16:
# 3.0488240469069225
# DataFrames differ at index 823
# summary_results17:
# 158.01736731282895
# summary_results16:
# 156.9270231003223
# DataFrames differ at index 826
# summary_results17:
# 452.743213914322
# summary_results16:
# 415.630084462743
# DataFrames differ at index 827
# summary_results17:
# 955.4982598414596
# summary_results16:
# 2.1110163999246123
# DataFrames differ at index 830
# summary_results17:
# 953.8043279141422
# summary_results16:
# 912.9708221983814
# DataFrames differ at index 833
# summary_results17:
# 631.9756759050074
# summary_results16:
# 95.75612727548685
# DataFrames differ at index 836
# summary_results17:
# 381.3218061156647
# summary_results16:
# 358.8335775503816
# DataFrames differ at index 837
# summary_results17:
# 333.66746870630476
# summary_results16:
# 175.950477070169
# DataFrames differ at index 838
# summary_results17:
# 406.0452422644076
# summary_results16:
# 398.2279953783563
# DataFrames differ at index 841
# summary_results17:
# 580.3286393179691
# summary_results16:
# 336.6247888774008
# DataFrames differ at index 845
# summary_results17:
# 528.4279338324782
# summary_results16:
# 39.71368307191771
# DataFrames differ at index 847
# summary_results17:
# 962.8666667682792
# summary_results16:
# 201.87537490026008
# Total differing entries found: 309
# Total variable differing entries found: 59
# Total variable entries found: 519

# %% [markdown]
# ### Old data:

# %%
results = []
for target in range(0,848):
    print("Target: ", target)
    overall_mean, means, overall_median, medians, overall_mags_mean, overall_mags_median, mags_means, mags_medians = mean_med_flux(target, g=True, newfiles=False)
    chi_squared_95, chi2_threshold_95, dof_95, chi_flag_95 = chi(target, g=True, newfiles=False)
    chi_squared_997, chi2_threshold_997, dof_997, chi_flag_997 = chi(target, confidence=0.997, g=True, newfiles=False)
    chi_squared_68, chi2_threshold_68, dof_68, chi_flag_68 = chi(target, confidence=0.68, g=True, newfiles=False)
    # largest_amp = curve_fitter_flux(target)
    offset_flag = offset_warning(target, newfiles=False)
    amplitude_5, lower_percentile_5, upper_percentile_5, mag_amplitude_5 = percentile_amplitude(target, tails=5, g=True, newfiles=False)
    amplitude_1, lower_percentile_1, upper_percentile_1, mag_amplitude_1 = percentile_amplitude(target, tails=1, g=True, newfiles=False)
    # plot_percentile_amplitude(target, tails=1)
    largest_amp = largest_amplitude(target, g=True, newfiles=False)
    # lombs = compute_lomb_scargle(target, auto=True, samples_per_peak=5) #freq_range=(0.0, 0.05),
    # plot_periodogram(lombs['frequency'], lombs['power'], lombs['false_alarm_level'], lombs['peaks'], lombs['observation_period'], auto = True, show_best=True)
    lombs = compute_lomb_scargle(target, auto=False, median=False, subtract_median=False, samples_per_peak=10, report=False, newfiles=False)
    best_period = lombs['best_period']
    alarm_level_flag = lombs['alarm_level_flag']
    result = amplitude_per_period(target, report = False, newfiles=False)
    std_amp = result['std_amplitude']
    # amplitude_per_period_plot(target, result)

    # fit_plotter_flux(target)
    # plot_periodogram(lombs['frequency'], lombs['power'], lombs['false_alarm_level'], lombs['peaks'], lombs['observation_period'], show_best=True)
    # plot_phase_fold(target, phase_bins=2)

        # Get RA and DEC for this target
    RA = coords['ra'][target]
    DEC = coords['dec'][target]

    results.append({
        'RA': RA,
        'DEC': DEC,
        'overall_mean': overall_mean,
        'overall_median': overall_median,
        'overall_mean_mag': overall_mags_mean,
        'overall_median_mag': overall_mags_median,
        'offset_flag': offset_flag,
        'chi_squared_68': chi_squared_68,
        'chi2_threshold_68': chi2_threshold_68,
        'chi_flag_68': chi_flag_68,
        'chi_squared_95': chi_squared_95,
        'chi2_threshold_95': chi2_threshold_95,
        'chi_flag_95': chi_flag_95,
        'chi_squared_997': chi_squared_997,
        'chi2_threshold_997': chi2_threshold_997,
        'chi_flag_997': chi_flag_997,
        'amplitude_5': amplitude_5,
        'lower_percentile_5': lower_percentile_5,
        'upper_percentile_5': upper_percentile_5,
        'mag_amplitude_5': mag_amplitude_5,
        'amplitude_1': amplitude_1,
        'lower_percentile_1': lower_percentile_1,
        'upper_percentile_1': upper_percentile_1,
        'mag_amplitude_1': mag_amplitude_1,
        'largest_amp': largest_amp,
        'best_period': best_period,
        'alarm_level_flag': alarm_level_flag,
        'std_amplitude': std_amp
    })

# print(results)

# Convert to DataFrame and save to CSV
df_results = pd.DataFrame(results)
df_results.to_csv('summary_results07.csv', index=False)

# %%
print(df)

# %% [markdown]
# # sorting

# %%
# create three new columns in summary_results15.csv called 'cephied_like', 'ir_variable_like', and 'other_variable_like' and leave them empty for now
summary_file = 'summary_results15.csv'
stats = pd.read_csv(summary_file)
stats['cephied_like'] = ''
stats['ir_variable_like'] = ''
stats['other_variable_like'] = ''
stats.to_csv(summary_file, index=False)

# %% [markdown]
# # creating summary pdf files

# %%
info_to_pdf(0)
# Out:
# Best frequency: 0.443516 1/day, Best period: 2.25 days, Max power: 0.122, False alarm probability: 2.488e-72
# False alarm level for 1.0%: 1.087e-02
# Grid sampled at 24290 points
# Average scatter (amplitude) per 10 point phase bin: 0.579 mJy
# Average scatter (amplitude) per 10 point phase bin: 0.579 mJy
# [0.00121324 0.0018797  0.00243507 ... 0.89877817 0.89937057 0.89996297]
# Amplitude metrics:
# 	Lower 5% percentile: -0.34 mJy, 13.83 mags
# 	Upper 5% percentile: 0.32 mJy, 13.89 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.65 mJy, 0.07 mags
# Amplitude metrics:
# 	Lower 1% percentile: -0.49 mJy, 13.81 mags
# 	Upper 1% percentile: 0.46 mJy, 13.91 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.96 mJy, 0.10 mags
# 	Largest amplitude of variability (g-band: True): 1.09 mJy, 0.11 mags
# 	Average amplitude across all periods: 0.390 mJy
# 	Standard deviation of amplitudes: 0.184 mJy
# 	Warning: average amplitude (0.390 mJy) is less than 5 sigma (0.184 mJy). This indicates significant variability in the amplitudes across periods.
# Saved 6 plot(s) to /Users/shannonbowes/Research/ysg/candidates_and_lcs/2022_asassn_lc_data/figs/star_reports/0_7.521702-73.913918_info_plots.pdf
# PosixPath('/Users/shannonbowes/Research/ysg/candidates_and_lcs/2022_asassn_lc_data/figs/star_reports/0_7.521702-73.913918_info_plots.pdf')

# %%
info_to_pdf_batch(range(0,848))
# Out:
# Best frequency: 0.443516 1/day, Best period: 2.25 days, Max power: 0.122, False alarm probability: 2.488e-72
# False alarm level for 1.0%: 1.087e-02
# Grid sampled at 24290 points
# Average scatter (amplitude) per 10 point phase bin: 0.579 mJy
# Average scatter (amplitude) per 10 point phase bin: 0.579 mJy
# [0.00121324 0.0018797  0.00243507 ... 0.89877817 0.89937057 0.89996297]
# Amplitude metrics:
# 	Lower 5% percentile: -0.34 mJy, 13.83 mags
# 	Upper 5% percentile: 0.32 mJy, 13.89 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.65 mJy, 0.07 mags
# Amplitude metrics:
# 	Lower 1% percentile: -0.49 mJy, 13.81 mags
# 	Upper 1% percentile: 0.46 mJy, 13.91 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.96 mJy, 0.10 mags
# 	Largest amplitude of variability (g-band: True): 1.09 mJy, 0.11 mags
# 	Average amplitude across all periods: 0.390 mJy
# 	Standard deviation of amplitudes: 0.184 mJy
# 	Warning: average amplitude (0.390 mJy) is less than 5 sigma (0.184 mJy). This indicates significant variability in the amplitudes across periods.
# Saved 6 plot(s) to /Users/shannonbowes/Research/ysg/candidates_and_lcs/2022_asassn_lc_data/figs/star_reports/0_7.521702-73.913918_info_plots.pdf
# Best frequency: 0.004374 1/day, Best period: 228.61 days, Max power: 0.012, False alarm probability: 2.558e-02
# False alarm level for 1.0%: 1.283e-02
# Grid sampled at 20288 points
# Average scatter (amplitude) per 10 point phase bin: 0.457 mJy
# Average scatter (amplitude) per 10 point phase bin: 0.457 mJy
# [0.00113826 0.00162588 0.00206917 ... 0.89760623 0.89840415 0.89955671]
# Amplitude metrics:
# 	Lower 5% percentile: -0.25 mJy, 14.07 mags
# 	Upper 5% percentile: 0.27 mJy, 14.13 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.51 mJy, 0.07 mags
# Amplitude metrics:
# 	Lower 1% percentile: -0.37 mJy, 14.05 mags
# 	Upper 1% percentile: 0.37 mJy, 14.15 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.74 mJy, 0.10 mags
# 	Largest amplitude of variability (g-band: True): 0.86 mJy, 0.11 mags
# 	Average amplitude across all periods: 0.812 mJy
# 	Standard deviation of amplitudes: 0.040 mJy
# 	Average amplitude (0.812 mJy) is greater than 5 sigma (0.040 mJy). This indicates consistent variability across periods.
# Saved 6 plot(s) to /Users/shannonbowes/Research/ysg/candidates_and_lcs/2022_asassn_lc_data/figs/star_reports/1_7.746443-73.741425_info_plots.pdf
# Best frequency: 0.004971 1/day, Best period: 201.15 days, Max power: 0.049, False alarm probability: 1.029e-20
# False alarm level for 1.0%: 1.289e-02
# Grid sampled at 20189 points
# Average scatter (amplitude) per 10 point phase bin: 0.391 mJy
# Average scatter (amplitude) per 10 point phase bin: 0.391 mJy
# [0.00114044 0.00171954 0.00216501 0.00318958 0.00390232 0.00497144
#  0.00568418 0.00661966 0.00773332 0.00831243 0.03873769]
# Amplitude metrics:
# 	Lower 5% percentile: -0.23 mJy, 14.92 mags
# 	Upper 5% percentile: 0.22 mJy, 15.05 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.45 mJy, 0.13 mags
# Amplitude metrics:
# 	Lower 1% percentile: -0.31 mJy, 14.89 mags
# 	Upper 1% percentile: 0.33 mJy, 15.08 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.64 mJy, 0.19 mags
# 	Largest amplitude of variability (g-band: True): 0.74 mJy, 0.22 mags
# 	Average amplitude across all periods: 0.708 mJy
# 	Standard deviation of amplitudes: 0.021 mJy
# 	Average amplitude (0.708 mJy) is greater than 5 sigma (0.021 mJy). This indicates consistent variability across periods.
# Saved 6 plot(s) to /Users/shannonbowes/Research/ysg/candidates_and_lcs/2022_asassn_lc_data/figs/star_reports/2_7.925977-73.53167_info_plots.pdf
# Best frequency: 0.002061 1/day, Best period: 485.27 days, Max power: 0.035, False alarm probability: 8.116e-14
# False alarm level for 1.0%: 1.276e-02
# Grid sampled at 20414 points
# Average scatter (amplitude) per 10 point phase bin: 0.355 mJy
# Average scatter (amplitude) per 10 point phase bin: 0.355 mJy
# [0.00122364 0.00206069 0.0025453  0.00391102 0.0313576 ]
# Amplitude metrics:
# 	Lower 5% percentile: -0.20 mJy, 14.73 mags
# 	Upper 5% percentile: 0.21 mJy, 14.83 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.41 mJy, 0.10 mags
# Amplitude metrics:
# 	Lower 1% percentile: -0.30 mJy, 14.71 mags
# 	Upper 1% percentile: 0.29 mJy, 14.86 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.60 mJy, 0.15 mags
# 	Largest amplitude of variability (g-band: True): 0.72 mJy, 0.18 mags
# 	Average amplitude across all periods: 0.690 mJy
# 	Standard deviation of amplitudes: 0.023 mJy
# 	Average amplitude (0.690 mJy) is greater than 5 sigma (0.023 mJy). This indicates consistent variability across periods.
# Saved 6 plot(s) to /Users/shannonbowes/Research/ysg/candidates_and_lcs/2022_asassn_lc_data/figs/star_reports/3_7.948884-73.599243_info_plots.pdf
# Best frequency: 0.002684 1/day, Best period: 372.51 days, Max power: 0.017, False alarm probability: 6.340e-05
# False alarm level for 1.0%: 1.281e-02
# Grid sampled at 20342 points
# Average scatter (amplitude) per 10 point phase bin: 0.395 mJy
# /opt/anaconda3/envs/ysg/lib/python3.13/site-packages/numpy/_core/fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/envs/ysg/lib/python3.13/site-packages/numpy/_core/_methods.py:145: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# Average scatter (amplitude) per 10 point phase bin: 0.395 mJy
# [0.00166762 0.00219816 0.00268449 0.00356872 0.00432031]
# Amplitude metrics:
# 	Lower 5% percentile: -0.20 mJy, 15.01 mags
# 	Upper 5% percentile: 0.22 mJy, 15.15 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.42 mJy, 0.13 mags
# Amplitude metrics:
# 	Lower 1% percentile: -0.30 mJy, 14.99 mags
# 	Upper 1% percentile: 0.31 mJy, 15.18 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.61 mJy, 0.20 mags
# 	Largest amplitude of variability (g-band: True): 0.72 mJy, 0.23 mags
# 	Average amplitude across all periods: 0.695 mJy
# 	Standard deviation of amplitudes: 0.023 mJy
# 	Average amplitude (0.695 mJy) is greater than 5 sigma (0.023 mJy). This indicates consistent variability across periods.
# Saved 6 plot(s) to /Users/shannonbowes/Research/ysg/candidates_and_lcs/2022_asassn_lc_data/figs/star_reports/4_7.980047-73.578545_info_plots.pdf
# Best frequency: 0.000998 1/day, Best period: 1002.24 days, Max power: 0.089, False alarm probability: 1.520e-42
# False alarm level for 1.0%: 1.256e-02
# Grid sampled at 20791 points
# Average scatter (amplitude) per 10 point phase bin: 0.488 mJy
# /opt/anaconda3/envs/ysg/lib/python3.13/site-packages/numpy/_core/fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/envs/ysg/lib/python3.13/site-packages/numpy/_core/_methods.py:145: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# Average scatter (amplitude) per 10 point phase bin: 0.488 mJy
# [0.00099777 0.00181964 0.00298757 0.00402573 0.00891373 0.01021143
#  0.01289334 0.01367196 0.01566176 0.01648364 0.01894926 0.02011719
#  0.02063627 0.02340469 0.02478891 0.02954713 0.0348677 ]
# Amplitude metrics:
# 	Lower 5% percentile: -0.30 mJy, 14.40 mags
# 	Upper 5% percentile: 0.32 mJy, 14.51 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.63 mJy, 0.11 mags
# Amplitude metrics:
# 	Lower 1% percentile: -0.42 mJy, 14.38 mags
# 	Upper 1% percentile: 0.45 mJy, 14.54 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.87 mJy, 0.16 mags
# 	Largest amplitude of variability (g-band: True): 1.08 mJy, 0.20 mags
# 	Average amplitude across all periods: 1.062 mJy
# 	Standard deviation of amplitudes: 0.005 mJy
# 	Average amplitude (1.062 mJy) is greater than 5 sigma (0.005 mJy). This indicates consistent variability across periods.
# Saved 6 plot(s) to /Users/shannonbowes/Research/ysg/candidates_and_lcs/2022_asassn_lc_data/figs/star_reports/5_7.981742-73.585571_info_plots.pdf
# Best frequency: 0.063131 1/day, Best period: 15.84 days, Max power: 0.800, False alarm probability: 0.000e+00
# False alarm level for 1.0%: 1.231e-02
# Grid sampled at 21232 points
# Average scatter (amplitude) per 10 point phase bin: 0.760 mJy
# Average scatter (amplitude) per 10 point phase bin: 0.760 mJy
# [0.02920198 0.05775135 0.06037755 0.06262253 0.06313083 0.06368148
#  0.06592646 0.06677362 0.06855266 0.09705967 0.12624441 0.18940035]
# Amplitude metrics:
# 	Lower 5% percentile: -1.52 mJy, 13.85 mags
# 	Upper 5% percentile: 4.13 mJy, 14.69 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 5.65 mJy, 0.84 mags
# Amplitude metrics:
# 	Lower 1% percentile: -1.72 mJy, 13.81 mags
# 	Upper 1% percentile: 4.54 mJy, 14.74 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 6.27 mJy, 0.93 mags
# 	Largest amplitude of variability (g-band: True): 8.72 mJy, 1.58 mags
# 	Average amplitude across all periods: 5.827 mJy
# 	Standard deviation of amplitudes: 0.550 mJy
# 	Average amplitude (5.827 mJy) is greater than 5 sigma (0.550 mJy). This indicates consistent variability across periods.
# Saved 6 plot(s) to /Users/shannonbowes/Research/ysg/candidates_and_lcs/2022_asassn_lc_data/figs/star_reports/6_8.228736-73.821953_info_plots.pdf
# Best frequency: 0.144935 1/day, Best period: 6.90 days, Max power: 0.004, False alarm probability: 1.000e+00
# False alarm level for 1.0%: 1.436e-02
# Grid sampled at 17527 points
# Average scatter (amplitude) per 10 point phase bin: 0.402 mJy
# Average scatter (amplitude) per 10 point phase bin: 0.402 mJy
# [7.97596447e-04 1.36203530e-03 1.97778677e-03 ... 8.97639619e-01
#  8.98409309e-01 8.99435561e-01]
# Amplitude metrics:
# 	Lower 5% percentile: -0.23 mJy, 14.80 mags
# 	Upper 5% percentile: 0.22 mJy, 14.92 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.45 mJy, 0.12 mags
# Amplitude metrics:
# 	Lower 1% percentile: -0.33 mJy, 14.77 mags
# 	Upper 1% percentile: 0.33 mJy, 14.94 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.66 mJy, 0.17 mags
# 	Largest amplitude of variability (g-band: True): 0.74 mJy, 0.20 mags
# 	Average amplitude across all periods: 0.349 mJy
# 	Standard deviation of amplitudes: 0.136 mJy
# 	Warning: average amplitude (0.349 mJy) is less than 5 sigma (0.136 mJy). This indicates significant variability in the amplitudes across periods.
# Saved 6 plot(s) to /Users/shannonbowes/Research/ysg/candidates_and_lcs/2022_asassn_lc_data/figs/star_reports/7_8.560188-73.619049_info_plots.pdf
# Best frequency: 0.569422 1/day, Best period: 1.76 days, Max power: 0.025, False alarm probability: 7.649e-01
# False alarm level for 1.0%: 4.095e-02
# Grid sampled at 5692 points
# Average scatter (amplitude) per 10 point phase bin: 0.887 mJy
# Average scatter (amplitude) per 10 point phase bin: 0.887 mJy
# [0.00102449 0.00276271 0.00465895 0.00718727 0.01066371 0.01255995
#  0.01429817 0.01666847 0.01951282 0.02125104 0.0240954  0.02630768
#  0.0280459  0.0312063  0.03341858 0.0359469  0.0391073  0.04116156
#  0.0438479  0.04558612 0.04748236 0.0501687  0.05190691 0.05348711
#  0.05538335 0.05696355 0.05949187 0.06281029 0.06439049 0.06612871
#  0.06786693 0.06992119 0.07197545 0.07466179 0.07734813 0.07892833
#  0.08082457 0.08240477 0.08414298 0.08603922 0.0882515  0.09109586
#  0.0945723  0.09741666 0.100103   0.10263132 0.10515964 0.10768796
mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.69 mJy, 0.07 mags
# Amplitude metrics:
# 	Lower 1% percentile: -0.47 mJy, 13.84 mags
# 	Upper 1% percentile: 0.52 mJy, 13.95 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 1.00 mJy, 0.11 mags
# 	Largest amplitude of variability (g-band: True): 1.28 mJy, 0.14 mags
# 	Average amplitude across all periods: 1.047 mJy
# 	Standard deviation of amplitudes: 0.103 mJy
# 	Average amplitude (1.047 mJy) is greater than 5 sigma (0.103 mJy). This indicates consistent variability across periods.
# Saved 6 plot(s) to /Users/shannonbowes/Research/ysg/candidates_and_lcs/2022_asassn_lc_data/figs/star_reports/14_9.508638-73.630348_info_plots.pdf
# Best frequency: 0.001110 1/day, Best period: 900.55 days, Max power: 0.065, False alarm probability: 1.017e-20
# False alarm level for 1.0%: 1.678e-02
# Grid sampled at 15153 points
# Average scatter (amplitude) per 10 point phase bin: 0.454 mJy
# Average scatter (amplitude) per 10 point phase bin: 0.454 mJy
# [0.00111044 0.00247554 0.00384064 0.00520574 0.01363376 0.02864987
#  0.03143943 0.03416963]
# Amplitude metrics:
# 	Lower 5% percentile: -0.26 mJy, 14.65 mags
# 	Upper 5% percentile: 0.28 mJy, 14.78 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.53 mJy, 0.12 mags
# Amplitude metrics:
# 	Lower 1% percentile: -0.38 mJy, 14.63 mags
# 	Upper 1% percentile: 0.39 mJy, 14.81 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.77 mJy, 0.18 mags
# 	Largest amplitude of variability (g-band: True): 0.94 mJy, 0.22 mags
# 	Average amplitude across all periods: 0.914 mJy
# 	Standard deviation of amplitudes: 0.003 mJy
# 	Average amplitude (0.914 mJy) is greater than 5 sigma (0.003 mJy). This indicates consistent variability across periods.
# Saved 6 plot(s) to /Users/shannonbowes/Research/ysg/candidates_and_lcs/2022_asassn_lc_data/figs/star_reports/15_9.563685-73.017746_info_plots.pdf
# Best frequency: 0.027045 1/day, Best period: 36.98 days, Max power: 0.852, False alarm probability: 0.000e+00
# False alarm level for 1.0%: 1.641e-02
# Grid sampled at 15530 points
# Average scatter (amplitude) per 10 point phase bin: 0.768 mJy
# Average scatter (amplitude) per 10 point phase bin: 0.768 mJy
# [0.00689148 0.02426488 0.02617596 0.02704463 0.0279133  0.02982437
#  0.03248829 0.05414713 0.06098066 0.08119172]
# Amplitude metrics:
# 	Lower 5% percentile: -1.28 mJy, 13.99 mags
# 	Upper 5% percentile: 2.21 mJy, 14.51 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 3.49 mJy, 0.52 mags
# Amplitude metrics:
# 	Lower 1% percentile: -1.52 mJy, 13.96 mags
# 	Upper 1% percentile: 2.51 mJy, 14.56 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 4.03 mJy, 0.60 mags
# 	Largest amplitude of variability (g-band: True): 6.35 mJy, 1.09 mags
# 	Average amplitude across all periods: 3.745 mJy
# 	Standard deviation of amplitudes: 0.470 mJy
# 	Average amplitude (3.745 mJy) is greater than 5 sigma (0.470 mJy). This indicates consistent variability across periods.
# Saved 6 plot(s) to /Users/shannonbowes/Research/ysg/candidates_and_lcs/2022_asassn_lc_data/figs/star_reports/16_9.57867-73.525597_info_plots.pdf
# Best frequency: 0.052908 1/day, Best period: 18.90 days, Max power: 0.797, False alarm probability: 0.000e+00
# False alarm level for 1.0%: 1.059e-02
# Grid sampled at 24955 points
# Average scatter (amplitude) per 10 point phase bin: 0.929 mJy
# Average scatter (amplitude) per 10 point phase bin: 0.929 mJy
# [0.01903185 0.04750249 0.05013332 0.05200734 0.05236773 0.05290831
#  0.05344889 0.05380928 0.0556833  0.05835017 0.08685685 0.15875423
#  0.26449203]
# Amplitude metrics:
# 	Lower 5% percentile: -1.83 mJy, 13.58 mags
# 	Upper 5% percentile: 6.10 mJy, 14.55 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 7.94 mJy, 0.97 mags
# Amplitude metrics:
# 	Lower 1% percentile: -2.05 mJy, 13.52 mags
# 	Upper 1% percentile: 6.88 mJy, 14.59 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 8.93 mJy, 1.08 mags
# 	Largest amplitude of variability (g-band: True): 9.37 mJy, 1.14 mags
# 	Average amplitude across all periods: 8.204 mJy
# 	Standard deviation of amplitudes: 1.114 mJy
# 	Average amplitude (8.204 mJy) is greater than 5 sigma (1.114 mJy). This indicates consistent variability across periods.
# Saved 6 plot(s) to /Users/shannonbowes/Research/ysg/candidates_and_lcs/2022_asassn_lc_data/figs/star_reports/17_9.818972-72.032875_info_plots.pdf
# Best frequency: 0.002894 1/day, Best period: 345.59 days, Max power: 0.041, False alarm probability: 1.494e-11
# False alarm level for 1.0%: 1.681e-02
# Grid sampled at 15135 points
# Average scatter (amplitude) per 10 point phase bin: 0.481 mJy
# Average scatter (amplitude) per 10 point phase bin: 0.481 mJy
# [0.0012892  0.00289362 0.00396323 0.00663725 0.00907359 0.01204473
#  0.02285968 0.0312383  0.03183253 0.03242676 0.03337752 0.03516021]
# Amplitude metrics:
# 	Lower 5% percentile: -0.27 mJy, 14.51 mags
# 	Upper 5% percentile: 0.30 mJy, 14.63 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.57 mJy, 0.11 mags
# Amplitude metrics:
# 	Lower 1% percentile: -0.37 mJy, 14.49 mags
# 	Upper 1% percentile: 0.43 mJy, 14.65 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.81 mJy, 0.16 mags
# 	Largest amplitude of variability (g-band: True): 1.06 mJy, 0.21 mags
# 	Average amplitude across all periods: 0.937 mJy
# 	Standard deviation of amplitudes: 0.056 mJy
# 	Average amplitude (0.937 mJy) is greater than 5 sigma (0.056 mJy). This indicates consistent variability across periods.
# Saved 6 plot(s) to /Users/shannonbowes/Research/ysg/candidates_and_lcs/2022_asassn_lc_data/figs/star_reports/18_10.190774-72.673569_info_plots.pdf
# Best frequency: 0.035152 1/day, Best period: 28.45 days, Max power: 0.694, False alarm probability: 0.000e+00
# False alarm level for 1.0%: 1.641e-02
# Grid sampled at 15530 points
# Average scatter (amplitude) per 10 point phase bin: 0.849 mJy
# Average scatter (amplitude) per 10 point phase bin: 0.849 mJy
# [0.00121617 0.02970855 0.03237247 0.03428354 0.03515221 0.03793196
#  0.04053797 0.06914616 0.0703623  0.10551448]
# Amplitude metrics:
# 	Lower 5% percentile: -2.21 mJy, 13.67 mags
# 	Upper 5% percentile: 4.69 mJy, 14.56 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 6.90 mJy, 0.89 mags
# Amplitude metrics:
# 	Lower 1% percentile: -2.41 mJy, 13.62 mags
# 	Upper 1% percentile: 5.35 mJy, 14.60 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 7.76 mJy, 0.99 mags
# 	Largest amplitude of variability (g-band: True): 9.16 mJy, 1.17 mags
# 	Average amplitude across all periods: 7.153 mJy
# 	Standard deviation of amplitudes: 0.708 mJy
# 	Average amplitude (7.153 mJy) is greater than 5 sigma (0.708 mJy). This indicates consistent variability across periods.
# Saved 6 plot(s) to /Users/shannonbowes/Research/ysg/candidates_and_lcs/2022_asassn_lc_data/figs/star_reports/19_10.191936-73.717102_info_plots.pdf
# Best frequency: 0.003919 1/day, Best period: 255.16 days, Max power: 0.037, False alarm probability: 4.375e-10
# False alarm level for 1.0%: 1.689e-02
# Grid sampled at 15063 points
# Average scatter (amplitude) per 10 point phase bin: 0.400 mJy
# Average scatter (amplitude) per 10 point phase bin: 0.400 mJy
# [0.00075468 0.00391914]
# Amplitude metrics:
# 	Lower 5% percentile: -0.22 mJy, 14.81 mags
# 	Upper 5% percentile: 0.23 mJy, 14.93 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.45 mJy, 0.12 mags
# Amplitude metrics:
# 	Lower 1% percentile: -0.31 mJy, 14.78 mags
# 	Upper 1% percentile: 0.33 mJy, 14.95 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.63 mJy, 0.17 mags
# 	Largest amplitude of variability (g-band: True): 0.76 mJy, 0.20 mags
# 	Average amplitude across all periods: 0.682 mJy
# 	Standard deviation of amplitudes: 0.057 mJy
# 	Average amplitude (0.682 mJy) is greater than 5 sigma (0.057 mJy). This indicates consistent variability across periods.
# Saved 6 plot(s) to /Users/shannonbowes/Research/ysg/candidates_and_lcs/2022_asassn_lc_data/figs/star_reports
#  0.85832489 0.85915483 0.86063688 0.86146682 0.86300815 0.86437163
#  0.86508302 0.86573511 0.86680219 0.86763213 0.86852136 0.86964771
#  0.8710112  0.87213755 0.87302678 0.87373816 0.87498308 0.87605015
#  0.87723579 0.87818429 0.87883639 0.87942921 0.88002203 0.88144479
#  0.88221546 0.88280828 0.88375678 0.88506098 0.88589093 0.88666159
#  0.88778795 0.88867717 0.88938856 0.88998137 0.89092988 0.8915227
#  0.89229336 0.89318259 0.89472392 0.89590956 0.89685806 0.89762873
#  0.89857724 0.89976287]
# Amplitude metrics:
# 	Lower 5% percentile: -0.34 mJy, 13.47 mags
# 	Upper 5% percentile: 0.36 mJy, 13.52 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.70 mJy, 0.05 mags
# Amplitude metrics:
# 	Lower 1% percentile: -0.49 mJy, 13.46 mags
# 	Upper 1% percentile: 0.52 mJy, 13.53 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 1.01 mJy, 0.08 mags
# 	Largest amplitude of variability (g-band: True): 1.21 mJy, 0.09 mags
# 	Average amplitude across all periods: 1.113 mJy
# 	Standard deviation of amplitudes: 0.063 mJy
# 	Average amplitude (1.113 mJy) is greater than 5 sigma (0.063 mJy). This indicates consistent variability across periods.
# Saved 6 plot(s) to /Users/shannonbowes/Research/ysg/candidates_and_lcs/2022_asassn_lc_data/figs/star_reports/22_10.721161-73.596092_info_plots.pdf
# Best frequency: 0.000873 1/day, Best period: 1145.72 days, Max power: 0.020, False alarm probability: 9.014e-04
# False alarm level for 1.0%: 1.678e-02
# Grid sampled at 15171 points
# Average scatter (amplitude) per 10 point phase bin: 0.526 mJy
# /opt/anaconda3/envs/ysg/lib/python3.13/site-packages/numpy/_core/fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/envs/ysg/lib/python3.13/site-packages/numpy/_core/_methods.py:145: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# Average scatter (amplitude) per 10 point phase bin: 0.526 mJy
# [0.00087282]
# Amplitude metrics:
# 	Lower 5% percentile: -0.29 mJy, 13.84 mags
# 	Upper 5% percentile: 0.28 mJy, 13.90 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.57 mJy, 0.06 mags
# Amplitude metrics:
# 	Lower 1% percentile: -0.45 mJy, 13.82 mags
# 	Upper 1% percentile: 0.42 mJy, 13.92 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.87 mJy, 0.09 mags
# 	Largest amplitude of variability (g-band: True): 1.02 mJy, 0.11 mags
# 	Average amplitude across all periods: 1.017 mJy
# 	Standard deviation of amplitudes: 0.003 mJy
# 	Average amplitude (1.017 mJy) is greater than 5 sigma (0.003 mJy). This indicates consistent variability across periods.
# Saved 6 plot(s) to /Users/shannonbowes/Research/ysg/candidates_and_lcs/2022_asassn_lc_data/figs/star_reports/23_10.745516-73.29184_info_plots.pdf
# Best frequency: 0.031346 1/day, Best period: 31.90 days, Max power: 0.701, False alarm probability: 0.000e+00
# False alarm level for 1.0%: 1.644e-02
# Grid sampled at 15522 points
# Average scatter (amplitude) per 10 point phase bin: 1.566 mJy
# Average scatter (amplitude) per 10 point phase bin: 1.566 mJy
# [0.02589938 0.02856468 0.0304188  0.03134585 0.03221497 0.03406909
#  0.06263409 0.06529939 0.1252685 ]
# Amplitude metrics:
# 	Lower 5% percentile: -2.57 mJy, 13.59 mags
# 	Upper 5% percentile: 6.35 mJy, 14.81 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 8.92 mJy, 1.21 mags
# Amplitude metrics:
# 	Lower 1% percentile: -2.85 mJy, 13.53 mags
# 	Upper 1% percentile: 7.10 mJy, 14.88 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 9.95 mJy, 1.35 mags
# 	Largest amplitude of variability (g-band: True): 12.78 mJy, 1.82 mags
# 	Average amplitude across all periods: 9.378 mJy
# 	Standard deviation of amplitudes: 0.960 mJy
# 	Average amplitude (9.378 mJy) is greater than 5 sigma (0.960 mJy). This indicates consistent variability across periods.
# Saved 6 plot(s) to /Users/shannonbowes/Research/ysg/candidates_and_lcs/2022_asassn_lc_data/figs/star_reports/24_10.95191-73.613548_info_plots.pdf
# Best frequency: 0.001761 1/day, Best period: 567.73 days, Max power: 0.087, False alarm probability: 1.273e-29
# False alarm level for 1.0%: 1.676e-02
# Grid sampled at 15180 points
# Average scatter (amplitude) per 10 point phase bin: 0.543 mJy
# Average scatter (amplitude) per 10 point phase bin: 0.543 mJy
# [0.00093196 0.00176141 0.00324258 0.00401278 0.00460525 0.00590868
#  0.00875252 0.02178678]
# Amplitude metrics:
# 	Lower 5% percentile: -0.31 mJy, 14.45 mags
# 	Upper 5% percentile: 0.31 mJy, 14.57 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.62 mJy, 0.12 mags
# Amplitude metrics:
# 	Lower 1% percentile: -0.44 mJy, 14.43 mags
# 	Upper 1% percentile: 0.46 mJy, 14.60 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.90 mJy, 0.17 mags
# 	Largest amplitude of variability (g-band: True): 1.06 mJy, 0.20 mags
# 	Average amplitude across all periods: 0.961 mJy
# 	Standard deviation of amplitudes: 0.068 mJy
# 	Average amplitude (0.961 mJy) is greater than 5 sigma (0.068 mJy). This indicates consistent variability across periods.
# Saved 6 plot(s) to /Users/shannonbowes/Research/ysg/candidates_and_lcs/2022_asassn_lc_data/figs/star_reports/25_11.004765-72.995163_info_plots.pdf
# Best frequency: 0.002964 1/day, Best period: 337.40 days, Max power: 0.026, False alarm probability: 6.194e-06
# False alarm level for 1.0%: 1.688e-02
# Grid sampled at 15063 points
# Average scatter (amplitude) per 10 point phase bin: 0.436 mJy
# Average scatter (amplitude) per 10 point phase bin: 0.436 mJy
# [0.00296383]
# Amplitude metrics:
# 	Lower 5% percentile: -0.25 mJy, 14.57 mags
# 	Upper 5% percentile: 0.24 mJy, 14.68 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.50 mJy, 0.10 mags
# Amplitude metrics:
# 	Lower 1% percentile: -0.35 mJy, 14.55 mags
# 	Upper 1% percentile: 0.37 mJy, 14.70 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.72 mJy, 0.15 mags
# 	Largest amplitude of variability (g-band: True): 0.85 mJy, 0.18 mags
# 	Average amplitude across all periods: 0.798 mJy
# 	Standard deviation of amplitudes: 0.022 mJy
# 	Average amplitude (0.798 mJy) is greater than 5 sigma (0.022 mJy). This indicates consistent variability across periods.
# Saved 6 plot(s) to /Users/shannonbowes/Research/ysg/candidates_and_lcs/2022_asassn_lc_data/figs/star_reports/26_11.045316-73.212608_info_plots.pdf
# Best frequency: 0.002297 1/day, Best period: 435.26 days, Max power: 0.023, False alarm probability: 4.791e-05
# False alarm level for 1.0%: 1.679e-02
# Grid sampled at 15153 points
# Average scatter (amplitude) per 10 point phase bin: 0.422 mJy
# Average scatter (amplitude) per 10 point phase bin: 0.422 mJy
# [0.00099173 0.00229748 0.00306906]
# Amplitude metrics:
# 	Lower 5% percentile: -0.22 mJy, 14.76 mags
# 	Upper 5% percentile: 0.26 mJy, 14.88 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 5% of data) (g-band: True): 0.48 mJy, 0.12 mags
# Amplitude metrics:
# 	Lower 1% percentile: -0.31 mJy, 14.73 mags
# 	Upper 1% percentile: 0.36 mJy, 14.90 mags
# 	Percentile amplitude of variability (excluding the brightest and dimmest 1% of data) (g-band: True): 0.67 mJy, 0.17 mags
# 	Largest amplitude of variability (g-band: True): 0.79 mJy, 0.20 mags
# 	Average amplitude across all periods: 0.741 mJy
# 	Standard deviation of amplitudes: 0.031 mJy
# 	Average amplitude (0.741 mJy) is greater than 5 sigma (0.031 mJy). This indicates consistent variability across periods.
# Saved 6 plot(s) to /Users/shannonbowes/Research/ysg/candidates_and_lcs/2022_asassn_lc_data/figs/star_reports/27_11.210925-72.885483_info_plots.pdf
# Best frequency: 0.002478 1/day, Best period: 403.61 days, Max power: 0.100, False alarm probability: 1.321e-34
# False alarm level for 1.0%: 1.680e-02
# Grid sampled at 15135 points
